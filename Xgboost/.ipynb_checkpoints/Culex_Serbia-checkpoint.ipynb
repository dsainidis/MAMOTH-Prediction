# %%
import pandas as pd
import numpy as np
from ipynb.fs.defs.Preprocessing_Module import read_data, add_topological, add_landcover, select_columns, reshape_dataset, fillna_dataset
from ipynb.fs.defs.Feature_Expansion_Module import feature_expansion
from ipynb.fs.defs.Initializer_Module import initializer
from ipynb.fs.defs.XGBoost_Model_Module import Xgboost_model
from ipynb.fs.defs.Model_Validation_Module import test_model_random_split, train_model_KFold, operational_validation, predict

# %%
import warnings
warnings.filterwarnings('ignore')
np.set_printoptions(suppress=True)

# %%
data = read_data('../Datasets/Serbia/Vojvodina/SER_vojvodina_culex_2010_2022.csv')
columns = ['dt_placement', 'x', 'y', 'culex.spp', 'ndvi', 'ndwi', 'ndmi', 'ndbi',
           'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean',
           'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day', 'lst_night',
           'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan',
           'lst_jan_day_mean', 'lst_feb_day_mean', 'lst_mar_day_mean', 'lst_apr_day_mean',
           'lst_jan_night_mean', 'lst_feb_night_mean', 'lst_mar_night_mean', 'lst_apr_night_mean']
names = ['dt_placement', 'x', 'y', 'mosq_now', 'ndvi', 'ndwi', 'ndmi', 'ndbi',
         'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean',
         'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day', 'lst_night',
         'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan',
         'lst_jan_day_mean', 'lst_feb_day_mean', 'lst_mar_day_mean', 'lst_apr_day_mean',
         'lst_jan_night_mean', 'lst_feb_night_mean', 'lst_mar_night_mean', 'lst_apr_night_mean']
data = select_columns(data,columns,names)
data = add_topological(data,'../Datasets/Topological Datasets/2x2grid/th_Serbia_shapefile_2km_geo.csv')
data = add_landcover(data,'../Datasets/Landcover Datasets/2x2grid/th_Serbia_shapefile_2km_lulc.csv')
data = reshape_dataset(data,['x','y','dt_placement'])
data = fillna_dataset(data,{'acc_rainfall_1week':0, 'acc_rainfall_2week':0, 'acc_rainfall_jan':0})
# Out:
# Index(['station_id', 'x', 'y', 'dt_placement', 'week', 'month', 'year',
#        'country_code', 'nuts0_code', 'nuts0_name', 'nuts1_code', 'nuts1_name',
#        'nuts2_code', 'nuts2_name', 'nuts3_code', 'nuts3_name',
#        'lau1_municipality', 'lau2_settlement', 'trap_type', 'culex.spp',
#        'region', 'dt_placement_original', 'indices_image_date', 'indices_lat',
#        'indices_lon', 'ndvi', 'ndmi', 'ndwi', 'ndbi', 'ndvi_mean', 'ndmi_mean',
#        'ndwi_mean', 'ndbi_mean', 'ndvi_std', 'ndmi_std', 'ndwi_std',
#        'ndbi_std', 'lst_image_date', 'lst_lat', 'lst_lon', 'lst_day',
#        'lst_night', 'monthly_lst_lat', 'monthly_lst_lon', 'lst_jan_day_mean',
#        'lst_jan_night_mean', 'lst_feb_day_mean', 'lst_feb_night_mean',
#        'lst_mar_day_mean', 'lst_mar_night_mean', 'lst_apr_day_mean',
#        'lst_apr_night_mean', 'indices_image_date.1', 'indices_lat.1',
#        'indices_lon.1', 'acc_rainfall_jan', 'dt_placement_minus_7',
#        'dt_placement_minus_14', 'dt_placement_minus_7_avail',
#        'dt_placement_minus_14_avail', 'acc_rainfall_1week',
#        'acc_rainfall_2week'],
#       dtype='object')

# %%
# set the only_env as True if you want to use only environmental features
only_env = True
# set the case title
case_title = 'Culex Serbia'
# set the exp as True if you want to save the results as csv
exp = False
# set the filepath to export the data
path = '../Results/Culex Serbia/'
# set the name of the sdate column
date_col = 'dt_placement'
# set the model type. Could be 'class_regression' or 'mosquito_regression' or 'classification'
model_type = 'class_regression'
# set the transform argument as True if you want to limit the target variable to 0-9 scale
transform_target = False
#set the data for embeddings e.g. data[['col', 'col2']]
embedded_data = None
#set the transformation actions of the data. Options are 'augmentation', 'normalization', 'log', 'scaling'
transformation_list = []

# %%
data = feature_expansion(data, env=only_env)

# %%
data = initializer(data, model_type, 10, dropna=True)
# Out:
# Bounds: [    0.     15.     38.2    80.3   142.    200.    256.    408.7   635.8
#   1143.2 23248. ]

# %%
model = Xgboost_model(model_type = model_type, learning_rate = 0.2,
                      embedding_data = embedded_data,  transformation_list = transformation_list,
                      early_stop = False, l1_weight = 1.5, l2_weight = 0, weights = False)

# %%
test_model_random_split(data, model, filepath = '', date_col = date_col, case='', fi = True, export=exp)
# Out:
# Fitting 10 folds for each of 350 candidates, totalling 3500 fits
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 test_model_random_split(data, model, filepath = '', date_col = date_col, case='', fi = True, export=exp)
#
# File ~\Desktop\noa\Xgboost\Model_Validation_Module.ipynb:350, in test_model_random_split(train, model, test, filepath, date_col, case, fi, export)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "nonprofit-range",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import pandas as pd\n",
#      11     "import numpy as np\n",
#      12     "import datetime\n",
#      13     "from sklearn.model_selection import train_test_split\n",
#      14     "from sklearn.model_selection import KFold\n",
#      15     "from sklearn.metrics import mean_absolute_error\n",
#      16     "import matplotlib.pyplot as plt\n",
#      17     "import copy\n",
#      18     "from ipynb.fs.defs.XGboost_Model_Module import transformations_xgboost, train_xgboost, predict_xgboost\n",
#      19     "from imblearn.under_sampling import TomekLinks"
#      20    ]
#      21   },
#      22   {
#      23    "cell_type": "code",
#      24    "execution_count": 4,
#      25    "id": "binding-triangle",
#      26    "metadata": {},
#      27    "outputs": [],
#      28    "source": [
#      29     "def plot_error_dist(actual, predictions, model_type, case=''):\n",
#      30     "    \"\"\"Prints the error distribution plot\n",
#      31     "    Parameters\n",
#      32     "    --------\n",
#      33     "    actual : pd.Series\n",
#      34     "        A Series with the actual class of each prediction\n",
#      35     "        \n",
#      36     "    predictions : pd.Series\n",
#      37     "        A Series with the predicted class of each prediction\n",
#      38     "        \n",
#      39     "    model_type : str\n",
#      40     "        Could be 'class_regression' or 'mosquito_regression' or 'classification'\n",
#      41     "    \n",
#      42     "    case: str, optional\n",
#      43     "        Title of the plot (default= '')\n",
#      44     "    \"\"\"\n",
#      45     "    error = np.abs(actual-predictions).tolist()\n",
#      46     "    if model_type != 'mosquito_regression':\n",
#      47     "        bins = np.arange(len(actual.unique())) - 0.5\n",
#      48     "        plt.hist(error, bins)\n",
#      49     "        plt.xticks(range(len(actual.unique())))\n",
#      50     "    else:\n",
#      51     "        plt.hist(error)\n",
#      52     "    plt.xlabel('abs(error)')\n",
#      53     "    plt.title('Error Distribution \\n' + case)\n",
#      54     "    plt.show()"
#      55    ]
#      56   },
#      57   {
#      58    "cell_type": "code",
#      59    "execution_count": null,
#      60    "id": "6a564578",
#      61    "metadata": {},
#      62    "outputs": [],
#      63    "source": [
#      64     "def plot_hist(actual, predictions, model_type, case=''):\n",
#      65     "    \"\"\"Prints the histogram of the actual values and the predicted values\n",
#      66     "    Parameters\n",
#      67     "    --------\n",
#      68     "    actual : pd.Series\n",
#      69     "        A Series with the actual class of each prediction\n",
#      70     "        \n",
#      71     "    predictions : pd.Series\n",
#      72     "        A Series with the predicted class of each prediction\n",
#      73     "        \n",
#      74     "    model_type : str\n",
#      75     "        Could be 'class_regression' or 'mosquito_regression' or 'classification'\n",
#      76     "    \n",
#      77     "    case: str, optional\n",
#      78     "        Title of the plot (default= '')\n",
#      79     "    \"\"\"\n",
#      80     "    plt.figure(figsize=(10,8)) \n",
#      81     "    if model_type != 'mosquito_regression':\n",
#      82     "        bins = np.arange(len(actual.unique())+1)-0.5\n",
#      83     "        plt.hist(actual, bins=bins, alpha=0.5, label='actual')\n",
#      84     "        plt.hist(predictions, bins=bins, alpha=0.5, label='prediction')\n",
#      85     "        plt.xticks(range(len(actual.unique())))\n",
#      86     "    else:\n",
#      87     "        plt.hist(actual, alpha=0.5, label='actual')\n",
#      88     "        plt.hist(predictions, alpha=0.5, label='prediction')\n",
#      89     "    plt.legend()\n",
#      90     "    plt.title('Histogram of actual vs predicted values \\n'+case)\n",
#      91     "    plt.show()"
#      92    ]
#      93   },
#      94   {
#      95    "cell_type": "code",
#      96    "execution_count": 5,
#      97    "id": "educated-change",
#      98    "metadata": {},
#      99    "outputs": [],
#     100    "source": [
#     101     "def plot_error_per_class(test, case=''):\n",
#     102     "    \"\"\"Prints the error distribution per class plot\n",
#     103     "    Parameters\n",
#     104     "    --------\n",
#     105     "    actual : lst\n",
#     106     "        A list with the actual class of each prediction\n",
#     107     "        \n",
#     108     "    case: str, optional\n",
#     109     "        Title of the plot (Area and mosquito genus) (default= '')\n",
#     110     "    \"\"\"\n",
#     111     "    labels = test.loc[:,'actual'].unique().tolist()\n",
#     112     "    labels.sort()\n",
#     113     "    f = []\n",
#     114     "    length = []\n",
#     115     "    for k in labels:\n",
#     116     "        cc = test.loc[test['actual']==k]\n",
#     117     "        length.append(len(cc))\n",
#     118     "        actual = cc.loc[:,'actual']\n",
#     119     "        predictions = cc.loc[:,'prediction']\n",
#     120     "        mae_class = mean_absolute_error(actual, predictions)\n",
#     121     "        f.append(mae_class)\n",
#     122     "    labels = [str(int(e)) for e in labels]\n",
#     123     "    fig = plt.figure()\n",
#     124     "    ax = fig.add_axes([0,0,1,1])\n",
#     125     "    ax.bar(labels,f)\n",
#     126     "    for i, v in enumerate(f):\n",
#     127     "        ax.text(i, v, str('%.2f'%(v)), rotation=30)\n",
#     128     "        ax.text(i, v/2,'n = '+ str(length[i]), weight=\"bold\", ha='center', rotation=90)\n",
#     129     "    plt.xlabel('class')\n",
#     130     "    plt.ylabel('MAE')\n",
#     131     "    plt.title('MAE per class \\n' + case)\n",
#     132     "    plt.show()\n",
#     133     "    \n",
#     134     "    print('-----------|class error-MAE| difference-----------')\n",
#     135     "    z = np.abs(f-mean_absolute_error(actual, predictions))\n",
#     136     "    print('mean:',z.mean())\n",
#     137     "    print('std:',z.std())\n",
#     138     "    print('coefficient of variation (std/mean):',z.std()/z.mean())\n",
#     139     "    \n",
#     140     "    print()\n",
#     141     "    \n",
#     142     "    print('----------normalized difference-------------')\n",
#     143     "    min_val = min(z)\n",
#     144     "    max_val = max(z)\n",
#     145     "    z = (z - min_val) / (max_val-min_val)\n",
#     146     "    print('mean:',z.mean())\n",
#     147     "    print('std:',z.std())\n",
#     148     "    print('coefficient of variation (std/mean):',z.std()/z.mean())"
#     149    ]
#     150   },
#     151   {
#     152    "cell_type": "code",
#     153    "execution_count": 6,
#     154    "id": "expired-stable",
#     155    "metadata": {},
#     156    "outputs": [],
#     157    "source": [
#     158     "def plot_error_per_month(df, case=''):\n",
#     159     "    \"\"\"Prints the error per month\n",
#     160     "    Parameters\n",
#     161     "    --------\n",
#     162     "    df : dataframe\n",
#     163     "        A dataframe containing the data\n",
#     164     "    \n",
#     165     "    case: str, optional\n",
#     166     "        Title of the plot (Area and mosquito genus) (default= '')\n",
#     167     "    \"\"\"\n",
#     168     "    fig = plt.figure()\n",
#     169     "    ax = fig.add_axes([0,0,1,1])\n",
#     170     "    labels = (df['dt_prediction'].dt.month).unique()\n",
#     171     "    labels.sort()\n",
#     172     "    labels = [str(e) for e in labels]\n",
#     173     "    df['abs(error)'] = np.abs(df['actual']-df['prediction'])\n",
#     174     "    f = df.groupby(by=[df['dt_prediction'].dt.month])['abs(error)'].mean().values\n",
#     175     "    length = df.groupby(by=[df['dt_prediction'].dt.month])['dt_prediction'].count().values\n",
#     176     "    ax.bar(labels,f)\n",
#     177     "    for i, v in enumerate(f):\n",
#     178     "        ax.text(i, v, str('%.2f'%(v)),rotation=30)\n",
#     179     "        ax.text(i, v/2,'n = '+ str(length[i]),weight=\"bold\",ha='center', rotation=90)\n",
#     180     "    plt.xlabel('Month')\n",
#     181     "    plt.ylabel('MAE')\n",
#     182     "    plt.title('Mean Absolute Error per month \\n' + case)\n",
#     183     "    plt.show()"
#     184    ]
#     185   },
#     186   {
#     187    "cell_type": "code",
#     188    "execution_count": 7,
#     189    "id": "formed-start",
#     190    "metadata": {},
#     191    "outputs": [],
#     192    "source": [
#     193     "def scatter_plot_error(actual, prediction, case=''):\n",
#     194     "    \"\"\"Prints the error in relation with the distance of point from the train region\n",
#     195     "    Parameters\n",
#     196     "    --------\n",
#     197     "    df : dataframe\n",
#     198     "        A dataframe containing the data\n",
#     199     "    \n",
#     200     "    case: str, optional\n",
#     201     "        Title of the plot (Area and mosquito genus) (default= '')\n",
#     202     "    \"\"\"\n",
#     203     "    # choose the input and output variables\n",
#     204     "    x, y = actual, np.abs(actual-prediction)\n",
#     205     "    plt.scatter(x, y)\n",
#     206     "    plt.xlabel('Mosquito bins')\n",
#     207     "    plt.ylabel('Error')\n",
#     208     "    plt.title('Scatterplot of error \\n' + case)\n",
#     209     "    plt.show()"
#     210    ]
#     211   },
#     212   {
#     213    "cell_type": "code",
#     214    "execution_count": null,
#     215    "id": "0a61b7e5",
#     216    "metadata": {},
#     217    "outputs": [],
#     218    "source": [
#     219     "def plot_error_per_group(actual,prediction,case=''):\n",
#     220     "    \"\"\"Prints the error distribution plot\n",
#     221     "    Parameters\n",
#     222     "    --------\n",
#     223     "    actual : pd.Series\n",
#     224     "        A Series with the actual class of each prediction\n",
#     225     "        \n",
#     226     "    predictions : pd.Series\n",
#     227     "        A Series with the predicted class of each prediction\n",
#     228     "        \n",
#     229     "    case: str, optional\n",
#     230     "        Title of the plot (default= '')\n",
#     231     "\n",
#     232     "    \"\"\"\n",
#     233     "    test = {'mosq_now':actual,'predictions':prediction}\n",
#     234     "    test = pd.DataFrame(test)\n",
#     235     "    test['classes'] = pd.cut(x=test['mosq_now'], bins=[-1, 100, 200, 300, 400, 500, np.inf],\n",
#     236     "                      labels=['0-100', '101-200', '201-300', '301-400', '401-500', '500<'])\n",
#     237     "    labels = test['classes'].unique().tolist()\n",
#     238     "    labels.sort()\n",
#     239     "    f = []\n",
#     240     "    length = []\n",
#     241     "    for k in labels:\n",
#     242     "        cc = test.loc[test['classes']==k]\n",
#     243     "        length.append(len(cc))\n",
#     244     "        actual = cc.loc[:,'mosq_now']\n",
#     245     "        predictions = cc.loc[:,'predictions']\n",
#     246     "        f.append(mean_absolute_error(actual, predictions))\n",
#     247     "    fig = plt.figure()\n",
#     248     "    ax = fig.add_axes([0,0,1,1])\n",
#     249     "    ax.bar(labels,f)\n",
#     250     "    for i, v in enumerate(f):\n",
#     251     "        ax.text(i, v, str('%.2f'%(v)),rotation=30)\n",
#     252     "        ax.text(i, v/2,'n = '+ str(length[i]),weight=\"bold\",ha='center', rotation=90)\n",
#     253     "    plt.xlabel('Mosquito Group')\n",
#     254     "    plt.ylabel('MAE')\n",
#     255     "    plt.title('MAE per Mosquito group \\n'+case)\n",
#     256     "    plt.show()"
#     257    ]
#     258   },
#     259   {
#     260    "cell_type": "code",
#     261    "execution_count": null,
#     262    "id": "b8a22928",
#     263    "metadata": {},
#     264    "outputs": [],
#     265    "source": [
#     266     "def error_cdf(actual, prediction, case=''):\n",
#     267     "    \"\"\"Prints the cdf of errors\n",
#     268     "    Parameters\n",
#     269     "    --------\n",
#     270     "    actual : pd.Series\n",
#     271     "        A Series with the actual class of each prediction\n",
#     272     "        \n",
#     273     "    predictions : pd.Series\n",
#     274     "        A Series with the predicted class of each prediction\n",
#     275     "        \n",
#     276     "    case: str, optional\n",
#     277     "        Title of the plot (default= '')\n",
#     278     "\n",
#     279     "    \"\"\"\n",
#     280     "    error = np.abs(actual-prediction)\n",
#     281     "    \n",
#     282     "    a = np.sort(error.unique())\n",
#     283     "    b = np.array(error)\n",
#     284     "    cdf = np.zeros(len(a))\n",
#     285     "    for k, val in enumerate(a):\n",
#     286     "        mask_d = b <= val\n",
#     287     "        cdf[k] = mask_d.sum()/ len(b)\n",
#     288     "    plt.plot(a,cdf)\n",
#     289     "    plt.grid()\n",
#     290     "    plt.xlabel('abs(error)')\n",
#     291     "    plt.ylabel('CDF')\n",
#     292     "    plt.title('CDF of error \\n' + case)\n",
#     293     "    plt.show() \n",
#     294     "    \n",
#     295     "    b = np.sort(error)\n",
#     296     "    a = np.arange(1,len(error)+1) \n",
#     297     "    cdf = np.zeros(len(a))\n",
#     298     "    for k, val in enumerate(b):\n",
#     299     "        cdf[k] = b[k]\n",
#     300     "    plt.plot(a,cdf)\n",
#     301     "    plt.grid()\n",
#     302     "    plt.xlabel('Number of samples')\n",
#     303     "    plt.ylabel('Error')\n",
#     304     "    plt.title('CDF of error \\n' + case)\n",
#     305     "    plt.show()"
#     306    ]
#     307   },
#     308   {
#     309    "cell_type": "code",
#     310    "execution_count": null,
#     311    "id": "1c00821f",
#     312    "metadata": {},
#     313    "outputs": [],
#     314    "source": [
#     315     "def validation(train,test, model_type, case=''):\n",
#     316     "    \"\"\"Prints plots about the performance of the model on the test set\n",
#     317     "    \n",
#     318     "    Parameters\n",
#     319     "    --------        \n",
#     320     "    test : Dataframe\n",
#     321     "        A Dataframe with the actual and the predicted values on the train set\n",
#     322     "    \n",
#     323     "    model_type : str\n",
#     324     "        Could be 'class_regression' or 'mosquito_regression' or 'classification'\n",
#     325     "        \n",
#     326     "    case: str, optional\n",
#     327     "        Title of the plot (default= '')\n",
#     328     "    \"\"\"\n",
#     329     "    if model_type != 'mosquito_regression':\n",
#     330     "        metrics(train, test)\n",
#     331     "        plot_error_per_class(test, case)\n",
#     332     "    else:\n",
#     333     "        metrics(train, test, threshold=30)\n",
#     334     "        plot_error_per_group(test['actual'],test['prediction'], case)\n",
#     335     "        error_cdf(test['actual'],test['prediction'], case)\n",
#     336     "    scatter_plot_error(test['actual'],test['prediction'], case)\n",
#     337     "    plot_error_dist(test['actual'],test['prediction'], model_type, case)\n",
#     338     "    plot_hist(test['actual'],test['prediction'], model_type, case)\n",
#     339     "    plot_error_per_month(test, case)"
#     340    ]
#     341   },
#     342   {
#     343    "cell_type": "code",
#     344    "execution_count": null,
#     345    "id": "a85ae4b8",
#     346    "metadata": {},
#     347    "outputs": [],
#     348    "source": [
#     349     "def metrics(train, test, threshold=3):\n",
# --> 350     "    \"\"\"Calculates the perfomance of the model on train and test set\n",
#     351     "    Parameters\n",
#     352     "    --------\n",
#     353     "    train : Dataframe\n",
#     354     "        A Dataframe with the actual and the predicted values on the train set\n",
#     355     "        \n",
#     356     "    test : Dataframe\n",
#     357     "        A Dataframe with the actual and the predicted values on the train set\n",
#     358     "        \n",
#     359     "    threshold: int, optional\n",
#     360     "        A threshold to calculate percentage of error < threshold (default= 3)\n",
#     361     "\n",
#     362     "    \"\"\"    \n",
#     363     "    print('MAE on train set: ', mean_absolute_error(train['actual'], train['prediction']))\n",
#     364     "\n",
#     365     "    print('min prediction:',min(train['prediction']))\n",
#     366     "    print('max prediction:',max(train['prediction']))\n",
#     367     "    \n",
#     368     "    print()\n",
#     369     "\n",
#     370     "    print('MAE on test set: ', mean_absolute_error(test['actual'], test['prediction']))\n",
#     371     "    perc = ((np.abs(test['actual']-test['prediction']) < (threshold+0.5)).mean())*100\n",
#     372     "    print('Error <= '+str(threshold)+':',\"%.2f\"%perc,'%')\n",
#     373     "\n",
#     374     "    print('min prediction:',min(test['prediction']))\n",
#     375     "    print('max prediction:',max(test['prediction']))"
#     376    ]
#     377   },
#     378   {
#     379    "cell_type": "code",
#     380    "execution_count": 9,
#     381    "id": "vital-times",
#     382    "metadata": {},
#     383    "outputs": [],
#     384    "source": [
#     385     "def test_model_random_split(train, model, test=None, filepath = '', date_col = 'dt_placement',\n",
#     386     "                            case='', fi = True, export=False):\n",
#     387     "    \"\"\"Trains a model on random splitted data\n",
#     388     "    \n",
#     389     "    Parameters\n",
#     390     "    --------\n",
#     391     "    data : dataframe\n",
#     392     "        A dataframe containing the data\n",
#     393     "        \n",
#     394     "    embedding_data : dataframe, optional\n",
#     395     "        A datafrane with the categorical features (default = None)\n",
#     396     "        \n",
#     397     "    filepath : srt, optional\n",
#     398     "        The path of the file to export the results (default = '')\n",
#     399     "        \n",
#     400     "    date_col : str, optional\n",
#     401     "        The name of the date column (default = 'dt_placement')\n",
#     402     "    \n",
#     403     "    case : str, optional\n",
#     404     "        The title of case for the plot (default='')\n",
#     405     "    \n",
#     406     "    export : boolean, optional\n",
#     407     "        Export a csv with the feature importance and a csv with the test data (default = False)\n",
#     408     "    \"\"\"\n",
#     409     "    case = case + \" random validation\"\n",
#     410     "\n",
#     411     "    if test is None:\n",
#     412     "        np.random.seed(1)\n",
#     413     "        drop_index = np.random.randint(0, len(train), int((len(train)*20)/100))\n",
#     414     "        test = train.iloc[drop_index,:].reset_index(drop=True)\n",
#     415     "        train = train.drop(drop_index).reset_index(drop=True)\n",
#     416     "    \n",
#     417     "    del train[date_col]\n",
#     418     "    date = test[date_col]\n",
#     419     "    del test[date_col]\n",
#     420     "    \n",
#     421     "#     tl = TomekLinks()\n",
#     422     "#     train, y = tl.fit_resample(train.iloc[:,:-1], train.iloc[:,-1])\n",
#     423     "#     train = pd.concat([train,y],axis=1)\n",
#     424     "\n",
#     425     "    max_val= train.iloc[:,-1].max()\n",
#     426     "    mosq_col = train.columns[-1]\n",
#     427     "    model_int = copy.deepcopy(model)\n",
#     428     "    \n",
#     429     "    train_X, train_y, test_X, test_y = transformations_xgboost(train, test = test, model_type = model.model_type,\n",
#     430     "                                                               evaluation=False,\n",
#     431     "                                                               transformation_list=model.transformation_list,\n",
#     432     "                                                               embedding_data=model.embedding_data)\n",
#     433     "\n",
#     434     "    results_train, results_test = train_xgboost(model_int, train_X, train_y, test_X, test_y, max_val, fi)\n",
#     435     "        \n",
#     436     "    \n",
#     437     "    test[date_col] = date\n",
#     438     "    test['dt_prediction'] = test[date_col] + datetime.timedelta(days=15)\n",
#     439     "    test['prediction'] = results_test['prediction']\n",
#     440     "    test['error'] = test[mosq_col] - test['prediction']\n",
#     441     "    test['abs(error)'] = np.abs(test['error'])\n",
#     442     "    \n",
#     443     "    test = test.rename(columns={mosq_col:'actual'})\n",
#     444     "    \n",
#     445     "    validation(results_train, test, model_type=model.model_type, case=case)\n",
#     446     "    \n",
#     447     "    test_X = test.rename(columns={'actual':mosq_col})\n",
#     448     "    \n",
#     449     "    if export:\n",
#     450     "        csv = filepath + case + '.csv'\n",
#     451     "        test.to_csv(csv,index=False)"
#     452    ]
#     453   },
#     454   {
#     455    "cell_type": "code",
#     456    "execution_count": 10,
#     457    "id": "duplicate-senator",
#     458    "metadata": {},
#     459    "outputs": [],
#     460    "source": [
#     461     "def train_model_KFold(data, model, cv=10, date_col='dt_placement', case = '', fi=False):\n",
#     462     "    \"\"\"Trains a model on KFold splitted data\n",
#     463     "    \n",
#     464     "    Parameters\n",
#     465     "    --------\n",
#     466     "    data : dataframe\n",
#     467     "        A dataframe containing the data\n",
#     468     "        \n",
#     469     "    date_col : str, optional\n",
#     470     "        The name of the date column (default = 'dt_placement')\n",
#     471     "    \"\"\"\n",
#     472     "    \n",
#     473     "    case = case + \" KFold validation\"\n",
#     474     " \n",
#     475     "    kf = KFold(n_splits=cv, random_state=0, shuffle=True)\n",
#     476     "    \n",
#     477     "    df_train = pd.DataFrame() \n",
#     478     "    df_test = pd.DataFrame()\n",
#     479     "    \n",
#     480     "    model_int = copy.deepcopy(model)\n",
#     481     "\n",
#     482     "    for train_index, test_index in kf.split(data):\n",
#     483     "        train = data.iloc[train_index,:].reset_index(drop=True)\n",
#     484     "        test = data.iloc[test_index,:].reset_index(drop=True)\n",
#     485     "        \n",
#     486     "        del train[date_col]\n",
#     487     "        date = test[date_col]\n",
#     488     "        del test[date_col]\n",
#     489     "        \n",
#     490     "        max_val= train.iloc[:,-1].max()\n",
#     491     "        \n",
#     492     "#         tl = TomekLinks()\n",
#     493     "#         train, y = tl.fit_resample(train.iloc[:,:-1], train.iloc[:,-1])\n",
#     494     "#         train = pd.concat([train,y],axis=1)\n",
#     495     "        \n",
#     496     "        train_X, train_y, test_X, test_y = transformations_xgboost(train, test = test, model_type = model.model_type,\n",
#     497     "                                                                   evaluation=False,\n",
#     498     "                                                                   transformation_list=model.transformation_list,\n",
#     499     "                                                                   embedding_data=model.embedding_data)\n",
#     500     "\n",
#     501     "        results_train, results_test = train_xgboost(model_int, train_X, train_y, test_X, test_y, max_val, fi)\n",
#     502     "        \n",
#     503     "        results_test['dt_prediction'] = date + datetime.timedelta(days=15)\n",
#     504     "        \n",
#     505     "        df_train = pd.concat([df_train, results_train])\n",
#     506     "        df_test = pd.concat([df_test, results_test])\n",
#     507     "        \n",
#     508     "     \n",
#     509     "    validation(df_train, df_test, model_type=model.model_type, case=case)"
#     510    ]
#     511   },
#     512   {
#     513    "cell_type": "code",
#     514    "execution_count": null,
#     515    "id": "ed0d8a7c",
#     516    "metadata": {},
#     517    "outputs": [],
#     518    "source": [
#     519     "def operational_validation(data, model, date, filepath='', date_col='dt_placement', case='', fi=False, export=False):\n",
#     520     "    \"\"\"Trains a model on data of the previous months and evaluates on data of the next month iteratively.\n",
#     521     "    \n",
#     522     "    Parameters\n",
#     523     "    --------\n",
#     524     "    data : dataframe\n",
#     525     "        A dataframe containing the data\n",
#     526     "        \n",
#     527     "    date: str\n",
#     528     "        The date to start the testing process from (format: YYYY-MM-DD)\n",
#     529     "    \n",
#     530     "    filepath : srt\n",
#     531     "        The path of the file to export results (default ='')\n",
#     532     "        \n",
#     533     "    date_col : str, optional\n",
#     534     "        The name of the date column (default = 'dt_placement')\n",
#     535     "    \n",
#     536     "    case : str, optional\n",
#     537     "        The title of case for the plot (default ='')\n",
#     538     "        \n",
#     539     "    \n",
#     540     "    export : boolean, optional\n",
#     541     "        Export a csv with the feature importance and a csv with the test data (default=False)\n",
#     542     "        \n",
#     543     "    Raise\n",
#     544     "    --------------\n",
#     545     "    ValueError\n",
#     546     "        If date > maximum date in the dataset\n",
#     547     "        \n",
#     548     "    \"\"\"\n",
#     549     "    case = case + \" operational validation\"\n",
#     550     "    \n",
#     551     "    data = data.copy()\n",
#     552     "    if (pd.to_datetime(date) > data['dt_placement'].max()):\n",
#     553     "        raise ValueError('date argument given must be before than '+ str(data['dt_placement'].max()))\n",
#     554     "        \n",
#     555     "    df_train = pd.DataFrame() \n",
#     556     "    df_test = pd.DataFrame()\n",
#     557     "    \n",
#     558     "    mosq_col = data.columns[-1]\n",
#     559     "        \n",
#     560     "    months = data.loc[data['dt_placement']>=pd.to_datetime(date),'dt_placement'].dt.to_period('M').unique()\n",
#     561     "    months = months.strftime('%Y-%m')\n",
#     562     "    months.sort()\n",
#     563     "    \n",
#     564     "    model_int = copy.deepcopy(model)\n",
#     565     "    \n",
#     566     "    for i in months:\n",
#     567     "        date1 = i +'-01'\n",
#     568     "        if i.split('-')[1]=='12':\n",
#     569     "            date2 = str(int(i.split('-')[0])+1) +'-01-01'\n",
#     570     "        else:\n",
#     571     "            date2 = i.split('-')[0] + '-' + str(int(i.split('-')[1]) + 1) + '-01'\n",
#     572     "\n",
#     573     "        train = data.loc[data[date_col] < pd.to_datetime(date1)]\n",
#     574     "        train = train.reset_index(drop=True)\n",
#     575     "        del train[date_col]\n",
#     576     "        \n",
#     577     "#         tl = TomekLinks()\n",
#     578     "#         train, y = tl.fit_resample(train.iloc[:,:-1], train.iloc[:,-1])\n",
#     579     "#         train = pd.concat([train,y],axis=1)\n",
#     580     "\n",
#     581     "        test = data.loc[data[date_col] >= pd.to_datetime(date1)]\n",
#     582     "        test = test.loc[test[date_col] < pd.to_datetime(date2)]\n",
#     583     "        test = test.reset_index(drop=True)\n",
#     584     "        date = test[date_col]\n",
#     585     "        del test[date_col]\n",
#     586     "\n",
#     587     "        max_val = train.iloc[:,-1].max()\n",
#     588     "        \n",
#     589     "        train_X, train_y, test_X, test_y = transformations_xgboost(train, test = test, model_type = model.model_type,\n",
#     590     "                                                                   evaluation=False,\n",
#     591     "                                                                   transformation_list=model.transformation_list,\n",
#     592     "                                                                   embedding_data=model.embedding_data)\n",
#     593     "\n",
#     594     "        results_train, results_test = train_xgboost(model_int, train_X, train_y, test_X, test_y, max_val, fi)\n",
#     595     "        \n",
#     596     "        test[date_col] = date\n",
#     597     "        test['dt_prediction'] = test[date_col] + datetime.timedelta(days=15)\n",
#     598     "        test['prediction'] = results_test['prediction']\n",
#     599     "        test.loc[test['prediction']<0,'prediction'] = 0\n",
#     600     "        test['error'] = test[mosq_col] - test['prediction']\n",
#     601     "        test['abs(error)'] = np.abs(test[mosq_col] - test['prediction'])\n",
#     602     "\n",
#     603     "        df_train = pd.concat([df_train,results_train])\n",
#     604     "        df_test = pd.concat([df_test,test])\n",
#     605     "             \n",
#     606     "    df_test = df_test.rename(columns={mosq_col:'actual'})\n",
#     607     "    \n",
#     608     "    years = df_test['dt_prediction'].dt.to_period('Y').unique()\n",
#     609     "    years = years.strftime('%Y')\n",
#     610     "    years.sort()\n",
#     611     "    for i in years:\n",
#     612     "        print('====================')\n",
#     613     "        print(i)\n",
#     614     "        print('====================')\n",
#     615     "        df_test_year = df_test.loc[df_test['dt_prediction'].dt.year==int(i)].reset_index(drop=True)\n",
#     616     "        validation(df_train, df_test_year, model_type=model.model_type, case=case)\n",
#     617     "    \n",
#     618     "    df_test = df_test.rename(columns={'actual':mosq_col})\n",
#     619     "    \n",
#     620     "    if export:\n",
#     621     "        csv = filepath + case + '.csv'\n",
#     622     "        df_test.to_csv(csv,index=False)"
#     623    ]
#     624   },
#     625   {
#     626    "cell_type": "code",
#     627    "execution_count": null,
#     628    "id": "bcc78069",
#     629    "metadata": {},
#     630    "outputs": [],
#     631    "source": [
#     632     "def predict(data, test, model, filepath = '', date_col = 'dt_placement',\n",
#     633     "                            case='', fi = True, export=False):\n",
#     634     "    \"\"\"Trains a model on random splitted data\n",
#     635     "    \n",
#     636     "    Parameters\n",
#     637     "    --------\n",
#     638     "    data : dataframe\n",
#     639     "        A dataframe containing the data\n",
#     640     "        \n",
#     641     "    embedding_data : dataframe, optional\n",
#     642     "        A datafrane with the categorical features (default = None)\n",
#     643     "        \n",
#     644     "    filepath : srt, optional\n",
#     645     "        The path of the file to export the results (default = '')\n",
#     646     "        \n",
#     647     "    date_col : str, optional\n",
#     648     "        The name of the date column (default = 'dt_placement')\n",
#     649     "    \n",
#     650     "    case : str, optional\n",
#     651     "        The title of case for the plot (default='')\n",
#     652     "    \n",
#     653     "    export : boolean, optional\n",
#     654     "        Export a csv with the feature importance and a csv with the test data (default = False)\n",
#     655     "    \"\"\"\n",
#     656     "    case = case + \" predict\"\n",
#     657     "    \n",
#     658     "    max_val= data.iloc[:,-1].max()\n",
#     659     "    \n",
#     660     "    del data[date_col]\n",
#     661     "    date = test[date_col]\n",
#     662     "    del test[date_col]\n",
#     663     "    \n",
#     664     "    model_int = copy.deepcopy(model)\n",
#     665     "    \n",
#     666     "#     tl = TomekLinks()\n",
#     667     "#     train, y = tl.fit_resample(train.iloc[:,:-1], train.iloc[:,-1])\n",
#     668     "#     train = pd.concat([train,y],axis=1)\n",
#     669     "    \n",
#     670     "    train_X, train_y, test_X, test_y = transformations_xgboost(data, test = test, model_type = model.model_type,\n",
#     671     "                                                               evaluation=False,\n",
#     672     "                                                               transformation_list=model.transformation_list,\n",
#     673     "                                                               embedding_data=model.embedding_data)\n",
#     674     "\n",
#     675     "    results_test = predict_xgboost(model_int, train_X, train_y, test_X, test_y, max_val, fi)\n",
#     676     "    \n",
#     677     "    test[date_col] = date\n",
#     678     "    test['dt_prediction'] = test[date_col] + datetime.timedelta(days=15)\n",
#     679     "    test['prediction'] = results_test['prediction']\n",
#     680     "    \n",
#     681     "    if export:\n",
#     682     "        csv = filepath + case + '.csv'\n",
#     683     "        test.to_csv(csv,index=False)\n",
#     684     "    return test"
#     685    ]
#     686   }
#     687  ],
#     688  "metadata": {
#     689   "kernelspec": {
#     690    "display_name": "Python 3 (ipykernel)",
#     691    "language": "python",
#     692    "name": "python3"
#     693   },
#     694   "language_info": {
#     695    "codemirror_mode": {
#     696     "name": "ipython",
#     697     "version": 3
#     698    },
#     699    "file_extension": ".py",
#     700    "mimetype": "text/x-python",
#     701    "name": "python",
#     702    "nbconvert_exporter": "python",
#     703    "pygments_lexer": "ipython3",
#     704    "version": "3.11.4"
#     705   }
#     706  },
#     707  "nbformat": 4,
#     708  "nbformat_minor": 5
#     709 }
#
# File ~\Desktop\noa\Xgboost\XGboost_Model_Module.ipynb:489, in train_xgboost(xg_model, train_X, train_y, test_X, test_y, max_val, fi)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "0d653348",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import pandas as pd\n",
#      11     "import numpy as np\n",
#      12     "import xgboost as xgb\n",
#      13     "import seaborn as sns\n",
#      14     "import matplotlib.pyplot as plt\n",
#      15     "from sklearn.feature_selection import RFECV\n",
#      16     "from sklearn.metrics import mean_absolute_error\n",
#      17     "from sklearn.model_selection import train_test_split\n",
#      18     "from sklearn.preprocessing import StandardScaler, OneHotEncoder\n",
#      19     "from sklearn.model_selection import GridSearchCV"
#      20    ]
#      21   },
#      22   {
#      23    "cell_type": "code",
#      24    "execution_count": 5,
#      25    "id": "4c1b7654",
#      26    "metadata": {},
#      27    "outputs": [],
#      28    "source": [
#      29     "def normalizeData(y, min_val=0, max_val=9):\n",
#      30     "    'Transforms the target data to 0-1 range in order to use the sigmoid function as activation'\n",
#      31     "    return pd.Series((np.array(y) - min_val) / (max_val-min_val))\n",
#      32     "\n",
#      33     "def logData(y):\n",
#      34     "    'Transforms the target variable to log(target) in order to follow a more normal disribution'\n",
#      35     "    return np.log1p(y)\n",
#      36     "\n",
#      37     "def expData(y):\n",
#      38     "    'Calculate the exponential value of the target variable'\n",
#      39     "    return np.expm1(y)\n",
#      40     "\n",
#      41     "def denormalizeData(y, min_val=0, max_val=9):\n",
#      42     "    'Transforms the data from 0-1 range to the initial 0-9 range'\n",
#      43     "    return pd.Series((np.array(y)*(max_val-min_val))+min_val)\n",
#      44     "\n",
#      45     "def sigmoid(x,a=1,b=0):\n",
#      46     "    return 1.0 / (1.0 + np.exp(a*(-x+b)))\n",
#      47     "\n",
#      48     "def parabola(x,a=1,b=0):\n",
#      49     "    return a*(x-b)**2"
#      50    ]
#      51   },
#      52   {
#      53    "cell_type": "code",
#      54    "execution_count": 3,
#      55    "id": "4844c008",
#      56    "metadata": {},
#      57    "outputs": [],
#      58    "source": [
#      59     "def transformations_xgboost(data, model_type, test=None, evaluation=False, transformation_list=['scaling'],\n",
#      60     "                    embedding_data=None):\n",
#      61     "    \"\"\"Executes scaling, augmentation or label endconding on the dataset \n",
#      62     "    \n",
#      63     "    Parameters\n",
#      64     "    ----------\n",
#      65     "    data : dataframe\n",
#      66     "        A dataframe containing all the data or the data of trainning.\n",
#      67     "        If test not given, then data will be randomnly slpit in 80-20% train and test set\n",
#      68     "        \n",
#      69     "    model_type : str\n",
#      70     "        The type of the model to be implemented.\n",
#      71     "        Could be 'class_regression' or 'mosquito_regression' or 'classification'\n",
#      72     "        \n",
#      73     "    test : dataframe, optional\n",
#      74     "        A dataframe containing all the data for testing (default = None)\n",
#      75     "        \n",
#      76     "    scaling : boolean, optional\n",
#      77     "        If True, perofrms scaling on numerical features (default = False)\n",
#      78     "        \n",
#      79     "    augment : boolean, optional\n",
#      80     "        If True, augments the train data with existing observations\n",
#      81     "        and giving greater weight on the observations with greater target value (default = False)\n",
#      82     "        \n",
#      83     "    embedding_data : dataframe, optional\n",
#      84     "        A datafrane with the categorical features (default = None)\n",
#      85     "        \n",
#      86     "    evaluation : boolean, optional\n",
#      87     "        If True, 20% of the observations of train set will be held for evaluation set (default = False)\n",
#      88     "        \n",
#      89     "    Returns\n",
#      90     "    ----------\n",
#      91     "    train_X: numpy array\n",
#      92     "        A numpy array with independent variables for training\n",
#      93     "        \n",
#      94     "    train_y: pd.Series\n",
#      95     "        A array with the dependent variables (target) for training\n",
#      96     "        \n",
#      97     "    test_X: numpy array\n",
#      98     "        A numpy array with independent variables for test\n",
#      99     "        \n",
#     100     "    test_y: pd.Series\n",
#     101     "        A array with the dependent variables (target) for test\n",
#     102     "    \n",
#     103     "    \"\"\"\n",
#     104     "\n",
#     105     "    if test is None:    \n",
#     106     "        X, y = data.iloc[:,:-1], data.iloc[:,-1]\n",
#     107     "        train_X,test_X,train_y,test_y = train_test_split(X, y, test_size=0.20, random_state=1)\n",
#     108     "    else:\n",
#     109     "        data = data.sample(frac=1,random_state=1).reset_index(drop=True)\n",
#     110     "        train_X, train_y = data.iloc[:,:-1], data.iloc[:,-1]\n",
#     111     "        test_X, test_y = test.iloc[:,:-1], test.iloc[:,-1]\n",
#     112     "        \n",
#     113     "    train_X = train_X.reset_index(drop=True)\n",
#     114     "    train_y = train_y.reset_index(drop=True)\n",
#     115     "    test_X = test_X.reset_index(drop=True)\n",
#     116     "    test_y = test_y.reset_index(drop=True)\n",
#     117     "        \n",
#     118     "    if evaluation:\n",
#     119     "        train_X,eval_X,train_y,eval_y = train_test_split(train_X, train_y, test_size=0.20, random_state=1)\n",
#     120     "        eval_X = eval_X.reset_index(drop=True)\n",
#     121     "        eval_y = eval_y.reset_index(drop=True)\n",
#     122     "        \n",
#     123     "    if model_type == 'mosquito_regression':       \n",
#     124     "        percentile = round(np.percentile(train_y, 95))\n",
#     125     "        train_y.loc[train_y >= percentile] = percentile\n",
#     126     "\n",
#     127     "    if 'augmentation' in transformation_list:\n",
#     128     "        augment_index = train_y.sample(frac=0.4, weights=train_y, random_state=1, replace=True).index\n",
#     129     "        train_X = pd.concat([train_X,train_X.iloc[augment_index,:]]).reset_index(drop=True)\n",
#     130     "        train_y = pd.concat([train_y,train_y[augment_index]]).reset_index(drop=True)\n",
#     131     "    \n",
#     132     "    if embedding_data is not None:\n",
#     133     "        embeddings = embedding_data.columns.tolist()\n",
#     134     "        \n",
#     135     "        embedded_columns_train = train_X[embeddings] #categorical columns\n",
#     136     "        train_X = train_X.drop(columns=embeddings)\n",
#     137     "\n",
#     138     "        embedded_columns_test = test_X[embeddings] #categorical columns\n",
#     139     "        test_X = test_X.drop(columns=embeddings)           \n",
#     140     "            \n",
#     141     "        encoder = OneHotEncoder(sparse=False, handle_unknown='ignore')\n",
#     142     "        encoder.fit(embedded_columns_train)\n",
#     143     "        if evaluation:\n",
#     144     "            embedded_columns_eval = eval_X[embeddings] #categorical columns\n",
#     145     "            eval_X = eval_X.drop(columns=embeddings)\n",
#     146     "            embedded_columns_eval= encoder.transform(embedded_columns_eval)\n",
#     147     "        embedded_columns_train = encoder.transform(embedded_columns_train)\n",
#     148     "        embedded_columns_test = encoder.transform(embedded_columns_test)\n",
#     149     "\n",
#     150     "        train_X_emb = pd.DataFrame(embedded_columns_train,columns=encoder.get_feature_names_out().tolist())  \n",
#     151     "        test_X_emb = pd.DataFrame(embedded_columns_test,columns=encoder.get_feature_names_out().tolist())\n",
#     152     "        if evaluation:\n",
#     153     "            eval_X_emb = pd.DataFrame(embedded_columns_eval,columns=encoder.get_feature_names_out().tolist())\n",
#     154     "            \n",
#     155     "    if 'scaling' in transformation_list:\n",
#     156     "        scaler = StandardScaler()\n",
#     157     "        cols = train_X.columns.tolist()\n",
#     158     "        train_X = scaler.fit_transform(train_X)\n",
#     159     "        train_X = pd.DataFrame(train_X, columns=cols, dtype='category')\n",
#     160     "        test_X = scaler.transform(test_X)\n",
#     161     "        test_X = pd.DataFrame(test_X, columns=cols, dtype='category')\n",
#     162     "        if evaluation:\n",
#     163     "            eval_X = scaler.transform(eval_X)\n",
#     164     "            eval_X = pd.DataFrame(eval_X, columns=cols, dtype='category')\n",
#     165     "            \n",
#     166     "    if 'normalization' in transformation_list:\n",
#     167     "        min_val = train_y.min()\n",
#     168     "        max_val = train_y.max()\n",
#     169     "        test_y = normalizeData(test_y, min_val, max_val)\n",
#     170     "        train_y = normalizeData(train_y, min_val, max_val)\n",
#     171     "        if evaluation:\n",
#     172     "            eval_y = normalizeData(eval_y, min_val, max_val)\n",
#     173     "            \n",
#     174     "    if 'log' in transformation_list:\n",
#     175     "        test_y = logData(test_y)\n",
#     176     "        train_y = logData(train_y)\n",
#     177     "        if evaluation:\n",
#     178     "            eval_y = logData(eval_y)\n",
#     179     "            \n",
#     180     "    if embedding_data is not None:\n",
#     181     "        train_X = pd.concat([train_X,train_X_emb],axis=1)\n",
#     182     "        test_X = pd.concat([test_X, test_X_emb],axis=1)\n",
#     183     "        if evaluation:\n",
#     184     "            eval_X = pd.concat([eval_X,eval_X_emb],axis=1)\n",
#     185     "            \n",
#     186     "    if evaluation:\n",
#     187     "        return train_X, train_y, eval_X, eval_y, test_X, test_y\n",
#     188     "    else:       \n",
#     189     "        return train_X, train_y, test_X, test_y"
#     190    ]
#     191   },
#     192   {
#     193    "cell_type": "code",
#     194    "execution_count": 7,
#     195    "id": "973ae936",
#     196    "metadata": {},
#     197    "outputs": [],
#     198    "source": [
#     199     "class Xgboost_model:\n",
#     200     "    def __init__(self, model_type, learning_rate=0.3,\n",
#     201     "                 embedding_data=None,  transformation_list=[],\n",
#     202     "                 early_stop = False, l1_weight=0, l2_weight=0, weights=False):\n",
#     203     "        \n",
#     204     "        self.model_type = model_type\n",
#     205     "        self.learning_rate = learning_rate\n",
#     206     "        self.embedding_data = embedding_data\n",
#     207     "        self.transformation_list = transformation_list\n",
#     208     "        self.early_stop = early_stop\n",
#     209     "        self.weights = weights\n",
#     210     "        self.estimators = None\n",
#     211     "        self.depth = None\n",
#     212     "        self.l1_weight = l1_weight\n",
#     213     "        self.l2_weight = l2_weight\n",
#     214     "        self.features = None\n",
#     215     "    \n",
#     216     "        if self.model_type == 'classification':\n",
#     217     "            self.model = xgb.XGBClassifier()\n",
#     218     "        else:\n",
#     219     "            self.model = xgb.XGBRegressor()\n",
#     220     "            \n",
#     221     "        xgb_params = {'learning_rate': self.learning_rate,\n",
#     222     "                      'random_state':1,\n",
#     223     "                      'lambda':self.l2_weight,\n",
#     224     "                      'alpha':self.l1_weight}\n",
#     225     "        self.model.set_params(**xgb_params)\n",
#     226     "        \n",
#     227     "    def tune_parameters(self, train_X, train_y, weights=None, flag = False):\n",
#     228     "        \"\"\"Returns the depth and the number of estimators with the minimum MAE\n",
#     229     "\n",
#     230     "        Parameters\n",
#     231     "        ----------\n",
#     232     "        data : Dataframe\n",
#     233     "            A Daframe containing the data\n",
#     234     "\n",
#     235     "        flag : boolean, otional\n",
#     236     "            If true plots are printed (default=False)\n",
#     237     "\n",
#     238     "        transform : boolean, optional\n",
#     239     "            If True, performs log transformation of the target variable (default = False)\n",
#     240     "\n",
#     241     "        Returns\n",
#     242     "        ----------\n",
#     243     "        depth : int\n",
#     244     "            The max depth of the trees to construct\n",
#     245     "\n",
#     246     "        est : int\n",
#     247     "            The number of trees to construct\n",
#     248     "\n",
#     249     "        \"\"\"\n",
#     250     "        \n",
#     251     "        \n",
#     252     "#         if weights is None:\n",
#     253     "#             train_X, val_X, train_y, val_y = train_test_split(train_X, train_y, test_size=0.20, random_state=1)\n",
#     254     "#         else:\n",
#     255     "#             train_X, val_X, train_y, val_y, weights, val_weights = train_test_split(train_X, train_y, weights,\n",
#     256     "#                                                                                     test_size=0.20, random_state=1)\n",
#     257     "        \n",
#     258     "#         tr_depth = []\n",
#     259     "#         val_depth = []\n",
#     260     "#         tr_est = []\n",
#     261     "#         val_est = []\n",
#     262     "\n",
#     263     "#         for i in range(1,11):\n",
#     264     "#             xgb_params = {'n_estimators': 5,\n",
#     265     "#                           'max_depth': i}\n",
#     266     "#             self.model.set_params(**xgb_params)\n",
#     267     "#             self.model.fit(train_X, train_y, sample_weight = weights)               \n",
#     268     "#             predictions_train = self.model.predict(train_X)\n",
# ...
#     366     "            However it highly increases time complexity (default=False)\n",
#     367     "            \n",
#     368     "\n",
#     369     "        Returns\n",
#     370     "        --------\n",
#     371     "        selected_features : lst\n",
#     372     "            A list containing the features selected\n",
#     373     "\n",
#     374     "        depth : int\n",
#     375     "            The depth of the trees to construct\n",
#     376     "\n",
#     377     "        estimators : int\n",
# --> 378     "            The number of trees to constuct\n",
#     379     "        \"\"\"   \n",
#     380     "        if grid:\n",
#     381     "            r2=-1\n",
#     382     "            final = None\n",
#     383     "            dep=0\n",
#     384     "            est = 0\n",
#     385     "            for i in range(self.depth-2,self.depth+3):\n",
#     386     "                for j in range(self.estimators-2,self.estimators+3):\n",
#     387     "                    xgb_params = {'n_estimators': i,\n",
#     388     "                                  'max_depth': j}\n",
#     389     "                    self.model.set_params(**xgb_params)\n",
#     390     "                    rfe = RFECV(self.model, step=1, cv=10, scoring = 'neg_mean_absolute_error')\n",
#     391     "                    X_train_rfe = rfe.fit_transform(train_X, train_y)\n",
#     392     "                    if rfe.score(X_train, y_train) > r2:\n",
#     393     "                        final = rfe\n",
#     394     "                        dep = i\n",
#     395     "                        est = j\n",
#     396     "                        r2 = rfe.score(X_train, y_train)\n",
#     397     "            rfe = final\n",
#     398     "            self.depth = dep\n",
#     399     "            self.estimators = est\n",
#     400     "        else:\n",
#     401     "            xgb_params = {'n_estimators': self.estimators,\n",
#     402     "                          'max_depth': self.depth}\n",
#     403     "            self.model.set_params(**xgb_params)\n",
#     404     "#             fit_params = {'sample_weight': weights}\n",
#     405     "            rfe = RFECV(self.model, step=1, cv=10, scoring = 'neg_mean_absolute_error')\n",
#     406     "            X_train_rfe = rfe.fit_transform(train_X, train_y, **{'sample_weight':weights})\n",
#     407     "\n",
#     408     "        #print the features selected\n",
#     409     "        cols = list(train_X.columns) \n",
#     410     "        temp = pd.Series(rfe.support_, index = cols)\n",
#     411     "        self.features = temp[temp==True].index\n",
#     412     "\n",
#     413     "        plt.figure()\n",
#     414     "        plt.xlabel(\"Number of features selected\")\n",
#     415     "        plt.ylabel(\"neg mean squared error\")\n",
#     416     "        plt.plot(range(1,len(rfe.cv_results_['mean_test_score']) + 1), rfe.cv_results_['mean_test_score'])\n",
#     417     "        plt.vlines(x = np.argmax(rfe.cv_results_['mean_test_score'])+1,\n",
#     418     "                   ls='--', ymin = np.min(rfe.cv_results_['mean_test_score']),\n",
#     419     "                   ymax = np.max(rfe.cv_results_['mean_test_score']), colors = 'grey',\n",
#     420     "                   label = 'x = '+str(np.argmax(rfe.cv_results_['mean_test_score'])+1))\n",
#     421     "        plt.grid()\n",
#     422     "        plt.legend()\n",
#     423     "        plt.show()\n",
#     424     "\n",
#     425     "        print('max_depth: ', self.depth)\n",
#     426     "        print('Number of estimators: ', self.estimators)\n",
#     427     "        print('Selected_features: ', self.features)\n",
#     428     "\n",
#     429     "        return self.features, self.depth, self.estimators\n",
#     430     "    \n",
#     431     "    def plot_feature_importance(self):\n",
#     432     "        \"\"\"Prints the plot of feature importance of the model and creates a .csv file with the frature importance\n",
#     433     "\n",
#     434     "        Parameters\n",
#     435     "        ----------\n",
#     436     "        importance : list\n",
#     437     "            A list containing the importnce of each feature\n",
#     438     "\n",
#     439     "        names : list\n",
#     440     "            A list containing the names of the features\n",
#     441     "\n",
#     442     "        filepath : srt\n",
#     443     "            The path of the file to export a csv with the importance of the featured\n",
#     444     "\n",
#     445     "        case: str, optional\n",
#     446     "            Title of the plot (Area and mosquito genus) (default= '')\n",
#     447     "\n",
#     448     "        export: boolean, optional\n",
#     449     "            Exports a csv with the importance of each figure (default = False)\n",
#     450     "        \"\"\"\n",
#     451     "        #Create arrays from feature importance and feature names\n",
#     452     "        feature_importance = np.array(self.model.feature_importances_)\n",
#     453     "        feature_names = np.array(self.features)\n",
#     454     "\n",
#     455     "        #Create a DataFrame using a Dictionary\n",
#     456     "        data={'feature_names':feature_names,'feature_importance':feature_importance}\n",
#     457     "        fi_df = pd.DataFrame(data)\n",
#     458     "\n",
#     459     "        #Sort the DataFrame in order decreasing feature importance\n",
#     460     "        fi_df.sort_values(by=['feature_importance'], ascending=False,inplace=True)\n",
#     461     "\n",
#     462     "        #Define size of bar plot\n",
#     463     "        plt.figure(figsize=(10,8))\n",
#     464     "\n",
#     465     "        #Plot Searborn bar chart\n",
#     466     "        sns.barplot(x=fi_df['feature_importance'], y=fi_df['feature_names'])\n",
#     467     "\n",
#     468     "        #Add chart labels\n",
#     469     "        plt.xlabel('Feature Importance')\n",
#     470     "        plt.ylabel('Feature Names')\n",
#     471     "        plt.show()"
#     472    ]
#     473   },
#     474   {
#     475    "cell_type": "code",
#     476    "execution_count": 12,
#     477    "id": "006cad2f",
#     478    "metadata": {},
#     479    "outputs": [],
#     480    "source": [
#     481     "def train_xgboost(xg_model, train_X, train_y, test_X, test_y, max_val, fi=True):\n",
#     482     "    \"\"\" Trainning of the model\n",
#     483     "    \n",
#     484     "    Parameters\n",
#     485     "    ----------\n",
#     486     "    model : FeedforwardNeuralNetModel\n",
#     487     "        A FeedforwardNeuralNetModel model\n",
#     488     "        \n",
#     489     "    train_set : Dataset\n",
#     490     "        A Dataset object with the train set\n",
#     491     "        \n",
#     492     "    test_set : Dataset\n",
#     493     "        A Dataset object with the test set\n",
#     494     "        \n",
#     495     "    learning_rate : int, optional\n",
#     496     "        The learning_rate of the training process. (default = None)\n",
#     497     "        \n",
#     498     "    epochs : int, optional\n",
#     499     "        The number of epochs for the training. (default = None)\n",
#     500     "        \n",
#     501     "    batch_size : int, optional\n",
#     502     "        The size of each batch in each iteration. (default = None)\n",
#     503     "        \n",
#     504     "    ealry_stop : tuple, optional\n",
#     505     "        Set the (tolerance,min_dleta), the trainning of the model may stop earlier than the epochs defined. (default = None)\n",
#     506     "        \n",
#     507     "    Returns\n",
#     508     "    ----------\n",
#     509     "    results_train: DataFrame\n",
#     510     "        A Dataframe containing the actual and the predicted values on the train set\n",
#     511     "        \n",
#     512     "    results_test: DataFrame\n",
#     513     "        A Dataframe containing the actual and the predicted values on the test set\n",
#     514     "        \n",
#     515     "    model : FeedforwardNeuralNetModel\n",
#     516     "        A trained FeedforwardNeuralNetModel model \n",
#     517     "    \"\"\"\n",
#     518     "    weights=None\n",
#     519     "    if xg_model.weights:\n",
#     520     "        b_val = train_y.mean().item()\n",
#     521     "        weights = [parabola(train_y[i], a=1, b=b_val) for i in range(int(train_X.shape[0]))]\n",
#     522     "    \n",
#     523     "    if xg_model.features is None:\n",
#     524     "        xg_model.tune_parameters(train_X, train_y, flag=True, weights=weights)\n",
#     525     "        xg_model.select_features(train_X, train_y, grid=False, weights=weights)\n",
#     526     "    \n",
#     527     "    train_X = train_X[xg_model.features]\n",
#     528     "    test_X = test_X[xg_model.features]\n",
#     529     "\n",
#     530     "    xgb_params = {'n_estimators': xg_model.estimators,\n",
#     531     "                  'max_depth': xg_model.depth}\n",
#     532     "    xg_model.model.set_params(**xgb_params)\n",
#     533     "#     eval_set = [(test_X, test_y)]\n",
#     534     "    xg_model.model.fit(train_X, train_y, sample_weight = weights)\n",
#     535     "#                        ,early_stopping_rounds=10, eval_metric=\"mae\", eval_set=eval_set)    \n",
#     536     "    predictions = xg_model.model.predict(test_X)\n",
#     537     "    predictions_train = xg_model.model.predict(train_X)\n",
#     538     "    \n",
#     539     "    if 'normalization' in xg_model.transformation_list:\n",
#     540     "        predictions = denormalizeData(predictions, max_val=max_val)\n",
#     541     "        predictions_train = denormalizeData(predictions_train, max_val=max_val)\n",
#     542     "        train_y = denormalizeData(train_y, max_val=max_val)\n",
#     543     "        test_y = denormalizeData(test_y, max_val=max_val)\n",
#     544     "        \n",
#     545     "    if 'log' in xg_model.transformation_list:\n",
#     546     "        predictions = expData(predictions)\n",
#     547     "        predictions_train = expData(predictions_train)\n",
#     548     "        train_y = expData(train_y)\n",
#     549     "        test_y = expData(test_y)\n",
#     550     "        \n",
#     551     "    predictions =  np.round(predictions)  \n",
#     552     "    predictions_train = np.round(predictions_train)\n",
#     553     "        \n",
#     554     "    results_train = {'actual': train_y, 'prediction': predictions_train}\n",
#     555     "    results_train = pd.DataFrame.from_dict(results_train)\n",
#     556     "    \n",
#     557     "    results_test = {'actual': test_y, 'prediction': predictions}\n",
#     558     "    results_test = pd.DataFrame.from_dict(results_test)\n",
#     559     "    \n",
#     560     "    results_test.loc[results_test['prediction'] < 0,'prediction'] = 0\n",
#     561     "    results_test.loc[results_test['prediction'] > max_val,'prediction'] = max_val\n",
#     562     "    results_train.loc[results_train['prediction'] < 0,'prediction'] = 0\n",
#     563     "    results_train.loc[results_train['prediction'] > max_val,'prediction'] = max_val\n",
#     564     "    \n",
#     565     "    if fi:\n",
#     566     "        xg_model.plot_feature_importance()\n",
#     567     "    \n",
#     568     "    return results_train, results_test"
#     569    ]
#     570   },
#     571   {
#     572    "cell_type": "code",
#     573    "execution_count": null,
#     574    "id": "cb9d6320",
#     575    "metadata": {},
#     576    "outputs": [],
#     577    "source": [
#     578     "def predict_xgboost(xg_model, train_X, train_y, test_X, test_y, max_val, fi=True):\n",
#     579     "    \"\"\" Trainning of the model\n",
#     580     "    \n",
#     581     "    Parameters\n",
#     582     "    ----------\n",
#     583     "    model : FeedforwardNeuralNetModel\n",
#     584     "        A FeedforwardNeuralNetModel model\n",
#     585     "        \n",
#     586     "    Returns\n",
#     587     "    ----------\n",
#     588     "    results_train: DataFrame\n",
#     589     "        A Dataframe containing the actual and the predicted values on the train set\n",
#     590     "        \n",
#     591     "    results_test: DataFrame\n",
#     592     "        A Dataframe containing the actual and the predicted values on the test set\n",
#     593     "        \n",
#     594     "    model : FeedforwardNeuralNetModel\n",
#     595     "        A trained FeedforwardNeuralNetModel model \n",
#     596     "    \"\"\"\n",
#     597     "    \n",
#     598     "    weights=None\n",
#     599     "    if xg_model.weights:\n",
#     600     "        b_val = train_y.mean().item()\n",
#     601     "        weights = [parabola(train_y[i], 1, b=b_val) for i in range(int(train_X.shape[0]))]\n",
#     602     "        \n",
#     603     "    if xg_model.features is None:\n",
#     604     "        xg_model.tune_parameters(train_X, train_y, flag=True)\n",
#     605     "        xg_model.select_features(train_X, train_y, grid=False)\n",
#     606     "    \n",
#     607     "    train_X = train_X[xg_model.features]\n",
#     608     "    test_X = test_X[xg_model.features]\n",
#     609     "\n",
#     610     "    xg_model.model.fit(train_X, train_y, sample_weight = weights)\n",
#     611     "    predictions = xg_model.model.predict(test_X)\n",
#     612     "    \n",
#     613     "    if 'normalization' in xg_model.transformation_list:\n",
#     614     "        predictions = denormalizeData(predictions, max_val=max_val)\n",
#     615     "\n",
#     616     "    if 'log' in xg_model.transformation_list:\n",
#     617     "        predictions = expData(predictions)\n",
#     618     "\n",
#     619     "    predictions =  np.round(predictions)  \n",
#     620     "\n",
#     621     "    results_test = {'prediction': predictions}\n",
#     622     "    results_test = pd.DataFrame.from_dict(results_test)\n",
#     623     "    \n",
#     624     "    results_test.loc[results_test['prediction'] < 0,'prediction'] = 0\n",
#     625     "    results_test.loc[results_test['prediction'] > max_val,'prediction'] = max_val\n",
#     626     "    \n",
#     627     "    if fi:\n",
#     628     "        xg_model.plot_feature_importance()\n",
#     629     "   \n",
#     630     "    return results_test"
#     631    ]
#     632   }
#     633  ],
#     634  "metadata": {
#     635   "kernelspec": {
#     636    "display_name": "Python 3 (ipykernel)",
#     637    "language": "python",
#     638    "name": "python3"
#     639   },
#     640   "language_info": {
#     641    "codemirror_mode": {
#     642     "name": "ipython",
#     643     "version": 3
#     644    },
#     645    "file_extension": ".py",
#     646    "mimetype": "text/x-python",
#     647    "name": "python",
#     648    "nbconvert_exporter": "python",
#     649    "pygments_lexer": "ipython3",
#     650    "version": "3.11.4"
#     651   }
#     652  },
#     653  "nbformat": 4,
#     654  "nbformat_minor": 5
#     655 }
#
# File ~\anaconda3\envs\noa3\Lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File ~\anaconda3\envs\noa3\Lib\site-packages\sklearn\base.py:918, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     915     return self.fit(X, **fit_params).transform(X)
#     916 else:
#     917     # fit method of arity 2 (supervised transformation)
# --> 918     return self.fit(X, y, **fit_params).transform(X)
#
# File ~\anaconda3\envs\noa3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# TypeError: RFECV.fit() got an unexpected keyword argument 'sample_weight'

# %%
train_model_KFold(data, model, date_col=date_col)
# Out:
# max_depth:  5
# Number of estimators:  29
# Selected_features:  Index(['y', 'lst_mar_day_mean', 'lst_mar_night_mean', 'lst_apr_night_mean',
#        'SLOPE_mean_1km', 'ELEVATION_mean_1km', 'HILLSHADE_mean_1km',
#        'FS_AREA_1km', 'landcover', 'null_island_distance', 'days_distance',
#        'year'],
#       dtype='object')
# MAE on train set:  1.1763460939931527
# min prediction: -0.0
# max prediction: 9.0
#
# MAE on test set:  1.5798319327731092
# Error <= 3: 91.09 %
# min prediction: 0.0
# max prediction: 8.0
# -----------|class error-MAE| difference-----------
# mean: 0.5598875381107659
# std: 0.3557017639285494
# coefficient of variation (std/mean): 0.6353093071669311
#
# ----------normalized difference-------------
# mean: 0.5526094979617205
# std: 0.3510779572839263
# coefficient of variation (std/mean): 0.6353093071669311

# %%
operational_validation(data, model, filepath = path, date_col = date_col,
                       date = '2021-01-01', case = case_title, export= exp)
# Out:
# max_depth:  7
# Number of estimators:  20
# Selected_features:  Index(['x', 'y', 'lst_mar_night_mean', 'lst_apr_night_mean', 'SLOPE_mean_1km',
#        'HILLSHADE_mean_1km', 'null_island_distance', 'days_distance', 'year'],
#       dtype='object')
# ====================
# 2022
# ====================
# MAE on train set:  0.987220447284345
# min prediction: 0.0
# max prediction: 9.0
#
# MAE on test set:  2.0277777777777777
# Error <= 3: 80.56 %
# min prediction: 0.0
# max prediction: 8.0
# -----------|class error-MAE| difference-----------
# mean: 3.3033474103112384
# std: 1.5000646834513176
# coefficient of variation (std/mean): 0.4541044271543885
#
# ----------normalized difference-------------
# mean: 0.7201610467977105
# std: 0.32702831961497913
# coefficient of variation (std/mean): 0.45410442715438853

# %% [markdown]
# operational validation:
# stable features:
#     MAE on train set:  0.9257568842233379
#     MAE on test set:  1.9305555555555556
#     Error <= 3: 84.38 %
# All features:
#     MAE on train set:  0.8384299406663623
#     MAE on test set:  1.8993055555555556
#     Error <= 3: 86.81 %
# different fatures:
#     MAE on train set:  0.3506770120188650
#     MAE on test set:  2.0208333333333335
#     Error <= 3: 82.99 %
