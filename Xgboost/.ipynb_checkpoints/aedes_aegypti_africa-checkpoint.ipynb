# %%
from ipynb.fs.defs.Preprocessing_Module import read_data, add_topological, select_columns, reshape_dataset, calculate_diff, cdf_plot
from ipynb.fs.defs.Feature_Expansion_Module import feature_expansion
from ipynb.fs.defs.Initializer_Module import initializer
from ipynb.fs.defs.Hyperparameters_Module import parameters
from ipynb.fs.defs.Feature_Selection_Module import select_features
from ipynb.fs.defs.Model_Validation_Module import test_model_random_split, train_model_KFold, operational_validation, validation_with_flag
import numpy as np
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')
np.set_printoptions(suppress=True)

# %%
data = read_data('../africa/all_aedes.csv')
columns = ['station_id', 'dt_placement',
           'total', 'ndvi', 'ndwi', 'ndmi', 'ndbi',
           'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean',
           'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day', 'lst_night','lst_jan_day_mean',
           'lst_feb_day_mean','lst_mar_day_mean','lst_apr_day_mean','acc_rainfall_1week', 'acc_rainfall_2week',
           'acc_rainfall_jan', 'x', 'y']
names = ['station_id', 'dt_placement',
         'mosq_now', 'ndvi', 'ndwi', 'ndmi', 'ndbi',
         'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean',
         'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day', 'lst_night', 'lst_jan_mean',
         'lst_feb_mean','lst_mar_mean','lst_apr_mean','acc_rainfall_1week', 'acc_rainfall_2week',
         'acc_rainfall_jan', 'x', 'y']
# data = add_topological(data,'../Datasets/Topological Datasets/Culex_Italy.csv')
data = select_columns(data,columns,names)
data = reshape_dataset(data,['station_id','dt_placement','mosq_now'],[True, True, False],['station_id','dt_placement'])
data = data.reset_index(drop=True)
time = calculate_diff(data,id_column='station_id',date_column='dt_placement')
# #=====================removal of stations with only zero mosquitoes=====================================
# st = np.unique(data['station_id'])
# c = []
# for x in st:
#     v = data.loc[data['station_id']== x]['mosq_now']
#     if len(np.unique(v)) == 1:
#         c.append(x)
# data = data[~data.station_id.isin(c)]
# data = data.reset_index(drop=True)
# Out:
# Index(['id', 'dt_placement', 'week', 'month', 'year', 'method',
#        'health district', 'site', 'longitude', 'latitude', 'x', 'altitude',
#        'genus', 'total', 'country_code', 'nuts0_code', 'nuts0_name',
#        'nuts1_code', 'nuts1_name', 'nuts2_code', 'nuts2_name', 'nuts3_code',
#        'nuts3_name', 'lau1_municipality', 'lau2_settlement', 'ndbi', 'ndmi',
#        'ndvi', 'ndwi', 'ndi_mission', 'ndi_acquisition', 'ndi_dates_diff',
#        'ndbi_std', 'ndmi_std', 'ndvi_std', 'ndwi_std', 'ndbi_mean',
#        'ndmi_mean', 'ndvi_mean', 'ndwi_mean', 'ndi_measures_mission',
#        'ndi_measures_acquisition', 'ndi_measures_dates_diff', 'lst_day',
#        'lst_day_mission', 'lst_day_acquisition', 'lst_day_diff', 'lst_night',
#        'lst_night_mission', 'lst_night_acquisition', 'lst_night_diff',
#        'lst_jan_day_mean', 'lst_feb_day_mean', 'lst_mar_day_mean',
#        'lst_apr_day_mean', 'lst_jan_night_mean', 'lst_feb_night_mean',
#        'lst_mar_night_mean', 'lst_apr_night_mean', 'acc_rainfall_1week',
#        'acc_rainfall_2week', 'acc_rainfall_jan', 'sp_cnt_1km', 'biol_cnt_1km',
#        'wc_l_1km', 'pg_area_1km', 'fs_area_1km', 'wc_mean_dist_1km',
#        'coast_mean_dist_1km', 'dem_mean_1km', 'slope_mean_1km',
#        'aspect_mean_1km', 'waw_mean_1km', 'flow_accu_1km', 'point', 'day',
#        'total_aedes_aegypti', 'methods', 'sampling point', 'ecozone',
#        'aedesspecies', 'aedesfemale', 'aedesmale', 'y', 'station_id'],
#       dtype='object')
# Length:  1821

# %%
step = cdf_plot(time[:1200], len(time))

# %%
step
# Out:
# 89.0

# %%
# set the number of days for the prediction based on the plot above
# step = 90
# set the only_env as True if you want to use only environmental features
only_env = False
# set the case title
case_title = 'Aedes Trentino'
# set the exp as True if you want to save the results as csv
exp = False
# set the filepath to export the data
path = '../Resuts/Aedes Africa/'
# set the name of the station ID column
station_col = 'station_id'
# set the name of the date column
date_col = 'dt_placement'

# %%
data = feature_expansion(data, imput_list=[date_col,station_col], env=only_env)

# %%
data
# Out:
#       station_id dt_placement  mosq_now      ndvi      ndwi      ndmi  \
# 0              0   2019-11-16         2 -0.007407 -0.008602 -0.130274
# 1              0   2020-02-12         0  0.008150 -0.030864 -0.200766
# 2              0   2020-06-25         0 -0.003545  0.014414 -0.086313
# 3              0   2020-09-16         1 -0.018100  0.001139 -0.090563
# 4              1   2019-11-16         1 -0.007407 -0.008602 -0.130274
# ...          ...          ...       ...       ...       ...       ...
# 2600         379   2013-04-05        14  0.061877 -0.213616 -0.124434
# 2601         379   2013-07-06        17  0.148072 -0.127282  0.014545
# 2602         379   2013-10-05         0       NaN       NaN       NaN
# 2603         379   2014-01-07         0  0.129640 -0.127777 -0.013167
# 2604         379   2014-04-05        15  0.099051 -0.079326  0.011778
#
#           ndbi  ndvi_mean  ndvi_std  ndwi_mean  ...         y  distance  \
# 0     0.130274  -0.096513  0.000000   0.074441  ... -4.002558  0.000000
# 1     0.200766   0.017221  0.034923  -0.033360  ... -4.002558  0.000000
# 2     0.086313   0.019320  0.018062  -0.038492  ... -4.002558  0.000000
# 3     0.090563  -0.017063  0.002494   0.003479  ... -4.002558  0.000000
# 4     0.130274  -0.096513  0.000000   0.074441  ... -4.002063  0.000700
# ...        ...        ...       ...        ...  ...       ...       ...
# 2600  0.124434   0.081023  0.033085  -0.142947  ... -4.014250  0.016535
# 2601 -0.014545   0.129920  0.053107  -0.085507  ... -4.014250  0.016535
# 2602       NaN        NaN       NaN        NaN  ... -4.014250  0.016535
# 2603  0.013167   0.085557  0.066397  -0.032561  ... -4.014250  0.016535
# 2604 -0.011778   0.125522  0.038442  -0.104388  ... -4.014250  0.016535
#
#       days_distance    lst  summer_days_year  summer_days_month        mo_sin  \
# 0              -320  27.13                 0                  0 -5.000000e-01
# 1               -42  29.02                 0                  0  8.660254e-01
# 2              -176    NaN                 0                  0  1.224647e-16
# 3              -259    NaN                 0                  0 -1.000000e+00
# 4              -320  27.13                 0                  0 -5.000000e-01
# ...             ...    ...               ...                ...           ...
# 2600            -95  28.88                 0                  0  8.660254e-01
# 2601           -187    NaN                 0                  0 -5.000000e-01
# 2602           -278    NaN                 0                  0 -8.660254e-01
# 2603             -6  28.16                 0                  0  5.000000e-01
# 2604            -95  29.30                 0                  0  8.660254e-01
#
#             mo_cos  mosq_month_sum  mosq_month_previousYear
# 0     8.660254e-01             2.0                 0.000000
# 1     5.000000e-01             0.0                 7.355055
# 2    -1.000000e+00             0.0                 0.000000
# 3    -1.836970e-16             1.0                 0.000000
# 4     8.660254e-01             1.0                 0.000000
# ...            ...             ...                      ...
# 2600 -5.000000e-01            14.0                19.189308
# 2601 -8.660254e-01            17.0                 0.000000
# 2602  5.000000e-01             0.0                 9.681186
# 2603  8.660254e-01             0.0                 6.411467
# 2604 -5.000000e-01            15.0                14.000000
#
# [2605 rows x 35 columns]

# %%
data = initializer(data,[-1,   1., 2.,  3., 5., 8.,  11., 14., 23., 40., np.inf],10,100,step,[station_col], env=only_env,
                   station_column = station_col, date_column = date_col)
# Out:
# Bounds: [-1.  1.  2.  3.  5.  8. 11. 14. 23. 40. inf]

# %%
data
# Out:
#    dt_placement  mosq_now      ndvi      ndwi      ndmi      ndbi  ndvi_mean  \
# 0    2019-11-21        13  0.132013 -0.151007 -0.111974  0.111974   0.257245
# 0    2019-11-21        19  0.132013 -0.151007 -0.111974  0.111974   0.257245
# 0    2019-11-21         6  0.132013 -0.151007 -0.111974  0.111974   0.257245
# 0    2019-11-21        11  0.132013 -0.151007 -0.111974  0.111974   0.257245
# 0    2019-11-21         9  0.132013 -0.151007 -0.111974  0.111974   0.257245
# ..          ...       ...       ...       ...       ...       ...        ...
# 1    2013-04-05        11  0.061877 -0.213616 -0.124434  0.124434   0.081023
# 0    2013-01-07        12  0.105664 -0.146360 -0.061923  0.061923   0.048805
# 0    2013-01-07        15  0.105664 -0.146360 -0.061923  0.061923   0.048805
# 0    2013-04-05         9  0.061877 -0.213616 -0.124434  0.124434   0.081023
# 0    2013-04-05        14  0.061877 -0.213616 -0.124434  0.124434   0.081023
#
#     ndvi_std  ndwi_mean  ndwi_std  ...  days_distance    lst  \
# 0   0.135220  -0.243979  0.097816  ...           -325  27.92
# 0   0.135220  -0.243979  0.097816  ...           -325  27.92
# 0   0.135220  -0.243979  0.097816  ...           -325  27.92
# 0   0.135220  -0.243979  0.097816  ...           -325  27.92
# 0   0.135220  -0.243979  0.097816  ...           -325  27.92
# ..       ...        ...       ...  ...            ...    ...
# 1   0.033085  -0.142947  0.078968  ...            -95  28.88
# 0   0.043247  -0.000862  0.161631  ...             -6  27.64
# 0   0.043247  -0.000862  0.161631  ...             -6  27.64
# 0   0.033085  -0.142947  0.078968  ...            -95  28.88
# 0   0.033085  -0.142947  0.078968  ...            -95  28.88
#
#     summer_days_year  summer_days_month    mo_sin    mo_cos  mosq_month_sum  \
# 0                  0                  0 -0.500000  0.866025            13.0
# 0                  0                  0 -0.500000  0.866025            19.0
# 0                  0                  0 -0.500000  0.866025             6.0
# 0                  0                  0 -0.500000  0.866025            11.0
# 0                  0                  0 -0.500000  0.866025             9.0
# ..               ...                ...       ...       ...             ...
# 1                  0                  0  0.866025 -0.500000            11.0
# 0                  0                  0  0.500000  0.866025            12.0
# 0                  0                  0  0.500000  0.866025            15.0
# 0                  0                  0  0.866025 -0.500000             9.0
# 0                  0                  0  0.866025 -0.500000            14.0
#
#     mosq_month_previousYear  mosq_bins  mosq_bins(t+1)
# 0                  0.000000          6             0.0
# 0                  0.000000          7             0.0
# 0                  0.000000          4             2.0
# 0                  0.000000          5             4.0
# 0                  0.000000          5             2.0
# ..                      ...        ...             ...
# 1                 19.111288          5             4.0
# 0                  7.807877          6             0.0
# 0                  7.885899          7             0.0
# 0                 19.059271          5             7.0
# 0                 19.189308          6             7.0
#
# [285 rows x 36 columns]

# %%
data['mosq_bins'].value_counts()
# Out:
# 0    156
# 7     45
# 5     28
# 4     14
# 3     12
# 6     11
# 2      7
# 1      6
# 8      6
# Name: mosq_bins, dtype: int64

# %%
depth, est = parameters(data,num=10,flag=True, date_col=date_col)

# %%
selected_features, depth, est = select_features(data,depth,est,grid=False, date_col=date_col)

# %%
print('max_depth: ', depth)
print('Number of estimators: ', est)
print('Selected_features: ', selected_features)
# Out:
# max_depth:  2
# Number of estimators:  5
# Selected_features:  Index(['mosq_month_previousYear'], dtype='object')

# %%
test_model_random_split(data, selected_features, depth, est, step, case=case_title, filepath = path,
                        date_col = date_col, export= exp)
# Out:
# MAE on train set:  2.1666666666666665
# MAE on test set:  2.2982456140350878
# % of error < 3:  0.8596491228070176

# %%
train_model_KFold(data,selected_features, depth, est, date_col=date_col)
# Out:
# Average MAE on train set:  2.2269531249999996
# Average MAE on test set:  2.310098522167488
# Average % of error < 3:  0.8346059113300492

# %%
operational_validation(data, selected_features, depth, est, step, date='2021-01-01', filepath = path, date_col = date_col,
                       case = case_title, export= exp)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-39bf7dd9e6fe> in <module>
# ----> 1 operational_validation(data, selected_features, depth, est, step, date='2021-01-01', filepath = path, date_col = date_col,
#       2                        case = case_title, export= exp)
#
# ~/Desktop/noa/xgboost/Model_Validation_Module.ipynb in operational_validation(data, features, depth, estimators, step, date, filepath, date_col, case, export)
#     393     "        pca = PCA(n_components=3)\n",
#     394     "        train_X1 = pca.fit_transform(train_X)\n",
# --> 395     "        train_X1 = pd.DataFrame(train_X1)\n",
#     396     "        train_X1.columns = ['PCA_1', 'PCA_2', 'PCA_3']\n",
#     397     "        train_X = pd.concat([train_X,train_X1],axis=1)\n",
#
# ValueError: date argument given must be smaller than 2019-11-21 00:00:00
