# %%
import pandas as pd

# %%
df = pd.read_csv('Culex_France_2025_06.csv')

# %%
df['prediction'] = df['prediction'].astype(int)

# %%
df
# Out:
#      dt_placement dt_prediction  week         x          y  prediction  \
# 0      2025-06-02    2025-06-17    25  1.871624  43.268754           3
# 1      2025-06-02    2025-06-17    25  4.018249  44.043779           1
# 2      2025-06-02    2025-06-17    25  4.018249  44.025813           2
# 3      2025-06-02    2025-06-17    25  4.018249  44.007846           1
# 4      2025-06-02    2025-06-17    25  4.018249  43.989879           3
# ...           ...           ...   ...       ...        ...         ...
# 5562   2025-06-02    2025-06-17    25  2.948748  42.540060           4
# 5563   2025-06-02    2025-06-17    25  2.948748  42.522093           1
# 5564   2025-06-02    2025-06-17    25  2.948748  42.504126           0
# 5565   2025-06-02    2025-06-17    25  2.948748  42.647860           3
# 5566   2025-06-02    2025-06-17    25  5.769103  43.399910           3
#
#       entomological_features
# 0                      False
# 1                      False
# 2                      False
# 3                      False
# 4                      False
# ...                      ...
# 5562                   False
# 5563                   False
# 5564                   False
# 5565                   False
# 5566                   False
#
# [5567 rows x 7 columns]

# %%
count_low = df['prediction'].between(0, 1).sum()
count_low
# Out:
# 1202

# %%
count_mid = df['prediction'].between(2, 5).sum()
count_mid
# Out:
# 4170

# %%
count_high = df['prediction'].between(6, 9).sum()
count_high
# Out:
# 195
