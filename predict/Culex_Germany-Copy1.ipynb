# %%
from Preprocessing_Module import read_data, add_topological, add_landcover, merge_new_data, fill_data, select_columns, reshape_dataset, fillna_dataset, remove_nan_features, unused_stations
from Feature_Expansion_Module import feature_expansion
from Initializer_Module import initializer
from XGboost_Model_Module import Xgboost_model
from Neural_Network_Module import FeedforwardNeuralNetModel
from Model_Validation_Module import give_predictions_nn, evaluate_nn, give_predictions_xgboost, evaluate_xgboost, validate_results, merge_predictions
import numpy as np
import pandas as pd
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
import warnings
warnings.filterwarnings('ignore')
np.set_printoptions(suppress=True)

# %%
data = read_data('../Datasets/Germany/GER_wuerttemberg_culex_2010_2023.csv')
data = merge_new_data('../Datasets/Germany/monthly_data/GER_culex_ento_2024_05_processed.csv', data)
data = merge_new_data('../Datasets/Germany/monthly_data/GER_env_2024_06_2km_processed.csv', data)
columns = ['dt_placement', 'x', 'y', 'culex.spp', 'ndvi', 'ndwi', 'ndmi', 'ndbi',
           'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean',
           'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day', 'lst_night',
           'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan',
           'lst_jan_day_mean', 'lst_feb_day_mean', 'lst_mar_day_mean', 'lst_apr_day_mean',
           'lst_jan_night_mean', 'lst_feb_night_mean', 'lst_mar_night_mean', 'lst_apr_night_mean']
names = ['dt_placement', 'x', 'y', 'mosq_now', 'ndvi', 'ndwi', 'ndmi', 'ndbi',
         'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean',
         'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day', 'lst_night',
         'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan',
         'lst_jan_day_mean', 'lst_feb_day_mean', 'lst_mar_day_mean', 'lst_apr_day_mean',
         'lst_jan_night_mean', 'lst_feb_night_mean', 'lst_mar_night_mean', 'lst_apr_night_mean']
data = select_columns(data,columns,names)
data = add_topological(data,'../Datasets/Topological Datasets/2x2grid/germany_wuerttemberg_2km_geo.csv')
data = add_landcover(data,'../Datasets/Landcover Datasets/2x2grid/germany_wuerttemberg_2km_lulc.csv')
data = reshape_dataset(data,['x','y','dt_placement'])
data = fillna_dataset(data,{'acc_rainfall_1week':0, 'acc_rainfall_2week':0, 'acc_rainfall_jan':0})
# Out:
# Index(['station_id', 'x', 'y', 'dt_placement', 'week', 'month', 'year',
#        'country_code', 'nuts0_code', 'nuts0_name', 'nuts1_code', 'nuts1_name',
#        'nuts2_code', 'nuts2_name', 'nuts3_code', 'nuts3_name',
#        'lau1_municipality', 'lau2_settlement', 'trap_type', 'culex.spp',
#        'region', 'dt_placement_original', 'indices_image_date', 'indices_lat',
#        'indices_lon', 'ndvi', 'ndmi', 'ndwi', 'ndbi', 'ndvi_mean', 'ndmi_mean',
#        'ndwi_mean', 'ndbi_mean', 'ndvi_std', 'ndmi_std', 'ndwi_std',
#        'ndbi_std', 'lst_image_date', 'lst_lat', 'lst_lon', 'lst_day',
#        'lst_night', 'monthly_lst_lat', 'monthly_lst_lon', 'lst_jan_day_mean',
#        'lst_jan_night_mean', 'lst_feb_day_mean', 'lst_feb_night_mean',
#        'lst_mar_day_mean', 'lst_mar_night_mean', 'lst_apr_day_mean',
#        'lst_apr_night_mean', 'indices_image_date.1', 'indices_lat.1',
#        'indices_lon.1', 'acc_rainfall_jan', 'dt_placement_minus_7',
#        'dt_placement_minus_14', 'dt_placement_minus_7_avail',
#        'dt_placement_minus_14_avail', 'acc_rainfall_1week',
#        'acc_rainfall_2week', 'culex modestus', 'no_pools', 'poolsize',
#        'no_pos_pools', 'wnv_mir', 'culex.pipiens'],
#       dtype='object')

# %%
# set the date of prediction for the test set
date = '2024-6-01'

# set the filename for export
case = 'Culex_Germany_'

# set the filename to export
path = './predictions/Germany/'
        
title = date[:-3].replace('-','_')
title = case + title

# set the name of the date column
date_col = 'dt_placement'
# set the model type. Could be 'class_regression' or 'mosquito_regression' or 'classification'
model_type = 'class_regression'

# %%
data = feature_expansion(data)

# %%
data = initializer(data, model_type, [-1,   1.,  3.,  8.,  11., 16., 23., 37., 78., 206., np.inf])
# Out:
# Bounds: [ -1.   1.   3.   8.  11.  16.  23.  37.  78. 206.  inf]

# %%
print("#===========================================")
print("Performance of the previous month")
print("#===========================================")
print()
validate_results(path+case + date[:-3].replace(date[:-3].split('-')[1],str(int(date[:-3].split('-')[1])-1)).replace('-','_')+'.csv',data)
# Out:
# #===========================================
# Performance of the previous month
# #===========================================
#
# Mean time difference in days: 0.3333333333333333
# -------------------
# Overall MAE: 1.303030303030303
# Overall % error <=3: 87.88
# number of observations: 33
# -------------------
# MAE without entomological: 1.303030303030303
# % error <=3 without entomological: 87.88
# number of observations: 33
# -------------------

# %%
#=====================================================================
# Automation models without or with/without entomological data
#=====================================================================

# Spit to train and test based on date of predictions
test = data.loc[data[date_col] >= pd.to_datetime(date)]
data = data.loc[data[date_col] < pd.to_datetime(date)]

# Delete from test set stations that are not used during the last 3 years
# test = unused_stations(data, test, period=3)

#Remove features that are more 40% filled with nan values in the test set
data, test = remove_nan_features(data, test, 0.4)

# set the only_env as True if there are no mosquitoes for the forecast month
only_env=None    
if len(test.dropna(subset=['mosq_sum_month', 'mosq_sum_month_previous_year', 'mosq_sum_year',
                           'mosq_sum_previous_2weeks','previous_mosq_measure']).drop(columns=['mosq_now']).dropna())>0:
    only_env=False
elif len(test.drop(columns=['mosq_sum_month', 'mosq_sum_month_previous_year', 'mosq_sum_year',
                           'mosq_sum_previous_2weeks', 'previous_mosq_measure', 'mosq_now']).dropna())>0:
    only_env=True
else:
    print('No data left for prediction')
    
num_class = 1
hidden_layers = [264,128,128,64,32]
learning_rate = 0.001
epochs = 50
batch_size = 128
dropout = 0.2
# set the early stop argument as early_stop = (tolerance, min_delta)
early_stop = None
#set the transformation actions on the data. Options are 'augmentation', 'normalization', 'log', 'scaling'
transformation_list = ['scaling']
#set the data for embeddings e.g. data[['col', 'col2']]
embedded_data = None
#set the boolean for plotting feature importance (!very time consuming!)
fi = False
    
if only_env != None:
    # Run first without entomological features
    print("#===========================================")
    print("Predictions without entomological features")
    print("#===========================================")
    print()
    data_env = data.drop(['mosq_sum_month', 'mosq_sum_month_previous_year', 'mosq_sum_year',
                          'mosq_sum_previous_2weeks', 'previous_mosq_measure'], axis = 1)
    test_env = test.drop(['mosq_sum_month', 'mosq_sum_month_previous_year', 'mosq_sum_year',
                          'mosq_sum_previous_2weeks', 'previous_mosq_measure'], axis = 1)

    data_env = data_env.dropna().reset_index(drop=True)
    test_env = test_env.dropna(subset=test_env.columns.difference(['mosq_now'])).reset_index(drop=True)

    
    model = FeedforwardNeuralNetModel(num_features=len(data_env.iloc[0,:])-2, num_class=num_class,
                                      hidden_layers = hidden_layers, model_type=model_type,
                                      learning_rate = learning_rate, epochs = epochs, batch_size = batch_size,
                                      dropout = dropout, embedding_data=embedded_data, 
                                      transformation_list=transformation_list, early_stop = early_stop, 
                                      l1_weight=0, l2_weight=0, weights=False)

    evaluate_nn(model, data_env, fi = fi)

    predictions_env = give_predictions_nn(model, data_env, test_env, env = True, filepath = path, case = title,
                                          export = only_env)

    # Run with entomological features if at least one station has mosquitos number
    if not only_env:
        print("#===========================================")
        print("Predictions with entomological features")
        print("#===========================================")
        print()
        
        data_entom = data.dropna().reset_index(drop=True)
        test_entom = test.dropna(subset=test.columns.difference(['mosq_now'])).reset_index(drop=True)
        
        model = FeedforwardNeuralNetModel(num_features=len(data_entom.iloc[0,:])-2, num_class=num_class,
                                          hidden_layers = hidden_layers, model_type=model_type,
                                          learning_rate = learning_rate, epochs = epochs, batch_size = batch_size,
                                          dropout = dropout, embedding_data=embedded_data, 
                                          transformation_list=transformation_list, early_stop = early_stop, 
                                          l1_weight=0, l2_weight=0, weights=False)
        
        evaluate_nn(model, data_entom, fi = fi)

        predictions_entom = give_predictions_nn(model, data_entom, test_entom, env = False, filepath = path,
                                                case = title, export = False)

        print("#===========================================")
        print("Predictions with/without entomological features")
        print("#===========================================")
        merge_predictions(predictions_env,predictions_entom,path,title,export=True)
# Out:
# #===========================================
# Predictions without entomological features
# #===========================================
# MAE on train set:  0.5483188834848806
# min prediction: 0
# max prediction: 7
#
# MAE on test set:  0.937447168216399
# Error <= 3: 94.84 %
# min prediction: 0
# max prediction: 7
# -----------|class error-MAE| difference-----------
# mean: 1.0496795633627032
# std: 0.6251391008282294
# coefficient of variation (std/mean): 0.5955523215347394
#
# ----------normalized difference-------------
# mean: 0.4880233929579201
# std: 0.3493689760749014
# coefficient of variation (std/mean): 0.7158857159640826
# 0    2722
# 1    2126
# 2    1081
# 3     690
# 4     427
# 5     221
# 6      52
# 7       5
# Name: predictions, dtype: int64
#
# Low risk category stations: 4848
# Medium risk category stations: 2419
# High risk category stations: 57
# #===========================================
# Predictions with entomological features
# #===========================================
# MAE on train set:  0.5671548769086943
# min prediction: 0
# max prediction: 11
#
# MAE on test set:  0.9937733499377335
# Error <= 3: 93.28 %
# min prediction: 0
# max prediction: 7
# -----------|class error-MAE| difference-----------
# mean: 1.1745509608348415
# std: 0.7696246874917603
# coefficient of variation (std/mean): 0.6552501450807466
#
# ----------normalized difference-------------
# mean: 0.4661385225485689
# std: 0.3630660061522951
# coefficient of variation (std/mean): 0.7788800723168418
# 0    14
# 1    13
# 2     3
# 3     3
# 4     3
# 5     1
# 8     2
# Name: predictions, dtype: int64
#
# Low risk category stations: 27
# Medium risk category stations: 10
# High risk category stations: 2
# #===========================================
# Predictions with/without entomological features
# #===========================================
# 0    2729
# 1    2118
# 2    1078
# 3     691
# 4     428
# 5     221
# 6      52
# 7       5
# 8       2
# Name: predictions, dtype: int64
#
# Low risk category stations: 4847
# Medium risk category stations: 2418
# High risk category stations: 59

# %%
#=====================================================================
# Automation models without or with/without entomological data
#=====================================================================

# Spit to train and test based on date of predictions
test = data.loc[data[date_col] >= pd.to_datetime(date)]
data = data.loc[data[date_col] < pd.to_datetime(date)]

# Delete from test set stations that are not used during the last 3 years
# test = unused_stations(data, test, period=3)

#Remove features that are more 40% filled with nan values in the test set
data, test = remove_nan_features(data, test, 0.3)

# set the only_env as True if there are no mosquitoes for the forecast month
only_env=None    
if len(test.dropna(subset=['mosq_sum_month', 'mosq_sum_month_previous_year', 'mosq_sum_year',
                           'mosq_sum_previous_2weeks','previous_mosq_measure']).drop(columns=['mosq_now']).dropna())>0:
    only_env=False
elif len(test.drop(columns=['mosq_sum_month', 'mosq_sum_month_previous_year', 'mosq_sum_year',
                           'mosq_sum_previous_2weeks', 'previous_mosq_measure', 'mosq_now']).dropna())>0:
    only_env=True
else:
    print('No data left for prediction')
    

learning_rate = 0.3
# set the early stop argument as early_stop = (tolerance, min_delta)
early_stop = None
#set the transformation actions on the data. Options are 'augmentation', 'normalization', 'log', 'scaling'
transformation_list = []
#set the data for embeddings e.g. data[['col', 'col2']]
embedded_data = None
#set the boolean for plotting feature importance (!very time consuming!)
fi = False
    
if only_env != None:
    # Run first without entomological features
    print("#===========================================")
    print("Predictions without entomological features")
    print("#===========================================")
    print()
    data_env = data.drop(['mosq_sum_month', 'mosq_sum_month_previous_year', 'mosq_sum_year',
                          'mosq_sum_previous_2weeks', 'previous_mosq_measure'], axis = 1)
    test_env = test.drop(['mosq_sum_month', 'mosq_sum_month_previous_year', 'mosq_sum_year',
                          'mosq_sum_previous_2weeks', 'previous_mosq_measure'], axis = 1)
    
    data_env = data_env.dropna().reset_index(drop=True)
    test_env = test_env.dropna(subset=test_env.columns.difference(['mosq_now'])).reset_index(drop=True)

    model = Xgboost_model(model_type = model_type, learning_rate = learning_rate,
                          embedding_data = embedded_data,  transformation_list = transformation_list,
                          early_stop = False, l1_weight = 0, l2_weight = 0, weights = False)
    
    evaluate_xgboost(model, data_env, fi = fi)

    predictions_env = give_predictions_xgboost(model, data_env, test_env, env = True, filepath = path, case = title,
                                               fi = fi, export = only_env)


    # Run with entomological features if at least one station has mosquitos number
    if not only_env:
        print("#===========================================")
        print("Predictions with entomological features")
        print("#===========================================")
        print()
        
        data_entom = data.dropna().reset_index(drop=True)
        test_entom = test.dropna(subset=test.columns.difference(['mosq_now'])).reset_index(drop=True)
        
        model = Xgboost_model(model_type = model_type, learning_rate = learning_rate,
                              embedding_data = embedded_data,  transformation_list = transformation_list,
                              early_stop = False, l1_weight = 0, l2_weight = 0, weights = False)
    
        evaluate_xgboost(model, data_entom, fi = fi)

        predictions_entom = give_predictions_xgboost(model, data_entom, test_entom, env = False, filepath = path,
                                                     fi = fi, case = title, export = only_env)

        print("#===========================================")
        print("Predictions with/without entomological features")
        print("#===========================================")
        merge_predictions(predictions_env,predictions_entom, path, title, export=True)
# Out:
# #===========================================
# Predictions without entomological features
# #===========================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 55
#      49 test_env = test_env.dropna(subset=test_env.columns.difference(['mosq_now'])).reset_index(drop=True)
#      51 model = Xgboost_model(model_type = model_type, learning_rate = learning_rate,
#      52                       embedding_data = embedded_data,  transformation_list = transformation_list,
#      53                       early_stop = False, l1_weight = 0, l2_weight = 0, weights = False)
# ---> 55 evaluate_xgboost(model, data_env, fi = fi)
#      57 predictions_env = give_predictions_xgboost(model, data_env, test_env, env = True, filepath = path, case = title,
#      58                                            fi = fi, export = only_env)
#      61 # Run with entomological features if at least one station has mosquitos number
#
# File ~\Desktop\noa\predict\Model_Validation_Module.ipynb:525, in evaluate_xgboost(model, train, test, date_col, filepath, case, fi)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": null,
#       6    "id": "e69c0372",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "import math\n",
#      11     "import copy\n",
#      12     "import datetime\n",
#      13     "import pandas as pd\n",
#      14     "import numpy as np\n",
#      15     "import matplotlib.pyplot as plt\n",
#      16     "import seaborn as sns\n",
#      17     "import xgboost as xgb\n",
#      18     "from xgboost import plot_tree\n",
#      19     "import geopandas as gpd\n",
#      20     "from ipynb.fs.defs.Neural_Network_Module import Dataset, transformations_nn, prediction_nn, train_nn\n",
#      21     "from ipynb.fs.defs.XGboost_Model_Module import  transformations_xgboost, predict_xgboost, train_xgboost\n",
#      22     "from sklearn.metrics import mean_absolute_error\n",
#      23     "from sklearn.metrics.pairwise import haversine_distances\n",
#      24     "from sklearn.model_selection import train_test_split\n",
#      25     "from sklearn.decomposition import PCA\n",
#      26     "import random"
#      27    ]
#      28   },
#      29   {
#      30    "cell_type": "code",
#      31    "execution_count": null,
#      32    "id": "ac20bedb",
#      33    "metadata": {},
#      34    "outputs": [],
#      35    "source": [
#      36     "def Average(lst):\n",
#      37     "    \"\"\"Calculates the average value of a list\n",
#      38     "    \n",
#      39     "    Parameters\n",
#      40     "    ----------\n",
#      41     "    lst : list\n",
#      42     "        A list of numbers\n",
#      43     "        \n",
#      44     "    Returns\n",
#      45     "    ----------\n",
#      46     "    avg: float\n",
#      47     "        The average value of the list\n",
#      48     "    \"\"\"\n",
#      49     "    avg = sum(lst) / len(lst)\n",
#      50     "    return avg"
#      51    ]
#      52   },
#      53   {
#      54    "cell_type": "code",
#      55    "execution_count": null,
#      56    "id": "bb0a1360",
#      57    "metadata": {},
#      58    "outputs": [],
#      59    "source": [
#      60     "def plot_error_dist(actual, predictions, model_type, case=''):\n",
#      61     "    \"\"\"Prints the error distribution plot\n",
#      62     "    Parameters\n",
#      63     "    --------\n",
#      64     "    actual : pd.Series\n",
#      65     "        A Series with the actual class of each prediction\n",
#      66     "        \n",
#      67     "    predictions : pd.Series\n",
#      68     "        A Series with the predicted class of each prediction\n",
#      69     "        \n",
#      70     "    model_type : str\n",
#      71     "        Could be 'class_regression' or 'mosquito_regression' or 'classification'\n",
#      72     "    \n",
#      73     "    case: str, optional\n",
#      74     "        Title of the plot (default= '')\n",
#      75     "    \"\"\"\n",
#      76     "    error = np.abs(actual-predictions).tolist()\n",
#      77     "    if model_type != 'mosquito_regression':\n",
#      78     "        bins = np.arange(len(actual.unique())) - 0.5\n",
#      79     "        plt.hist(error, bins)\n",
#      80     "        plt.xticks(range(len(actual.unique())))\n",
#      81     "    else:\n",
#      82     "        plt.hist(error)\n",
#      83     "    plt.xlabel('abs(error)')\n",
#      84     "    plt.title('Error Distribution \\n' + case)\n",
#      85     "    plt.show()"
#      86    ]
#      87   },
#      88   {
#      89    "cell_type": "code",
#      90    "execution_count": null,
#      91    "id": "2eaf1a5d",
#      92    "metadata": {},
#      93    "outputs": [],
#      94    "source": [
#      95     "def plot_hist(actual, predictions, model_type, case=''):\n",
#      96     "    \"\"\"Prints the histogram of the actual values and the predicted values\n",
#      97     "    Parameters\n",
#      98     "    --------\n",
#      99     "    actual : pd.Series\n",
#     100     "        A Series with the actual class of each prediction\n",
#     101     "        \n",
#     102     "    predictions : pd.Series\n",
#     103     "        A Series with the predicted class of each prediction\n",
#     104     "        \n",
#     105     "    model_type : str\n",
#     106     "        Could be 'class_regression' or 'mosquito_regression' or 'classification'\n",
#     107     "    \n",
#     108     "    case: str, optional\n",
#     109     "        Title of the plot (default= '')\n",
#     110     "    \"\"\"\n",
#     111     "    plt.figure(figsize=(10,8)) \n",
#     112     "    if model_type != 'mosquito_regression':\n",
#     113     "        bins = np.arange(len(actual.unique())+1)-0.5\n",
#     114     "        plt.hist(actual, bins=bins, alpha=0.5, label='actual')\n",
#     115     "        plt.hist(predictions, bins=bins, alpha=0.5, label='prediction')\n",
#     116     "        plt.xticks(range(len(actual.unique())))\n",
#     117     "    else:\n",
#     118     "        plt.hist(actual, alpha=0.5, label='actual')\n",
#     119     "        plt.hist(predictions, alpha=0.5, label='prediction')\n",
#     120     "    plt.legend()\n",
#     121     "    plt.title('Histogram of actual vs predicted values \\n'+case)\n",
#     122     "    plt.show()"
#     123    ]
#     124   },
#     125   {
#     126    "cell_type": "code",
#     127    "execution_count": null,
#     128    "id": "00d09320",
#     129    "metadata": {},
#     130    "outputs": [],
#     131    "source": [
#     132     "def plot_error_per_class(test, case=''):\n",
#     133     "    \"\"\"Prints the error distribution per class plot\n",
#     134     "    Parameters\n",
#     135     "    --------\n",
#     136     "    actual : lst\n",
#     137     "        A list with the actual class of each prediction\n",
#     138     "        \n",
#     139     "    case: str, optional\n",
#     140     "        Title of the plot (Area and mosquito genus) (default= '')\n",
#     141     "    \"\"\"\n",
#     142     "    labels = test.loc[:,'actual'].unique().tolist()\n",
#     143     "    labels.sort()\n",
#     144     "    f = []\n",
#     145     "    length = []\n",
#     146     "    for k in labels:\n",
#     147     "        cc = test.loc[test['actual']==k]\n",
#     148     "        length.append(len(cc))\n",
#     149     "        actual = cc.loc[:,'actual']\n",
#     150     "        predictions = cc.loc[:,'prediction']\n",
#     151     "        mae_class = mean_absolute_error(actual, predictions)\n",
#     152     "        f.append(mae_class)\n",
#     153     "    labels = [str(int(e)) for e in labels]\n",
#     154     "    fig = plt.figure()\n",
#     155     "    ax = fig.add_axes([0,0,1,1])\n",
#     156     "    ax.bar(labels,f)\n",
#     157     "    for i, v in enumerate(f):\n",
#     158     "        ax.text(i, v, str('%.2f'%(v)), rotation=30)\n",
#     159     "        ax.text(i, v/2,'n = '+ str(length[i]), weight=\"bold\", ha='center', rotation=90)\n",
#     160     "    plt.xlabel('class')\n",
#     161     "    plt.ylabel('MAE')\n",
#     162     "    plt.title('MAE per class ' + case)\n",
#     163     "    plt.show()\n",
#     164     "    \n",
#     165     "    print('-----------|class error-MAE| difference-----------')\n",
#     166     "    z = np.abs(f-mean_absolute_error(actual, predictions))\n",
#     167     "    print('mean:',z.mean())\n",
#     168     "    print('std:',z.std())\n",
#     169     "    print('coefficient of variation (std/mean):',z.std()/z.mean())\n",
#     170     "    \n",
#     171     "    print()\n",
#     172     "    \n",
#     173     "    print('----------normalized difference-------------')\n",
#     174     "    min_val = min(z)\n",
#     175     "    max_val = max(z)\n",
#     176     "    z = (z - min_val) / (max_val-min_val)\n",
#     177     "    print('mean:',z.mean())\n",
#     178     "    print('std:',z.std())"
#     179    ]
#     180   },
#     181   {
#     182    "cell_type": "code",
#     183    "execution_count": null,
#     184    "id": "add3936a",
#     185    "metadata": {},
#     186    "outputs": [],
#     187    "source": [
#     188     "def plot_error_per_month(df, case=''):\n",
#     189     "    \"\"\"Prints the error per month\n",
#     190     "    Parameters\n",
#     191     "    --------\n",
#     192     "    df : dataframe\n",
#     193     "        A dataframe containing the data\n",
#     194     "    \n",
#     195     "    case: str, optional\n",
#     196     "        Title of the plot (Area and mosquito genus) (default= '')\n",
#     197     "    \"\"\"\n",
#     198     "    fig = plt.figure()\n",
#     199     "    ax = fig.add_axes([0,0,1,1])\n",
#     200     "    labels = (df['dt_prediction'].dt.month).unique()\n",
#     201     "    labels.sort()\n",
#     202     "    labels = [str(e) for e in labels]\n",
#     203     "    df['abs(error)'] = np.abs(df['actual']-df['prediction'])\n",
#     204     "    f = df.groupby(by=[df['dt_prediction'].dt.month])['abs(error)'].mean().values\n",
#     205     "    length = df.groupby(by=[df['dt_prediction'].dt.month])['dt_prediction'].count().values\n",
#     206     "    ax.bar(labels,f)\n",
#     207     "    for i, v in enumerate(f):\n",
#     208     "        ax.text(i, v, str('%.2f'%(v)),rotation=30)\n",
#     209     "        ax.text(i, v/2,'n = '+ str(length[i]),weight=\"bold\",ha='center', rotation=90)\n",
#     210     "    plt.xlabel('Month')\n",
#     211     "    plt.ylabel('MAE')\n",
#     212     "    plt.title('Mean Absolute Error per month ' + case)\n",
#     213     "    plt.show()"
#     214    ]
#     215   },
#     216   {
#     217    "cell_type": "code",
#     218    "execution_count": null,
#     219    "id": "d9be2083",
#     220    "metadata": {},
#     221    "outputs": [],
#     222    "source": [
#     223     "def scatter_plot_error(actual, prediction, case=''):\n",
#     224     "    \"\"\"Prints the error in relation with the distance of point from the train region\n",
#     225     "    Parameters\n",
#     226     "    --------\n",
#     227     "    df : dataframe\n",
#     228     "        A dataframe containing the data\n",
#     229     "    \n",
#     230     "    case: str, optional\n",
#     231     "        Title of the plot (Area and mosquito genus) (default= '')\n",
#     232     "    \"\"\"\n",
#     233     "    # choose the input and output variables\n",
#     234     "    x, y = actual, np.abs(actual-prediction)\n",
#     235     "    plt.scatter(x, y)\n",
#     236     "    plt.xlabel('Mosquito bins')\n",
#     237     "    plt.ylabel('Error')\n",
#     238     "    plt.title('Scatterplot of error ' + case)\n",
#     239     "    plt.show()"
#     240    ]
#     241   },
#     242   {
#     243    "cell_type": "code",
#     244    "execution_count": null,
#     245    "id": "f35bff07",
#     246    "metadata": {},
#     247    "outputs": [],
#     248    "source": [
#     249     "def plot_error_per_group(actual,prediction,case=''):\n",
#     250     "    \"\"\"Prints the error distribution plot\n",
#     251     "    Parameters\n",
#     252     "    --------\n",
#     253     "    actual : pd.Series\n",
#     254     "        A Series with the actual class of each prediction\n",
#     255     "        \n",
#     256     "    predictions : pd.Series\n",
#     257     "        A Series with the predicted class of each prediction\n",
#     258     "        \n",
#     259     "    case: str, optional\n",
#     260     "        Title of the plot (default= '')\n",
#     261     "\n",
#     262     "    \"\"\"\n",
#     263     "    test = {'mosq_now':actual,'predictions':prediction}\n",
#     264     "    test = pd.DataFrame(test)\n",
#     265     "    test['classes'] = pd.cut(x=test['mosq_now'], bins=[-1, 100, 200, 300, 400, 500, np.inf],\n",
#     266     "                      labels=['0-100', '101-200', '201-300', '301-400', '401-500', '500<'])\n",
#     267     "    labels = test['classes'].unique().tolist()\n",
#     268     "    labels.sort()\n",
#     269     "    f = []\n",
#     270     "    length = []\n",
#     271     "    for k in labels:\n",
#     272     "        cc = test.loc[test['classes']==k]\n",
#     273     "        length.append(len(cc))\n",
#     274     "        actual = cc.loc[:,'mosq_now']\n",
#     275     "        predictions = cc.loc[:,'predictions']\n",
#     276     "        f.append(mean_absolute_error(actual, predictions))\n",
#     277     "    fig = plt.figure()\n",
#     278     "    ax = fig.add_axes([0,0,1,1])\n",
#     279     "    ax.bar(labels,f)\n",
#     280     "    for i, v in enumerate(f):\n",
#     281     "        ax.text(i, v, str('%.2f'%(v)),rotation=30)\n",
#     282     "        ax.text(i, v/2,'n = '+ str(length[i]),weight=\"bold\",ha='center', rotation=90)\n",
#     283     "    plt.xlabel('Mosquito Group')\n",
#     284     "    plt.ylabel('MAE')\n",
#     285     "    plt.title('MAE per Mosquito group \\n'+case)\n",
#     286     "    plt.show()"
#     287    ]
#     288   },
#     289   {
#     290    "cell_type": "code",
#     291    "execution_count": null,
#     292    "id": "04ce414a",
#     293    "metadata": {},
#     294    "outputs": [],
#     295    "source": [
#     296     "def error_cdf(actual,prediction, case=''):\n",
#     297     "    \"\"\"Prints the cdf of errors\n",
#     298     "    Parameters\n",
#     299     "    --------\n",
#     300     "    actual : pd.Series\n",
#     301     "        A Series with the actual class of each prediction\n",
#     302     "        \n",
#     303     "    predictions : pd.Series\n",
#     304     "        A Series with the predicted class of each prediction\n",
#     305     "        \n",
#     306     "    case: str, optional\n",
#     307     "        Title of the plot (default= '')\n",
#     308     "\n",
#     309     "    \"\"\"\n",
#     310     "    error = np.abs(actual-prediction)\n",
#     311     "    \n",
#     312     "    a = np.sort(error.unique())\n",
#     313     "    b = np.array(error)\n",
#     314     "    cdf = np.zeros(len(a))\n",
#     315     "    for k, val in enumerate(a):\n",
#     316     "        mask_d = b <= val\n",
#     317     "        cdf[k] = mask_d.sum()/ len(b)\n",
#     318     "    plt.figure(figsize=(8,8))\n",
#     319     "    plt.plot(a,cdf)\n",
#     320     "    plt.grid()\n",
#     321     "    plt.xlabel('abs(error)',fontsize=18)\n",
#     322     "    plt.ylabel('CDF',fontsize=18)\n",
#     323     "    plt.xticks(fontsize=14)\n",
#     324     "    plt.yticks(fontsize=14)\n",
#     325     "    #plt.title('CDF of error \\n' + case)\n",
#     326     "    plt.show() \n",
#     327     "    \n",
#     328     "    b = np.sort(error)\n",
#     329     "    a = np.arange(1,len(error)+1) \n",
#     330     "    cdf = np.zeros(len(a))\n",
#     331     "    for k, val in enumerate(b):\n",
#     332     "        cdf[k] = b[k]\n",
#     333     "    plt.plot(a,cdf)\n",
#     334     "    plt.grid()\n",
#     335     "    plt.xlabel('Number of samples',fontsize=18)\n",
#     336     "    plt.ylabel('Error',fontsize=18)\n",
#     337     "    plt.xticks(fontsize=14)\n",
#     338     "    plt.yticks(fontsize=14)\n",
#     339     "    plt.title('CDF of error \\n' + case)\n",
#     340     "    plt.show()"
#     341    ]
#     342   },
#     343   {
#     344    "cell_type": "code",
#     345    "execution_count": null,
#     346    "id": "e7fc8e39",
#     347    "metadata": {},
#     348    "outputs": [],
#     349    "source": [
#     350     "def metrics(train, test, threshold=3):\n",
#     351     "    \"\"\"Calculates the perfomance of the model on train and test set\n",
#     352     "    Parameters\n",
#     353     "    --------\n",
#     354     "    train : Dataframe\n",
#     355     "        A Dataframe with the actual and the predicted values on the train set\n",
#     356     "        \n",
#     357     "    test : Dataframe\n",
#     358     "        A Dataframe with the actual and the predicted values on the train set\n",
#     359     "        \n",
#     360     "    threshold: int, optional\n",
#     361     "        A threshold to calculate percentage of error < threshold (default= 3)\n",
#     362     "\n",
#     363     "    \"\"\"    \n",
#     364     "    print('MAE on train set: ', mean_absolute_error(train['actual'], train['prediction']))\n",
#     365     "\n",
#     366     "    print('min prediction:',min(train['prediction']))\n",
#     367     "    print('max prediction:',max(train['prediction']))\n",
#     368     "    \n",
#     369     "    print()\n",
#     370     "\n",
#     371     "    print('MAE on test set: ', mean_absolute_error(test['actual'], test['prediction']))\n",
#     372     "    perc = ((np.abs(test['actual']-test['prediction']) < (threshold+0.5)).mean())*100\n",
#     373     "    print('Error <= '+str(threshold)+':',\"%.2f\"%perc,'%')\n",
#     374     "\n",
#     375     "    print('min prediction:',min(test['prediction']))\n",
#     376     "    print('max prediction:',max(test['prediction']))"
#     377    ]
#     378   },
#     379   {
#     380    "cell_type": "code",
#     381    "execution_count": null,
#     382    "id": "f034d351",
#     383    "metadata": {},
#     384    "outputs": [],
#     385    "source": [
#     386     "def validation(train, test, model_type, case=''):\n",
#     387     "    \"\"\"Prints plots about the performance of the model on the test set\n",
#     388     "    \n",
#     389     "    Parameters\n",
#     390     "    --------        \n",
#     391     "    test : Dataframe\n",
#     392     "        A Dataframe with the actual and the predicted values on the train set\n",
#     393     "    \n",
#     394     "    model_type : str\n",
#     395     "        Could be 'class_regression' or 'mosquito_regression' or 'classification'\n",
#     396     "        \n",
#     397     "    case: str, optional\n",
#     398     "        Title of the plot (default= '')\n",
#     399     "    \"\"\"\n",
#     400     "    if model_type != 'mosquito_regression':\n",
#     401     "        metrics(train, test)\n",
#     402     "        plot_error_per_class(test, case)\n",
#     403     "    else:\n",
#     404     "        metrics(train, test, threshold=30)\n",
#     405     "        plot_error_per_group(test['actual'],test['prediction'], case)\n",
#     406     "        error_cdf(test['actual'],test['prediction'], case)\n",
#     407     "    scatter_plot_error(test['actual'],test['prediction'], case)\n",
#     408     "    plot_error_dist(test['actual'],test['prediction'], model_type, case)\n",
#     409     "    plot_hist(test['actual'],test['prediction'], model_type, case)\n",
#     410     "    plot_error_per_month(test, case)"
#     411    ]
#     412   },
#     413   {
#     414    "cell_type": "code",
#     415    "execution_count": null,
#     416    "id": "1ab575b3",
#     417    "metadata": {},
#     418    "outputs": [],
#     419    "source": [
#     420     "def evaluate_nn(model, train, test=None, filepath = '', date_col = 'dt_placement', fi=False, case=''):\n",
#     421     "    \n",
#     422     "    if test is None:\n",
#     423     "        train, test = train_test_split(train, test_size=0.2, random_state=3)\n",
#     424     "        train = train.reset_index(drop=True)\n",
#     425     "        test = test.reset_index(drop=True)\n",
#     426     "        \n",
#     427     "    train = train.drop([date_col],axis=1)    \n",
#     428     "    date = test[date_col]\n",
#     429     "    test = test.drop([date_col],axis=1)\n",
#     430     "        \n",
#     431     "    mosq_col = train.columns[-1]\n",
#     432     "    max_val= train.iloc[:,-1].max()\n",
#     433     "    \n",
#     434     "    model_int = copy.deepcopy(model)\n",
#     435     "    \n",
#     436     "    features = None\n",
#     437     "    if fi:\n",
#     438     "        if model.embedding_data is not None:\n",
#     439     "            columns = train.drop(columns=model.embedded_data.columns.tolist()).columns[:-1].tolist()\n",
#     440     "            columns = columns+embedded_data.columns.tolist()\n",
#     441     "            features = columns\n",
#     442     "        else:\n",
#     443     "            features = train.columns[:-1].tolist()\n",
#     444     "    \n",
#     445     "    train_X, train_y, test_X, test_y = transformations_nn(train, test = test, model_type = model.model_type, \n",
#     446     "                                                       embedding_data = model.embedding_data,\n",
#     447     "                                                       transformation_list = model.transformation_list)\n",
#     448     "\n",
#     449     "    training_set = Dataset(train_X, train_y)\n",
#     450     "\n",
#     451     "    testing_set = Dataset(test_X, test_y)\n",
#     452     "\n",
#     453     "    results_train, results_test, _ = train_nn(model = model_int, train_set = training_set, test_set = testing_set,\n",
#     454     "                               features=features, max_val = max_val)\n",
#     455     "    \n",
#     456     "\n",
#     457     "    test[date_col] = date\n",
#     458     "    test['dt_prediction'] = test[date_col] + datetime.timedelta(days=15)\n",
#     459     "    test['prediction'] = results_test['prediction']\n",
#     460     "    test.loc[test['prediction']<0,'prediction'] = 0\n",
#     461     "    test['error'] = test[mosq_col] - test['prediction']\n",
#     462     "    test['abs(error)'] = np.abs(test[mosq_col] - test['prediction'])\n",
#     463     "    \n",
#     464     "    test = test.rename(columns={mosq_col:'actual'})\n",
#     465     "\n",
#     466     "    validation(results_train, test, model_type=model.model_type, case=case)"
#     467    ]
#     468   },
#     469   {
#     470    "cell_type": "code",
#     471    "execution_count": null,
#     472    "id": "5a715cd9",
#     473    "metadata": {},
#     474    "outputs": [],
#     475    "source": [
#     476     "def give_predictions_nn(model, train, test, env, filepath, date_col='dt_placement', case='', fi=False, export=False):\n",
#     477     "    \"\"\" Trainning of the model\n",
#     478     "    \n",
#     479     "    Parameters\n",
#     480     "    ----------\n",
#     481     "    model : FeedforwardNeuralNetModel\n",
#     482     "        A FeedforwardNeuralNetModel model\n",
#     483     "        \n",
#     484     "    train : DataFrame\n",
#     485     "        A Dataframe object with the train set\n",
#     486     "        \n",
#     487     "    test : DataFrame\n",
#     488     "        A Dataframe object with the test set\n",
#     489     "    \n",
#     490     "    step : int\n",
#     491     "        The number of days for prediction\n",
#     492     "        \n",
#     493     "    env : boolean\n",
#     494     "        If true only enviromental features are used\n",
#     495     "        \n",
#     496     "    filepath : srt, optional\n",
#     497     "        The path of the file to export the results\n",
#     498     "        \n",
#     499     "    transform_target : boolean, \n",
#     500     "        If True, perofrms transformation of the target based on the model_type argument (default = False)\n",
#     501     "        \n",
#     502     "    learning_rate : int, optional\n",
#     503     "        The learning_rate of the training process. (default = None)\n",
#     504     "        \n",
#     505     "    epochs : int, optional\n",
#     506     "        The number of epochs for the training. (default = None)\n",
#     507     "        \n",
#     508     "    batch_size : int, optional\n",
#     509     "        The size of each batch in each iteration. (default = None)\n",
#     510     "        \n",
#     511     "    ealry_stop : boolean, optional\n",
#     512     "        If True, the trainning of the model may stop earlier than the epochs defined. (default = None)\n",
#     513     "        \n",
#     514     "    date_col : str, optional\n",
#     515     "        The name of the date column (default = 'dt_placement')\n",
#     516     "    \n",
#     517     "    case : str, optional\n",
#     518     "        The title of case for the plot (default='')\n",
#     519     "    \n",
#     520     "    export : boolean, optional\n",
#     521     "        Export a csv with the feature importance and a csv with the test data (default=False)\n",
#     522     "        \n",
#     523     "    Returns\n",
#     524     "    ----------        \n",
# --> 525     "    output: DataFrame\n",
#     526     "        A Dataframe containing the actual and the predicted values on the test set\n",
#     527     "\n",
#     528     "    \"\"\"    \n",
#     529     "    date = test[date_col]\n",
#     530     "    train = train.drop([date_col],axis=1)\n",
#     531     "    test = test.drop([date_col],axis=1)\n",
#     532     "    \n",
#     533     "    mosq_col = train.columns[-1]\n",
#     534     "    max_val= train.iloc[:,-1].max()\n",
#     535     "    \n",
#     536     "    features = None\n",
#     537     "    if fi:\n",
#     538     "        if model.embedding_data is not None:\n",
#     539     "            columns = data.drop(columns=model.embedded_data.columns.tolist()).columns[:-1].tolist()\n",
#     540     "            columns = columns+embedded_data.columns.tolist()\n",
#     541     "            features = columns\n",
#     542     "        else:\n",
#     543     "            features = data.columns[:-1].tolist()\n",
#     544     "    \n",
#     545     "    model_int = copy.deepcopy(model)\n",
#     546     "    \n",
#     547     "    train_X, train_y, test_X, test_y = transformations_nn(train, test = test, model_type = model.model_type, \n",
#     548     "                                                       embedding_data = model.embedding_data,\n",
#     549     "                                                       transformation_list = model.transformation_list)\n",
#     550     "\n",
#     551     "    training_set = Dataset(train_X, train_y)\n",
#     552     "\n",
#     553     "    testing_set = Dataset(test_X, test_y)\n",
#     554     "    \n",
#     555     "    test_predict = prediction_nn(model, training_set, testing_set, features=features, max_val = max_val)\n",
#     556     "            \n",
#     557     "            \n",
#     558     "    test[date_col] = date\n",
#     559     "    test['dt_prediction'] = test[date_col] + datetime.timedelta(days = 15)\n",
#     560     "    test['prediction'] = test_predict['prediction']\n",
#     561     "    test.loc[test['prediction']<0,'prediction'] = 0\n",
#     562     "    test.loc[test['prediction']>train.iloc[:, -1].max(),'prediction'] = train.iloc[:, -1].max()\n",
#     563     "    test['entomological_features'] = not(env)\n",
#     564     "    test['week'] = test['dt_prediction'].dt.isocalendar()['week']\n",
#     565     "    test = test.sort_values(['dt_prediction'], ascending=True).reset_index(drop=True)\n",
#     566     "    test = test.drop_duplicates(subset=['week', 'x', 'y'], keep='last').reset_index(drop=True)\n",
#     567     "    \n",
#     568     "    classes = test['prediction'].value_counts().sort_index()\n",
#     569     "    \n",
#     570     "    print(classes)\n",
#     571     "    print()\n",
#     572     "    print('Low risk category stations:',classes[classes.index<2].sum())\n",
#     573     "    print('Medium risk category stations:',classes[(classes.index>1) & (classes.index<6)].sum())\n",
#     574     "    print('High risk category stations:',classes[classes.index>5].sum())\n",
#     575     "    \n",
#     576     "    output = test[[date_col, 'dt_prediction', 'week', 'x', 'y', 'prediction', 'entomological_features']]\n",
#     577     "    \n",
#     578     "    if export:\n",
#     579     "        csv_name = filepath + case + '.csv'\n",
#     580     "        output.to_csv(csv_name,index=False)\n",
#     581     "        geopandas_predictions(output,filepath,case)\n",
#     582     "    \n",
#     583     "    return output"
#     584    ]
#     585   },
#     586   {
#     587    "cell_type": "code",
#     588    "execution_count": null,
#     589    "id": "0f98e58e",
#     590    "metadata": {},
#     591    "outputs": [],
#     592    "source": [
#     593     "def evaluate_xgboost(model, train, test = None, date_col = 'dt_placement', filepath='', case = '', fi = False):\n",
#     594     "    \"\"\"Trains a model on random splitted data\n",
#     595     "    \n",
#     596     "    Parameters\n",
#     597     "    --------\n",
#     598     "    data : dataframe\n",
#     599     "        A dataframe containing the data\n",
#     600     "        \n",
#     601     "    test_df : dataframe\n",
#     602     "        A dataframe containing the prediction\n",
#     603     "        \n",
#     604     "    filepath : srt, optional\n",
#     605     "        The path of the file to export the results\n",
#     606     "        \n",
#     607     "    date_col : str, optional\n",
#     608     "        The name of the date column (default = 'dt_placement')\n",
#     609     "        \n",
#     610     "    case : str, optional\n",
#     611     "        The title of case for the plot (default='')\n",
#     612     "    \n",
#     613     "    \"\"\"     \n",
#     614     "    if test is None:\n",
#     615     "        train, test = train_test_split(train, test_size=0.2, random_state=3)\n",
#     616     "        train = train.reset_index(drop=True)\n",
#     617     "        test = test.reset_index(drop=True)\n",
#     618     "    \n",
#     619     "    del train[date_col]\n",
#     620     "    date = test[date_col]\n",
#     621     "    del test[date_col]\n",
#     622     "    \n",
#     623     "    max_val= train.iloc[:,-1].max()\n",
#     624     "    mosq_col = train.columns[-1]\n",
#     625     "    \n",
#     626     "    model_int = copy.deepcopy(model)\n",
#     627     "    \n",
#     628     "    train_X, train_y, test_X, test_y = transformations_xgboost(train, test = test, model_type = model.model_type,\n",
#     629     "                                                               evaluation=False,\n",
#     630     "                                                               transformation_list=model.transformation_list,\n",
#     631     "                                                               embedding_data=model.embedding_data)\n",
#     632     "\n",
#     633     "    results_train, results_test = train_xgboost(model_int, train_X, train_y, test_X, test_y, max_val, fi)\n",
#     634     "        \n",
#     635     "    \n",
#     636     "    test[date_col] = date\n",
#     637     "    test['dt_prediction'] = test[date_col] + datetime.timedelta(days=15)\n",
#     638     "    test['prediction'] = results_test['prediction']\n",
#     639     "    test['error'] = test[mosq_col] - test['prediction']\n",
#     640     "    test['abs(error)'] = np.abs(test[mosq_col] - test['prediction'])\n",
#     641     "    \n",
#     642     "    test = test.rename(columns={mosq_col:'actual'})\n",
#     643     "    \n",
#     644     "    validation(results_train, test, model_type=model.model_type, case=case)"
#     645    ]
#     646   },
#     647   {
#     648    "cell_type": "code",
#     649    "execution_count": null,
#     650    "id": "89b1e23d",
#     651    "metadata": {},
#     652    "outputs": [],
#     653    "source": [
#     654     "def give_predictions_xgboost(model, train, test, env, filepath, fi=False, date_col='dt_placement', case='',export=False):\n",
#     655     "    \"\"\"Trains a model on random splitted data\n",
#     656     "    \n",
#     657     "    Parameters\n",
#     658     "    --------\n",
#     659     "    data : dataframe\n",
#     660     "        A dataframe containing the data\n",
#     661     "        \n",
#     662     "    test : dataframe\n",
#     663     "        A dataframe containing the prediction\n",
#     664     "    \n",
#     665     "    features : lst\n",
#     666     "        A list of features to use\n",
#     667     "    \n",
#     668     "    depth : int\n",
#     669     "        The dpeth of the trees to construct\n",
#     670     "        \n",
#     671     "    estimators : int\n",
#     672     "        The number of trees to construct\n",
#     673     "        \n",
#     674     "    env : boolean\n",
#     675     "        If true only enviromental features are used\n",
#     676     "        \n",
#     677     "    filepath : srt, optional\n",
#     678     "        The path of the file to export the results\n",
#     679     "        \n",
#     680     "    date_col : str, optional\n",
#     681     "        The name of the date column (default = 'dt_placement')\n",
#     682     "        \n",
#     683     "    case : str, optional\n",
#     684     "        The title of case for the plot (default='')\n",
#     685     "    \n",
#     686     "    export : boolean, optional\n",
#     687     "        Export a csv with the feature importance and a csv with the test data (default=False)\n",
#     688     "    \"\"\"\n",
#     689     "\n",
#     690     "    train = train.reset_index(drop=True)\n",
#     691     "    test = test.reset_index(drop=True)\n",
#     692     "\n",
#     693     "    max_val= train.iloc[:,-1].max()\n",
#     694     "    mosq_col = train.columns[-1]\n",
#     695     "#     model_int = copy.deepcopy(model)\n",
#     696     "    \n",
#     697     "    del train[date_col]\n",
#     698     "    date = test[date_col]\n",
#     699     "    del test[date_col]\n",
#     700     "    \n",
#     701     "    \n",
#     702     "    train_X, train_y, test_X, test_y = transformations_xgboost(train, test = test, model_type = model.model_type,\n",
#     703     "                                                               evaluation=False,\n",
#     704     "                                                               transformation_list=model.transformation_list,\n",
#     705     "                                                               embedding_data=model.embedding_data)\n",
#     706     "\n",
#     707     "    results_test = predict_xgboost(model, train_X, train_y, test_X, test_y, max_val, fi)\n",
#     708     "    \n",
#     709     "    test[date_col] = date\n",
#     710     "    test['dt_prediction'] = test[date_col] + datetime.timedelta(days=15)\n",
#     711     "    test['prediction'] = results_test['prediction']\n",
#     712     "    test['entomological_features'] = not(env)\n",
#     713     "    test['week'] = test['dt_prediction'].dt.isocalendar()['week']\n",
#     714     "    test = test.sort_values(['dt_prediction'], ascending=True).reset_index(drop=True)\n",
#     715     "    test = test.drop_duplicates(subset=['week', 'x', 'y'], keep='last').reset_index(drop=True)\n",
#     716     "    \n",
#     717     "    classes = test['prediction'].value_counts().sort_index()\n",
#     718     "    \n",
#     719     "    print(classes)\n",
#     720     "    print()\n",
#     721     "    print('Low risk category stations:',classes[classes.index<2].sum())\n",
#     722     "    print('Medium risk category stations:',classes[(classes.index>1) & (classes.index<6)].sum())\n",
#     723     "    print('High risk category stations:',classes[classes.index>5].sum())\n",
#     724     "    \n",
#     725     "    output = test[[date_col, 'dt_prediction', 'week', 'x', 'y', 'prediction', 'entomological_features']]\n",
#     726     "    \n",
#     727     "    if export:\n",
#     728     "        csv_name = filepath + case + '.csv'\n",
#     729     "        output.to_csv(csv_name,index=False)\n",
#     730     "        geopandas_predictions(output,filepath,case)\n",
#     731     "        \n",
#     732     "    return output"
#     733    ]
#     734   },
#     735   {
#     736    "cell_type": "code",
#     737    "execution_count": null,
#     738    "id": "stunning-spirituality",
#     739    "metadata": {},
#     740    "outputs": [],
#     741    "source": [
#     742     "def merge_predictions(predictions_env, predictions_entom, filepath='',case='', export=False):\n",
#     743     "    \"\"\"Integrates the predictions with and without the entomolofical featues\n",
#     744     "    \n",
#     745     "    Parameters\n",
#     746     "    --------\n",
#     747     "    predictions_env : dataframe\n",
#     748     "        A dataframe containing the predictions based only on the enviromental features\n",
#     749     "        \n",
#     750     "    predictions_env : dataframe\n",
#     751     "        A dataframe containing the predictions based on the enviromental and entomological features\n",
#     752     "    \n",
#     753     "    features : lst\n",
#     754     "        A list of features to use\n",
#     755     "        \n",
#     756     "    filepath : srt, optional\n",
#     757     "        The path of the file to export the results (default='')\n",
#     758     "        \n",
#     759     "    title : str, optional\n",
#     760     "        The name of the case (default='')\n",
#     761     "    \n",
#     762     "    export : boolean, optional\n",
#     763     "        Exports a csv with the predictions (default=False)\n",
#     764     "        \n",
#     765     "    \"\"\"\n",
#     766     "    predictions = pd.concat([predictions_entom, predictions_env])\n",
#     767     "    predictions = predictions.sort_values(['entomological_features'], ascending=False).reset_index(drop=True)\n",
#     768     "    predictions = predictions.drop_duplicates(subset=['dt_placement', 'x', 'y'], keep='first').reset_index(drop=True)\n",
#     769     "    predictions = predictions.drop_duplicates(subset=['week', 'x', 'y'], keep='first').reset_index(drop=True)\n",
#     770     "\n",
#     771     "    # Print risk classes for combined predictions\n",
#     772     "    classes = predictions['prediction'].value_counts().sort_index()\n",
#     773     "\n",
#     774     "    print(classes)\n",
#     775     "    print()\n",
#     776     "    print('Low risk category stations:', classes[classes.index<2].sum())\n",
#     777     "    print('Medium risk category stations:', classes[(classes.index>1) & (classes.index<6)].sum())\n",
#     778     "    print('High risk category stations:', classes[classes.index>5].sum())\n",
#     779     "\n",
#     780     "    # Save combined predictions to csv\n",
#     781     "    if export:\n",
#     782     "        csv_name =  filepath + case + '.csv'\n",
#     783     "        predictions.to_csv(csv_name,index=False)\n",
#     784     "        geopandas_predictions(predictions,filepath,case)\n",
#     785     "        \n",
#     786     "    return predictions"
#     787    ]
#     788   },
#     789   {
#     790    "cell_type": "code",
#     791    "execution_count": null,
#     792    "id": "0c139613",
#     793    "metadata": {},
#     794    "outputs": [],
#     795    "source": [
#     796     "def validate_results(predictions_path, data, period=8, radius=1, long_column='x', lat_column='y', error_buffer=3):\n",
#     797     "    \"\"\"Checks the accuracy of the predictions of the previous month.\n",
#     798     "    \n",
#     799     "    Parameters\n",
#     800     "    --------\n",
#     801     "    predictions_path : str\n",
#     802     "        A path to the file containing the predictions of a month\n",
#     803     "        \n",
#     804     "    data : dataframe\n",
#     805     "        A dataframe containing the dates and the actual classes on each date\n",
#     806     "        \n",
#     807     "    period : int, optional\n",
#     808     "        The period around a prediction that is acceptable to check for error (default = 8)\n",
#     809     "        \n",
#     810     "    radius : int or fload, optional\n",
#     811     "        The distance (in Km) around a point to search for mosquito measurment (default = 1)\n",
#     812     "        \n",
#     813     "    long_column : str, optional\n",
#     814     "            The name of the column with the longitude (default = 'x')\n",
#     815     "        \n",
#     816     "    lat_column : str, optional\n",
#     817     "        The name of the column with the latitude (default = 'y')\n",
#     818     "        \n",
#     819     "    error_buffer : int, optional\n",
#     820     "        The error buffer for cumpiting percentage of error (default = 3)\n",
#     821     "        \n",
#     822     "    \"\"\"\n",
#     823     "    predictions = pd.read_csv(predictions_path)\n",
#     824     "    predictions['dt_placement'] = pd.to_datetime(predictions['dt_placement'], format=\"%Y-%m-%d\")\n",
#     825     "    predictions['dt_prediction'] = pd.to_datetime(predictions['dt_prediction'], format=\"%Y-%m-%d\")\n",
#     826     "    actual = []\n",
#     827     "    date_l = []\n",
#     828     "    \n",
#     829     "    radians_y = data.loc[:,lat_column].astype(float).apply(math.radians)\n",
#     830     "    radians_x = data.loc[:,long_column].astype(float).apply(math.radians)\n",
#     831     "    radians_data = pd.concat([radians_y,radians_x],axis=1)\n",
#     832     "    radians_y = predictions.loc[:,lat_column].astype(float).apply(math.radians)\n",
#     833     "    radians_x = predictions.loc[:,long_column].astype(float).apply(math.radians)\n",
#     834     "    radians_predictions = pd.concat([radians_y,radians_x],axis=1)\n",
#     835     "    distances = haversine_distances(radians_predictions,radians_data)*6371\n",
#     836     "    \n",
#     837     "    for i in range(len(predictions)):\n",
#     838     "        indexes = np.where(distances[i,:] <= radius)[0].tolist()\n",
#     839     "        data1 = data.loc[indexes,:].reset_index(drop=True)\n",
#     840     "        y = np.nan\n",
#     841     "        d = np.nan\n",
#     842     "        if len(data1)>0:\n",
#     843     "            date =  predictions.loc[i,'dt_prediction']\n",
#     844     "            diff = ((data1['dt_placement'] + datetime.timedelta(days=15)) - date).dt.days\n",
#     845     "            indexmin = diff.abs().idxmin()\n",
#     846     "            y = data1.loc[indexmin,'mosq_now']\n",
#     847     "            d = diff[indexmin]\n",
#     848     "            diff = diff.drop(indexmin)\n",
#     849     "            while np.isnan(y) and (len(diff) !=0):\n",
#     850     "                indexmin = diff.abs().idxmin()\n",
#     851     "                y = data1.loc[indexmin,'mosq_now']\n",
#     852     "                d = diff[indexmin]\n",
#     853     "                diff = diff.drop(indexmin)\n",
#     854     "        actual.append(y)\n",
#     855     "        date_l.append(d)\n",
#     856     "    predictions.loc[:,'actual'] = actual\n",
#     857     "    predictions.loc[:,'time_diff'] = date_l\n",
#     858     "    \n",
#     859     "    predictions = predictions.loc[np.abs(predictions['time_diff'])<period]\n",
#     860     "    if len(predictions) != 0:\n",
#     861     "        x = predictions['prediction']-predictions['actual']\n",
#     862     "        print('Mean time difference in days:',predictions['time_diff'].mean())\n",
#     863     "        print('-------------------')\n",
#     864     "        print('Overall MAE:',np.abs(x).mean())\n",
#     865     "        print('Overall % error <=' +str(error_buffer) +':', np.round(Average(np.abs(x) <= error_buffer)*100,2))\n",
#     866     "        print('number of observations:', len(x))\n",
#     867     "        print('-------------------')\n",
#     868     "        ent = predictions.loc[predictions['entomological_features']==True]\n",
#     869     "        if len(ent) != 0:\n",
#     870     "            x = ent['prediction']-ent['actual']\n",
#     871     "            print('MAE with entomological:',np.abs(x).mean())\n",
#     872     "            print('% error <='+ str(error_buffer) +' with entomological:', np.round(Average(np.abs(x) <= error_buffer)*100,2))\n",
#     873     "            print('number of observations:', len(x))\n",
#     874     "            print('-------------------')\n",
#     875     "        ent = predictions.loc[predictions['entomological_features']==False]\n",
#     876     "        if len(ent) != 0:    \n",
#     877     "            x = ent['prediction']-ent['actual']\n",
#     878     "            print('MAE without entomological:',np.abs(x).mean())\n",
#     879     "            print('% error <='+ str(error_buffer) +' without entomological:', np.round(Average(np.abs(x) <= error_buffer)*100,2))\n",
#     880     "            print('number of observations:', len(x))\n",
#     881     "            print('-------------------')\n",
#     882     "    else:\n",
#     883     "        print('No predictions with difference less than %d days' % period)"
#     884    ]
#     885   },
#     886   {
#     887    "cell_type": "code",
#     888    "execution_count": null,
#     889    "id": "5084a41c",
#     890    "metadata": {},
#     891    "outputs": [],
#     892    "source": [
#     893     "def validate_results2(predictions, data, period=8, radius=1, long_column ='x', lat_column ='y'):\n",
#     894     "    \"\"\"Checks the accuracy of the predictions of the previous month.\n",
#     895     "    \n",
#     896     "    Parameters\n",
#     897     "    --------\n",
#     898     "    predictions_path : str\n",
#     899     "        A path to the file containing the predictions of a month\n",
#     900     "        \n",
#     901     "    data : dataframe\n",
#     902     "        A dataframe containing the dates and the actual classes on each date\n",
#     903     "        \n",
#     904     "    period : int, optional\n",
#     905     "        The period around a prediction that is acceptable to check for error (default = 8)\n",
#     906     "        \n",
#     907     "    period : int or fload, optional\n",
#     908     "        The distance (in Km) around a point to search for mosquito measurment (default = 1)\n",
#     909     "        \n",
#     910     "    long_column : str, optional\n",
#     911     "            The name of the column with the longitude (default = 'x')\n",
#     912     "        \n",
#     913     "    lat_column : str, optional\n",
#     914     "        The name of the column with the latitude (default = 'y')\n",
#     915     "        \n",
#     916     "    \"\"\"\n",
#     917     "#     predictions = pd.read_csv(predictions_path)\n",
#     918     "    predictions['dt_placement'] = pd.to_datetime(predictions['dt_placement'], format=\"%Y-%m-%d\")\n",
#     919     "    predictions['dt_prediction'] = pd.to_datetime(predictions['dt_prediction'], format=\"%Y-%m-%d\")\n",
#     920     "    actual = []\n",
#     921     "    date_l = []\n",
#     922     "    \n",
#     923     "    radians_y = data.loc[:,lat_column].astype(float).apply(math.radians)\n",
#     924     "    radians_x = data.loc[:,long_column].astype(float).apply(math.radians)\n",
#     925     "    radians_data = pd.concat([radians_y,radians_x],axis=1)\n",
#     926     "    radians_y = predictions.loc[:,lat_column].astype(float).apply(math.radians)\n",
#     927     "    radians_x = predictions.loc[:,long_column].astype(float).apply(math.radians)\n",
#     928     "    radians_predictions = pd.concat([radians_y,radians_x],axis=1)\n",
#     929     "    distances = haversine_distances(radians_predictions,radians_data)*6371\n",
#     930     "    \n",
#     931     "\n",
#     932     "    for i in range(len(predictions)):\n",
#     933     "#         data1 = data.loc[(data['x'] == predictions.loc[i,'x']) & (data['y'] == predictions.loc[i,'y'])]\n",
#     934     "        indexes = np.where(distances[i,:] <= radius)[0].tolist()\n",
#     935     "        data1 = data.loc[indexes,:].reset_index(drop=True)\n",
#     936     "        y = np.nan\n",
#     937     "        d = np.nan\n",
#     938     "        if len(data1)>0:\n",
#     939     "            date =  predictions.loc[i,'dt_prediction']\n",
#     940     "            diff = ((data1['dt_placement'] + datetime.timedelta(days=15)) - date).dt.days\n",
#     941     "            indexmin = diff.abs().idxmin()\n",
#     942     "            y = data1.loc[indexmin,'mosq_now']\n",
#     943     "            d = diff[indexmin]\n",
#     944     "            diff = diff.drop(indexmin)\n",
# ...
#     455     "                   'lst_apr_day_mean', 'lst_apr_night_mean',\n",
#     456     "                   'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan',]\n",
#     457     "\n",
#     458     "        geomorphological = ['DISTANCE_TO_COAST', 'DISTANCE_TO_RIVER', 'SLOPE_mean_1km', 'ASPECT_mean_200m',\n",
#     459     "                            'ELEVATION_mean_1km', 'HILLSHADE_mean_1km', 'FS_AREA_1km', 'FLOW_ACCU_200m', 'landcover']\n",
#     460     "\n",
#     461     "        spatiotemporal = ['x', 'y', 'year''null_island_distance', 'vert_distance',\n",
#     462     "                          'days_distance', 'mo_sin', 'mo_cos', 'year',  'summer_days_month']\n",
#     463     "\n",
#     464     "        entomological = ['mosq_sum_month', 'mosq_sum_month_previous_year', 'mosq_sum_year',\n",
#     465     "                         'mosq_sum_previous_2weeks', 'previous_mosq_measure',]\n",
#     466     "\n",
#     467     "        df_indicies = fi_df.loc[fi_df['feature_names'].isin(indicies)]\n",
#     468     "        df_weather = fi_df.loc[fi_df['feature_names'].isin(weather)]\n",
#     469     "        df_geomorphological = fi_df.loc[fi_df['feature_names'].isin(geomorphological)]\n",
#     470     "        df_spatiotemporal = fi_df.loc[fi_df['feature_names'].isin(spatiotemporal)]\n",
#     471     "        df_entomological = fi_df.loc[fi_df['feature_names'].isin(entomological)]\n",
#     472     "\n",
#     473     "        categories = {'Category': ['rs_indicies', 'weather', 'geomorphological', 'spatiotemporal', 'entomological'],\n",
#     474     "\n",
#     475     "                      'Mean_fi': [df_indicies.feature_importance.sum(),\n",
#     476     "                                  df_weather.feature_importance.sum(),\n",
#     477     "                                  df_geomorphological.feature_importance.sum(),\n",
#     478     "                                  df_spatiotemporal.feature_importance.sum(),\n",
#     479     "                                  df_entomological.feature_importance.sum()]}\n",
#     480     "\n",
#     481     "        categories_df = pd.DataFrame.from_dict(categories)\n",
#     482     "\n",
#     483     "        categories_df = categories_df.loc[(categories_df!=0).all(axis=1)].reset_index(drop=True)\n",
#     484     "        categories_df = categories_df.dropna().reset_index(drop=True)\n",
#     485     "\n",
#     486     "        categories_df.sort_values(by = 'Mean_fi', ascending=False)\n",
#     487     "\n",
#     488     "\n",
#     489     "        #Sort the DataFrame in order decreasing feature importance\n",
#     490     "        categories_df.sort_values(by=['Mean_fi'], ascending=False,inplace=True)\n",
#     491     "\n",
#     492     "        #Define size of bar plot\n",
#     493     "        plt.figure(figsize=(10,8))\n",
#     494     "\n",
#     495     "        #Plot Searborn bar chart\n",
#     496     "        sns.barplot(x=categories_df['Mean_fi'], y=categories_df['Category'])\n",
#     497     "\n",
#     498     "        #Add chart labels\n",
#     499     "        plt.xlabel('Feature Importance')\n",
#     500     "        plt.ylabel('Feature Category')\n",
#     501     "        plt.show()\n",
#     502     "        \n",
#     503     "        categories = {'Category': ['rs_indicies', 'weather', 'geomorphological', 'spatiotemporal', 'entomological'],\n",
#     504     "\n",
#     505     "                      'Mean_fi': [df_indicies.feature_importance.mean(),\n",
#     506     "                                  df_weather.feature_importance.mean(),\n",
#     507     "                                  df_geomorphological.feature_importance.mean(),\n",
#     508     "                                  df_spatiotemporal.feature_importance.mean(),\n",
#     509     "                                  df_entomological.feature_importance.mean()]}\n",
#     510     "\n",
#     511     "        categories_df = pd.DataFrame.from_dict(categories)\n",
#     512     "\n",
#     513     "        categories_df = categories_df.loc[(categories_df!=0).all(axis=1)].reset_index(drop=True)\n",
#     514     "        categories_df = categories_df.dropna().reset_index(drop=True)\n",
#     515     "\n",
#     516     "        categories_df.sort_values(by = 'Mean_fi', ascending=False)\n",
#     517     "\n",
#     518     "\n",
#     519     "        #Sort the DataFrame in order decreasing feature importance\n",
#     520     "        categories_df.sort_values(by=['Mean_fi'], ascending=False,inplace=True)\n",
#     521     "\n",
#     522     "        #Define size of bar plot\n",
#     523     "        plt.figure(figsize=(10,8))\n",
#     524     "\n",
#     525     "        #Plot Searborn bar chart\n",
#     526     "        sns.barplot(x=categories_df['Mean_fi'], y=categories_df['Category'])\n",
#     527     "\n",
#     528     "        #Add chart labels\n",
#     529     "        plt.xlabel('Feature Importance')\n",
#     530     "        plt.ylabel('Feature Category')\n",
#     531     "        plt.show()"
#     532    ]
#     533   },
#     534   {
#     535    "cell_type": "code",
#     536    "execution_count": 12,
#     537    "id": "006cad2f",
#     538    "metadata": {},
#     539    "outputs": [],
#     540    "source": [
#     541     "def train_xgboost(xg_model, train_X, train_y, test_X, test_y, max_val, fi=True):\n",
#     542     "    \"\"\" Trainning of the model\n",
#     543     "    \n",
#     544     "    Parameters\n",
#     545     "    ----------\n",
#     546     "    model : FeedforwardNeuralNetModel\n",
#     547     "        A FeedforwardNeuralNetModel model\n",
#     548     "        \n",
#     549     "    train_set : Dataset\n",
#     550     "        A Dataset object with the train set\n",
#     551     "        \n",
#     552     "    test_set : Dataset\n",
#     553     "        A Dataset object with the test set\n",
#     554     "        \n",
#     555     "    learning_rate : int, optional\n",
#     556     "        The learning_rate of the training process. (default = None)\n",
#     557     "        \n",
#     558     "    epochs : int, optional\n",
#     559     "        The number of epochs for the training. (default = None)\n",
#     560     "        \n",
#     561     "    batch_size : int, optional\n",
#     562     "        The size of each batch in each iteration. (default = None)\n",
#     563     "        \n",
#     564     "    ealry_stop : tuple, optional\n",
#     565     "        Set the (tolerance,min_dleta), the trainning of the model may stop earlier than the epochs defined. (default = None)\n",
#     566     "        \n",
#     567     "    Returns\n",
#     568     "    ----------\n",
#     569     "    results_train: DataFrame\n",
#     570     "        A Dataframe containing the actual and the predicted values on the train set\n",
#     571     "        \n",
#     572     "    results_test: DataFrame\n",
#     573     "        A Dataframe containing the actual and the predicted values on the test set\n",
#     574     "        \n",
#     575     "    model : FeedforwardNeuralNetModel\n",
#     576     "        A trained FeedforwardNeuralNetModel model \n",
#     577     "    \"\"\"\n",
#     578     "    weights=None\n",
#     579     "    if xg_model.weights:\n",
#     580     "        b_val = train_y.mean().item()\n",
#     581     "        weights = [sigmoid(train_y[i],0.005,b=b_val) for i in range(int(train_X.shape[0]))]\n",
#     582     "    \n",
#     583     "    if xg_model.features is None:\n",
#     584     "        xg_model.tune_parameters(train_X, train_y, flag=True)\n",
#     585     "        xg_model.select_features(train_X, train_y, grid=False)\n",
#     586     "    \n",
#     587     "    train_X = train_X[xg_model.features]\n",
#     588     "    test_X = test_X[xg_model.features]\n",
#     589     "\n",
#     590     "    xgb_params = {'n_estimators': xg_model.estimators,\n",
#     591     "                  'max_depth': xg_model.depth}\n",
#     592     "    xg_model.model.set_params(**xgb_params)\n",
#     593     "#     eval_set = [(test_X, test_y)]\n",
#     594     "    xg_model.model.fit(train_X, train_y, sample_weight = weights)\n",
#     595     "#                        ,early_stopping_rounds=10, eval_metric=\"mae\", eval_set=eval_set)    \n",
#     596     "    predictions = xg_model.model.predict(test_X)\n",
#     597     "    predictions_train = xg_model.model.predict(train_X)\n",
#     598     "    \n",
#     599     "    if 'normalization' in xg_model.transformation_list:\n",
#     600     "        predictions = denormalizeData(predictions, max_val=max_val)\n",
#     601     "        predictions_train = denormalizeData(predictions_train, max_val=max_val)\n",
#     602     "        train_y = denormalizeData(train_y, max_val=max_val)\n",
#     603     "        test_y = denormalizeData(test_y, max_val=max_val)\n",
#     604     "        \n",
#     605     "    if 'log' in xg_model.transformation_list:\n",
#     606     "        predictions = expData(predictions)\n",
#     607     "        predictions_train = expData(predictions_train)\n",
#     608     "        train_y = expData(train_y)\n",
#     609     "        test_y = expData(test_y)\n",
#     610     "        \n",
#     611     "    predictions =  np.round(predictions)  \n",
#     612     "    predictions_train = np.round(predictions_train)\n",
#     613     "        \n",
#     614     "    results_train = {'actual': train_y, 'prediction': predictions_train}\n",
#     615     "    results_train = pd.DataFrame.from_dict(results_train)\n",
#     616     "    \n",
#     617     "    results_test = {'actual': test_y, 'prediction': predictions}\n",
#     618     "    results_test = pd.DataFrame.from_dict(results_test)\n",
#     619     "    \n",
#     620     "    results_test.loc[results_test['prediction'] < 0,'prediction'] = 0\n",
#     621     "    results_test.loc[results_test['prediction'] > max_val,'prediction'] = max_val\n",
#     622     "    results_train.loc[results_train['prediction'] < 0,'prediction'] = 0\n",
#     623     "    results_train.loc[results_train['prediction'] > max_val,'prediction'] = max_val\n",
#     624     "    \n",
#     625     "    if fi:\n",
#     626     "        xg_model.plot_feature_importance()\n",
#     627     "    \n",
#     628     "    return results_train, results_test"
#     629    ]
#     630   },
#     631   {
#     632    "cell_type": "code",
#     633    "execution_count": null,
#     634    "id": "cb9d6320",
#     635    "metadata": {},
#     636    "outputs": [],
#     637    "source": [
#     638     "def predict_xgboost(xg_model, train_X, train_y, test_X, test_y, max_val, fi=True):\n",
#     639     "    \"\"\" Trainning of the model\n",
#     640     "    \n",
#     641     "    Parameters\n",
#     642     "    ----------\n",
#     643     "    model : FeedforwardNeuralNetModel\n",
#     644     "        A FeedforwardNeuralNetModel model\n",
#     645     "        \n",
#     646     "    Returns\n",
#     647     "    ----------\n",
#     648     "    results_train: DataFrame\n",
#     649     "        A Dataframe containing the actual and the predicted values on the train set\n",
#     650     "        \n",
#     651     "    results_test: DataFrame\n",
#     652     "        A Dataframe containing the actual and the predicted values on the test set\n",
#     653     "        \n",
#     654     "    model : FeedforwardNeuralNetModel\n",
#     655     "        A trained FeedforwardNeuralNetModel model \n",
#     656     "    \"\"\"\n",
#     657     "    \n",
#     658     "    weights=None\n",
#     659     "    if xg_model.weights:\n",
#     660     "        b_val = train_y.mean().item()\n",
#     661     "        weights = [sigmoid(train_y[i],0.005,b=b_val) for i in range(int(train_X.shape[0]))]\n",
#     662     "        \n",
#     663     "    if xg_model.features is None:\n",
#     664     "        xg_model.tune_parameters(train_X, train_y, flag=True)\n",
#     665     "        xg_model.select_features(train_X, train_y, grid=False)\n",
#     666     "    \n",
#     667     "    train_X = train_X[xg_model.features]\n",
#     668     "    test_X = test_X[xg_model.features]\n",
#     669     "\n",
#     670     "    xg_model.model.fit(train_X, train_y, sample_weight = weights)\n",
#     671     "    predictions = xg_model.model.predict(test_X)\n",
#     672     "    \n",
#     673     "    if 'normalization' in xg_model.transformation_list:\n",
#     674     "        predictions = denormalizeData(predictions, max_val=max_val)\n",
#     675     "\n",
#     676     "    if 'log' in xg_model.transformation_list:\n",
#     677     "        predictions = expData(predictions)\n",
#     678     "\n",
#     679     "    predictions =  np.round(predictions)  \n",
#     680     "\n",
#     681     "    results_test = {'prediction': predictions}\n",
#     682     "    results_test = pd.DataFrame.from_dict(results_test)\n",
#     683     "    \n",
#     684     "    results_test.loc[results_test['prediction'] < 0,'prediction'] = 0\n",
#     685     "    results_test.loc[results_test['prediction'] > max_val,'prediction'] = max_val\n",
#     686     "    \n",
#     687     "    if fi:\n",
#     688     "        xg_model.plot_feature_importance()\n",
#     689     "   \n",
#     690     "    return results_test"
#     691    ]
#     692   }
#     693  ],
#     694  "metadata": {
#     695   "kernelspec": {
#     696    "display_name": "Python 3 (ipykernel)",
#     697    "language": "python",
#     698    "name": "python3"
#     699   },
#     700   "language_info": {
#     701    "codemirror_mode": {
#     702     "name": "ipython",
#     703     "version": 3
#     704    },
#     705    "file_extension": ".py",
#     706    "mimetype": "text/x-python",
#     707    "name": "python",
#     708    "nbconvert_exporter": "python",
#     709    "pygments_lexer": "ipython3",
#     710    "version": "3.11.4"
#     711   }
#     712  },
#     713  "nbformat": 4,
#     714  "nbformat_minor": 5
#     715 }
#
# File ~\anaconda3\envs\noa3\Lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~\anaconda3\envs\noa3\Lib\site-packages\xgboost\sklearn.py:1025, in XGBModel.fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#    1014     obj = None
#    1016 (
#    1017     model,
#    1018     metric,
#    (...)
#    1023     xgb_model, eval_metric, params, early_stopping_rounds, callbacks
#    1024 )
# -> 1025 self._Booster = train(
#    1026     params,
#    1027     train_dmatrix,
#    1028     self.get_num_boosting_rounds(),
#    1029     evals=evals,
#    1030     early_stopping_rounds=early_stopping_rounds,
#    1031     evals_result=evals_result,
#    1032     obj=obj,
#    1033     custom_metric=metric,
#    1034     verbose_eval=verbose,
#    1035     xgb_model=model,
#    1036     callbacks=callbacks,
#    1037 )
#    1039 self._set_evaluation_result(evals_result)
#    1040 return self
#
# File ~\anaconda3\envs\noa3\Lib\site-packages\xgboost\core.py:620, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     618 for k, arg in zip(sig.parameters, args):
#     619     kwargs[k] = arg
# --> 620 return func(**kwargs)
#
# File ~\anaconda3\envs\noa3\Lib\site-packages\xgboost\training.py:185, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     183 if cb_container.before_iteration(bst, i, dtrain, evals):
#     184     break
# --> 185 bst.update(dtrain, i, obj)
#     186 if cb_container.after_iteration(bst, i, dtrain, evals):
#     187     break
#
# File ~\anaconda3\envs\noa3\Lib\site-packages\xgboost\core.py:1918, in Booster.update(self, dtrain, iteration, fobj)
#    1915 self._validate_dmatrix_features(dtrain)
#    1917 if fobj is None:
# -> 1918     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1919                                             ctypes.c_int(iteration),
#    1920                                             dtrain.handle))
#    1921 else:
#    1922     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
#=====================================================================
# Automation models without or with/without entomological data
#=====================================================================

# Spit to train and test based on date of predictions
test = data.loc[data[date_col] >= pd.to_datetime(date)]
data = data.loc[data[date_col] < pd.to_datetime(date)]

# Delete from test set stations that are not used during the last 3 years
# test = unused_stations(data, test, period=3)

#Remove features that are more 40% filled with nan values in the test set
data, test = remove_nan_features(data, test, 0.3)

# set the only_env as True if there are no mosquitoes for the forecast month
only_env=None    
if len(test.dropna(subset=['mosq_sum_month', 'mosq_sum_month_previous_year', 'mosq_sum_year',
                           'mosq_sum_previous_2weeks','previous_mosq_measure']).drop(columns=['mosq_now']).dropna())>0:
    only_env=False
elif len(test.drop(columns=['mosq_sum_month', 'mosq_sum_month_previous_year', 'mosq_sum_year',
                           'mosq_sum_previous_2weeks', 'previous_mosq_measure', 'mosq_now']).dropna())>0:
    only_env=True
else:
    print('No data left for prediction')
    

learning_rate = 0.3
# set the early stop argument as early_stop = (tolerance, min_delta)
early_stop = None
#set the transformation actions on the data. Options are 'augmentation', 'normalization', 'log', 'scaling'
transformation_list = []
#set the data for embeddings e.g. data[['col', 'col2']]
embedded_data = None
#set the boolean for plotting feature importance (!very time consuming!)
fi = False
    
if only_env != None:
    # Run first without entomological features
    print("#===========================================")
    print("Predictions without entomological features")
    print("#===========================================")
    print()
    data_env = data.drop(['mosq_sum_month', 'mosq_sum_month_previous_year', 'mosq_sum_year',
                          'mosq_sum_previous_2weeks', 'previous_mosq_measure'], axis = 1)
    test_env = test.drop(['mosq_sum_month', 'mosq_sum_month_previous_year', 'mosq_sum_year',
                          'mosq_sum_previous_2weeks', 'previous_mosq_measure'], axis = 1)
    
    data_env = data_env.dropna().reset_index(drop=True)
    test_env = test_env.dropna(subset=test_env.columns.difference(['mosq_now'])).reset_index(drop=True)

    model = Xgboost_model(model_type = model_type, learning_rate = learning_rate,
                          embedding_data = embedded_data,  transformation_list = transformation_list,
                          early_stop = False, l1_weight = 0, l2_weight = 0, weights = False)
    
    evaluate_xgboost(model, data_env, fi = fi)

    predictions_env = give_predictions_xgboost(model, data_env, test_env, env = True, filepath = path, case = title,
                                               fi = fi, export = only_env)
    
    model.plot_feature_importance()
# Out:
# #===========================================
# Predictions without entomological features
# #===========================================
# max_depth:  10
# Number of estimators:  8
# Selected_features:  Index(['acc_rainfall_jan', 'ELEVATION_mean_1km', 'null_island_distance',
#        'days_distance', 'mo_cos', 'year'],
#       dtype='object')
# MAE on train set:  0.439773171685569
# min prediction: 0.0
# max prediction: 9.0
#
# MAE on test set:  0.8326817826426895
# Error <= 3: 95.78 %
# min prediction: 0.0
# max prediction: 8.0
# -----------|class error-MAE| difference-----------
# mean: 0.7047848015717808
# std: 0.3855869384459366
# coefficient of variation (std/mean): 0.5470988273101479
#
# ----------normalized difference-------------
# mean: 0.5638278412574247
# std: 0.3084695507567493
# max_depth:  9
# Number of estimators:  18
# Selected_features:  Index(['acc_rainfall_jan', 'null_island_distance', 'days_distance', 'mo_cos',
#        'year'],
#       dtype='object')
# prediction
# -0.0     999
#  1.0    1596
#  2.0    1110
#  3.0     229
#  4.0     472
#  5.0     692
#  6.0     193
#  7.0      94
#  8.0      63
#  9.0       4
# Name: count, dtype: int64
#
# Low risk category stations: 2595
# Medium risk category stations: 2503
# High risk category stations: 354
