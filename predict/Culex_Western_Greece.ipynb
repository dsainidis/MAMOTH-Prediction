# %%
from Preprocessing_Module import read_data, add_topological, add_landcover, merge_new_data, fill_data, select_columns, reshape_dataset, fillna_dataset, remove_nan_features, unused_stations
from Feature_Expansion_Module import feature_expansion
from Initializer_Module import initializer
from XGboost_Model_Module import Xgboost_model
from Neural_Network_Module import FeedforwardNeuralNetModel
from Model_Validation_Module import give_predictions_nn, evaluate_nn, give_predictions_xgboost, evaluate_xgboost, validate_results, merge_predictions
import numpy as np
import pandas as pd
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
import warnings
warnings.filterwarnings('ignore')
np.set_printoptions(suppress=True)

# %%
data = read_data('../Datasets/Greece/GRE_culex_2011_2023.csv')
data = merge_new_data('../Datasets/Greece/monthly_data/GRE_culex_ento_2024_09_processed.csv', data)
data = merge_new_data('../Datasets/Greece/monthly_data/GRE_env_2024_10_2km_processed.csv', data)
#=====================================================================
data = data[(data.nuts2_name == 'WESTERN GREECE') | (data.nuts2_name == 'Π. ΔΥΤΙΚΗΣ ΕΛΛΑΔΑΣ')]
data = data.reset_index(drop=True)
#=====================================================================
columns = ['dt_placement', 'x', 'y', 'culex spp.', 'ndvi', 'ndwi', 'ndmi', 'ndbi',
           'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean',
           'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day', 'lst_night',
           'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan',
           'lst_jan_day_mean', 'lst_feb_day_mean', 'lst_mar_day_mean', 'lst_apr_day_mean',
           'lst_jan_night_mean', 'lst_feb_night_mean', 'lst_mar_night_mean', 'lst_apr_night_mean']
names = ['dt_placement', 'x', 'y', 'mosq_now', 'ndvi', 'ndwi', 'ndmi', 'ndbi',
         'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean',
         'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day', 'lst_night',
         'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan',
         'lst_jan_day_mean', 'lst_feb_day_mean', 'lst_mar_day_mean', 'lst_apr_day_mean',
         'lst_jan_night_mean', 'lst_feb_night_mean', 'lst_mar_night_mean', 'lst_apr_night_mean']
data = add_topological(data,'../Datasets/Topological Datasets/2x2grid/greece_2km_geo.csv')
data = add_landcover(data,'../Datasets/Landcover Datasets/2x2grid/greece_2km_lulc.csv')
data = select_columns(data,columns,names)
data = fillna_dataset(data,{'acc_rainfall_1week':0, 'acc_rainfall_2week':0, 'acc_rainfall_jan':0})
data = reshape_dataset(data,['x','y','dt_placement'])
# Out:
# Index(['trap_id', 'station_id', 'x', 'y', 'dt_placement', 'week', 'month',
#        'year', 'country_code', 'nuts0_code', 'nuts0_name', 'nuts1_code',
#        'nuts1_name', 'nuts2_code', 'nuts2_name', 'nuts3_code', 'nuts3_name',
#        'lau1_municipality', 'lau2_settlement', 'trap_type', 'culex spp.',
#        'region', 'dt_placement_original', 'indices_image_date', 'indices_lat',
#        'indices_lon', 'ndvi', 'ndmi', 'ndwi', 'ndbi', 'ndvi_mean', 'ndmi_mean',
#        'ndwi_mean', 'ndbi_mean', 'ndvi_std', 'ndmi_std', 'ndwi_std',
#        'ndbi_std', 'lst_image_date', 'lst_lat', 'lst_lon', 'lst_day',
#        'lst_night', 'monthly_lst_lat', 'monthly_lst_lon', 'lst_jan_day_mean',
#        'lst_jan_night_mean', 'lst_feb_day_mean', 'lst_feb_night_mean',
#        'lst_mar_day_mean', 'lst_mar_night_mean', 'lst_apr_day_mean',
#        'lst_apr_night_mean', 'indices_image_date.1', 'indices_lat.1',
#        'indices_lon.1', 'acc_rainfall_jan', 'dt_placement_minus_7',
#        'dt_placement_minus_14', 'dt_placement_minus_7_avail',
#        'dt_placement_minus_14_avail', 'acc_rainfall_1week',
#        'acc_rainfall_2week', 'id', 'trapid_region', 'trapid', 'unique_code',
#        'oldid', 'culex pipiens'],
#       dtype='object')

# %%
# set the date of prediction for the test set
date = '2024-10-01'

# set the filename for export
case = 'Culex_Greece_WG_'

# set the filename to export
path = './predictions/Greece/Western_Greece/'

title = date[:-3].replace('-','_')
title = case + title

# set the name of the date column
date_col = 'dt_placement'
# set the model type. Could be 'class_regression' or 'mosquito_regression' or 'classification'
model_type = 'class_regression'

# %%
data = feature_expansion(data)

# %%
data = initializer(data, model_type, 10, flag=True)
# Out:
# Bounds: [0, 1.0, 2.0, 4.0, 7.0, 11.0, 17.0, 26.0, 40.0, 74.0, 2973.0]

# %%
print("#===========================================")
print("Performance of the previous month")
print("#===========================================")
print()
validate_results(path+case + date[:-3].replace(date[:-3].split('-')[1],str(int(date[:-3].split('-')[1])-1)).replace('-','_')+'.csv',data)
# Out:
# #===========================================
# Performance of the previous month
# #===========================================
#
# Mean time difference in days: -1.0
# -------------------
# Overall MAE: 2.1875
# Overall % error <=3: 81.25
# number of observations: 32
# -------------------
# MAE without entomological: 2.1875
# % error <=3 without entomological: 81.25
# number of observations: 32
# -------------------

# %%
#=====================================================================
# Automation models without or with/without entomological data
#=====================================================================

# Spit to train and test based on date of predictions
test = data.loc[data[date_col] >= pd.to_datetime(date)]
data = data.loc[data[date_col] < pd.to_datetime(date)]

# Delete from test set stations that are not used during the last 3 years
# test = unused_stations(data, test, period=3)

#Remove features that are more 40% filled with nan values in the test set
data, test = remove_nan_features(data, test, 0.4)

# set the only_env as True if there are no mosquitoes for the forecast month
only_env=None    
if len(test.dropna(subset=['mosq_sum_month', 'mosq_sum_month_previous_year', 'mosq_sum_year',
                           'mosq_sum_previous_2weeks','previous_mosq_measure']).drop(columns=['mosq_now']).dropna())>0:
    only_env=False
elif len(test.drop(columns=['mosq_sum_month', 'mosq_sum_month_previous_year', 'mosq_sum_year',
                           'mosq_sum_previous_2weeks', 'previous_mosq_measure', 'mosq_now']).dropna())>0:
    only_env=True
else:
    print('No data left for prediction')
    
num_class = 1
hidden_layers = [264,128,128,64,32]
learning_rate = 0.001
epochs = 50
batch_size = 128
dropout = 0.2
# set the early stop argument as early_stop = (tolerance, min_delta)
early_stop = None
#set the transformation actions on the data. Options are 'augmentation', 'normalization', 'log', 'scaling'
transformation_list = ['scaling']
#set the data for embeddings e.g. data[['col', 'col2']]
embedded_data = None
#set the boolean for plotting feature importance (!very time consuming!)
fi = False
    
if only_env != None:
    # Run first without entomological features
    print("#===========================================")
    print("Predictions without entomological features")
    print("#===========================================")
    print()
    data_env = data.drop(['mosq_sum_month', 'mosq_sum_month_previous_year', 'mosq_sum_year',
                          'mosq_sum_previous_2weeks', 'previous_mosq_measure'], axis = 1)
    test_env = test.drop(['mosq_sum_month', 'mosq_sum_month_previous_year', 'mosq_sum_year',
                          'mosq_sum_previous_2weeks', 'previous_mosq_measure'], axis = 1)

    data_env = data_env.dropna().reset_index(drop=True)
    test_env = test_env.dropna(subset=test_env.columns.difference(['mosq_now'])).reset_index(drop=True)

    
    model = FeedforwardNeuralNetModel(num_features=len(data_env.iloc[0,:])-2, num_class=num_class,
                                      hidden_layers = hidden_layers, model_type=model_type,
                                      learning_rate = learning_rate, epochs = epochs, batch_size = batch_size,
                                      dropout = dropout, embedding_data=embedded_data, 
                                      transformation_list=transformation_list, early_stop = early_stop, 
                                      l1_weight=0, l2_weight=0, weights=False)

    evaluate_nn(model, data_env, fi = fi)

    predictions_env = give_predictions_nn(model, data_env, test_env, env = True, filepath = path, case = title,
                                          export = only_env)

    # Run with entomological features if at least one station has mosquitos number
    if not only_env:
        print("#===========================================")
        print("Predictions with entomological features")
        print("#===========================================")
        print()
        
        data_entom = data.dropna().reset_index(drop=True)
        test_entom = test.dropna(subset=test.columns.difference(['mosq_now'])).reset_index(drop=True)
        
        model = FeedforwardNeuralNetModel(num_features=len(data_entom.iloc[0,:])-2, num_class=num_class,
                                          hidden_layers = hidden_layers, model_type=model_type,
                                          learning_rate = learning_rate, epochs = epochs, batch_size = batch_size,
                                          dropout = dropout, embedding_data=embedded_data, 
                                          transformation_list=transformation_list, early_stop = early_stop, 
                                          l1_weight=0, l2_weight=0, weights=False)
        
        evaluate_nn(model, data_entom, fi = fi)

        predictions_entom = give_predictions_nn(model, data_entom, test_entom, env = False, filepath = path,
                                                case = title, export = False)

        print("#===========================================")
        print("Predictions with/without entomological features")
        print("#===========================================")
        merge_predictions(predictions_env,predictions_entom,path,title,export=True)
# Out:
# #===========================================
# Predictions without entomological features
# #===========================================
#
# Epoch 001: | Train Loss: 24.34787 | Val Loss: 24.13898 | Train Acc: 4.084| Val Acc: 4.132
# Epoch 002: | Train Loss: 20.97701 | Val Loss: 19.56996 | Train Acc: 3.746| Val Acc: 3.643
# Epoch 003: | Train Loss: 18.33822 | Val Loss: 16.70943 | Train Acc: 3.465| Val Acc: 3.334
# Epoch 004: | Train Loss: 16.19809 | Val Loss: 14.06023 | Train Acc: 3.238| Val Acc: 3.010
# Epoch 005: | Train Loss: 14.47667 | Val Loss: 12.12932 | Train Acc: 3.050| Val Acc: 2.800
# Epoch 006: | Train Loss: 12.98012 | Val Loss: 10.52251 | Train Acc: 2.861| Val Acc: 2.577
# Epoch 007: | Train Loss: 11.81190 | Val Loss: 9.77952 | Train Acc: 2.721| Val Acc: 2.464
# Epoch 008: | Train Loss: 10.89033 | Val Loss: 9.11274 | Train Acc: 2.617| Val Acc: 2.380
# Epoch 009: | Train Loss: 10.31416 | Val Loss: 8.67396 | Train Acc: 2.534| Val Acc: 2.313
# Epoch 010: | Train Loss: 9.46501 | Val Loss: 8.27995 | Train Acc: 2.435| Val Acc: 2.262
# Epoch 011: | Train Loss: 8.89889 | Val Loss: 8.03886 | Train Acc: 2.363| Val Acc: 2.262
# Epoch 012: | Train Loss: 8.84546 | Val Loss: 7.89726 | Train Acc: 2.335| Val Acc: 2.221
# Epoch 013: | Train Loss: 8.23484 | Val Loss: 7.78173 | Train Acc: 2.263| Val Acc: 2.201
# Epoch 014: | Train Loss: 8.21719 | Val Loss: 7.60954 | Train Acc: 2.266| Val Acc: 2.186
# Epoch 015: | Train Loss: 7.87537 | Val Loss: 7.39909 | Train Acc: 2.242| Val Acc: 2.176
# Epoch 016: | Train Loss: 7.78545 | Val Loss: 7.35169 | Train Acc: 2.217| Val Acc: 2.162
# Epoch 017: | Train Loss: 7.72302 | Val Loss: 7.22179 | Train Acc: 2.205| Val Acc: 2.152
# Epoch 018: | Train Loss: 7.40155 | Val Loss: 7.05485 | Train Acc: 2.151| Val Acc: 2.129
# Epoch 019: | Train Loss: 7.58673 | Val Loss: 7.08541 | Train Acc: 2.194| Val Acc: 2.121
# Epoch 020: | Train Loss: 7.37847 | Val Loss: 6.96098 | Train Acc: 2.150| Val Acc: 2.080
# Epoch 021: | Train Loss: 7.22486 | Val Loss: 6.77800 | Train Acc: 2.140| Val Acc: 2.058
# Epoch 022: | Train Loss: 6.93802 | Val Loss: 6.64438 | Train Acc: 2.094| Val Acc: 2.064
# Epoch 023: | Train Loss: 6.85454 | Val Loss: 6.60806 | Train Acc: 2.074| Val Acc: 2.060
# Epoch 024: | Train Loss: 6.94442 | Val Loss: 6.50216 | Train Acc: 2.101| Val Acc: 2.060
# Epoch 025: | Train Loss: 6.77934 | Val Loss: 6.37516 | Train Acc: 2.040| Val Acc: 2.037
# Epoch 026: | Train Loss: 6.65974 | Val Loss: 6.22067 | Train Acc: 2.071| Val Acc: 2.006
# Epoch 027: | Train Loss: 6.55719 | Val Loss: 6.19595 | Train Acc: 2.047| Val Acc: 1.994
# Epoch 028: | Train Loss: 6.60317 | Val Loss: 6.11935 | Train Acc: 2.032| Val Acc: 1.990
# Epoch 029: | Train Loss: 6.22692 | Val Loss: 5.95367 | Train Acc: 1.990| Val Acc: 1.962
# Epoch 030: | Train Loss: 6.20570 | Val Loss: 5.82016 | Train Acc: 2.008| Val Acc: 1.951
# Epoch 031: | Train Loss: 6.01587 | Val Loss: 5.76321 | Train Acc: 1.977| Val Acc: 1.912
# Epoch 032: | Train Loss: 6.01248 | Val Loss: 5.79942 | Train Acc: 1.989| Val Acc: 1.933
# Epoch 033: | Train Loss: 5.63405 | Val Loss: 5.68593 | Train Acc: 1.900| Val Acc: 1.898
# Epoch 034: | Train Loss: 5.58031 | Val Loss: 5.65199 | Train Acc: 1.900| Val Acc: 1.896
# Epoch 035: | Train Loss: 5.49578 | Val Loss: 5.70869 | Train Acc: 1.888| Val Acc: 1.908
# Epoch 036: | Train Loss: 5.40558 | Val Loss: 5.72074 | Train Acc: 1.857| Val Acc: 1.914
# Epoch 037: | Train Loss: 5.53351 | Val Loss: 5.67678 | Train Acc: 1.889| Val Acc: 1.902
# Epoch 038: | Train Loss: 5.42839 | Val Loss: 5.65826 | Train Acc: 1.858| Val Acc: 1.919
# Epoch 039: | Train Loss: 5.29947 | Val Loss: 5.76020 | Train Acc: 1.843| Val Acc: 1.923
# Epoch 040: | Train Loss: 5.24333 | Val Loss: 5.71715 | Train Acc: 1.829| Val Acc: 1.915
# Epoch 041: | Train Loss: 5.43698 | Val Loss: 5.73144 | Train Acc: 1.877| Val Acc: 1.929
# Epoch 042: | Train Loss: 5.39787 | Val Loss: 5.68149 | Train Acc: 1.852| Val Acc: 1.921
# Epoch 043: | Train Loss: 5.18240 | Val Loss: 5.57599 | Train Acc: 1.813| Val Acc: 1.882
# Epoch 044: | Train Loss: 5.27151 | Val Loss: 5.66013 | Train Acc: 1.841| Val Acc: 1.892
# Epoch 045: | Train Loss: 5.10476 | Val Loss: 5.60262 | Train Acc: 1.805| Val Acc: 1.871
# Epoch 046: | Train Loss: 5.10972 | Val Loss: 5.60289 | Train Acc: 1.811| Val Acc: 1.904
# Epoch 047: | Train Loss: 5.07375 | Val Loss: 5.67963 | Train Acc: 1.793| Val Acc: 1.900
# Epoch 048: | Train Loss: 4.97194 | Val Loss: 5.64807 | Train Acc: 1.781| Val Acc: 1.874
# Epoch 049: | Train Loss: 4.82222 | Val Loss: 5.58670 | Train Acc: 1.728| Val Acc: 1.853
# Epoch 050: | Train Loss: 5.10869 | Val Loss: 5.54437 | Train Acc: 1.807| Val Acc: 1.865
# MAE on train set:  1.5367286973555339
# min prediction: 0
# max prediction: 8
#
# MAE on test set:  1.8649706457925637
# Error <= 3: 86.89 %
# min prediction: 1
# max prediction: 8
# -----------|class error-MAE| difference-----------
# mean: 0.8406258282877355
# std: 0.47695167245594655
# coefficient of variation (std/mean): 0.5673768951727856
#
# ----------normalized difference-------------
# mean: 0.570336107687844
# std: 0.3235955299848605
# prediction
# 0     14
# 1    200
# 2    471
# 3    492
# 4    531
# 5    459
# 6    336
# 7    236
# 8    132
# 9     86
# Name: count, dtype: int64
#
# Low risk category stations: 214
# Medium risk category stations: 1953
# High risk category stations: 790

# %%
#=====================================================================
# Automation models without or with/without entomological data
#=====================================================================

# Spit to train and test based on date of predictions
test = data.loc[data[date_col] >= pd.to_datetime(date)]
data = data.loc[data[date_col] < pd.to_datetime(date)]

# Delete from test set stations that are not used during the last 3 years
# test = unused_stations(data, test, period=3)

#Remove features that are more 40% filled with nan values in the test set
data, test = remove_nan_features(data, test, 0.3)

# set the only_env as True if there are no mosquitoes for the forecast month
only_env=None    
if len(test.dropna(subset=['mosq_sum_month', 'mosq_sum_month_previous_year', 'mosq_sum_year',
                           'mosq_sum_previous_2weeks','previous_mosq_measure']).drop(columns=['mosq_now']).dropna())>0:
    only_env=False
elif len(test.drop(columns=['mosq_sum_month', 'mosq_sum_month_previous_year', 'mosq_sum_year',
                           'mosq_sum_previous_2weeks', 'previous_mosq_measure', 'mosq_now']).dropna())>0:
    only_env=True
else:
    print('No data left for prediction')
    

learning_rate = 0.3
# set the early stop argument as early_stop = (tolerance, min_delta)
early_stop = None
#set the transformation actions on the data. Options are 'augmentation', 'normalization', 'log', 'scaling'
transformation_list = []
#set the data for embeddings e.g. data[['col', 'col2']]
embedded_data = None
#set the boolean for plotting feature importance (!very time consuming!)
fi = False
    
if only_env != None:
    # Run first without entomological features
    print("#===========================================")
    print("Predictions without entomological features")
    print("#===========================================")
    print()
    data_env = data.drop(['mosq_sum_month', 'mosq_sum_month_previous_year', 'mosq_sum_year',
                          'mosq_sum_previous_2weeks', 'previous_mosq_measure'], axis = 1)
    test_env = test.drop(['mosq_sum_month', 'mosq_sum_month_previous_year', 'mosq_sum_year',
                          'mosq_sum_previous_2weeks', 'previous_mosq_measure'], axis = 1)
    
    data_env = data_env.dropna().reset_index(drop=True)
    test_env = test_env.dropna(subset=test_env.columns.difference(['mosq_now'])).reset_index(drop=True)

    model = Xgboost_model(model_type = model_type, learning_rate = learning_rate,
                          embedding_data = embedded_data,  transformation_list = transformation_list,
                          early_stop = False, l1_weight = 0, l2_weight = 0, weights = False)
    
    evaluate_xgboost(model, data_env, fi = fi)

    predictions_env = give_predictions_xgboost(model, data_env, test_env, env = True, filepath = path, case = title,
                                               fi = fi, export = only_env)


    # Run with entomological features if at least one station has mosquitos number
    if not only_env:
        print("#===========================================")
        print("Predictions with entomological features")
        print("#===========================================")
        print()
        
        data_entom = data.dropna().reset_index(drop=True)
        test_entom = test.dropna(subset=test.columns.difference(['mosq_now'])).reset_index(drop=True)
        
        model = Xgboost_model(model_type = model_type, learning_rate = learning_rate,
                              embedding_data = embedded_data,  transformation_list = transformation_list,
                              early_stop = False, l1_weight = 0, l2_weight = 0, weights = False)
    
        evaluate_xgboost(model, data_entom, fi = fi)

        predictions_entom = give_predictions_xgboost(model, data_entom, test_entom, env = True, filepath = path,
                                                     fi = fi, case = title, export = only_env)

        print("#===========================================")
        print("Predictions with/without entomological features")
        print("#===========================================")
        merge_predictions(predictions_env,predictions_entom, path, title, export=True)
# Out:
# #===========================================
# Predictions without entomological features
# #===========================================
# max_depth:  7
# Number of estimators:  25
# Selected_features:  Index(['null_island_distance', 'days_distance', 'mo_cos', 'year', 'lst'], dtype='object')
# MAE on train set:  0.9816924328722538
# min prediction: -0.0
# max prediction: 9.0
#
# MAE on test set:  1.8747967479674796
# Error <= 3: 86.34 %
# min prediction: 0.0
# max prediction: 9.0
# -----------|class error-MAE| difference-----------
# mean: 0.6488557566441393
# std: 0.413039148092977
# coefficient of variation (std/mean): 0.6365654367146281
#
# ----------normalized difference-------------
# mean: 0.5096752166993238
# std: 0.3244416269008278
# max_depth:  8
# Number of estimators:  11
# Selected_features:  Index(['lst_night', 'acc_rainfall_1week', 'acc_rainfall_2week',
#        'acc_rainfall_jan', 'lst_jan_day_mean', 'lst_feb_day_mean',
#        'lst_mar_day_mean', 'lst_apr_day_mean', 'lst_jan_night_mean',
#        'lst_feb_night_mean', 'lst_mar_night_mean', 'lst_apr_night_mean',
#        'null_island_distance', 'days_distance', 'mo_cos', 'year', 'lst',
#        'summer_days_month'],
#       dtype='object')
# prediction
# 1.0      9
# 2.0    301
# 3.0    371
# 4.0    685
# 5.0    760
# 6.0    590
# 7.0    224
# 8.0     12
# Name: count, dtype: int64
#
# Low risk category stations: 9
# Medium risk category stations: 2117
# High risk category stations: 826
# #===========================================
# Predictions with entomological features
# #===========================================
# max_depth:  7
# Number of estimators:  26
# Selected_features:  Index(['lst_apr_day_mean', 'lst_jan_night_mean', 'lst_feb_night_mean',
#        'lst_mar_night_mean', 'lst_apr_night_mean', 'null_island_distance',
#        'days_distance', 'mo_cos', 'year', 'lst', 'summer_days_month',
#        'mosq_sum_month', 'mosq_sum_month_previous_year', 'mosq_sum_year',
#        'mosq_sum_previous_2weeks', 'previous_mosq_measure'],
#       dtype='object')
# MAE on train set:  0.7197716658017644
# min prediction: 0.0
# max prediction: 9.0
#
# MAE on test set:  1.954356846473029
# Error <= 3: 85.48 %
# min prediction: 0.0
# max prediction: 9.0
# -----------|class error-MAE| difference-----------
# mean: 0.8169386957939306
# std: 0.416585084180843
# coefficient of variation (std/mean): 0.509934327172482
#
# ----------normalized difference-------------
# mean: 0.6127040218454483
# std: 0.3124388131356324
# max_depth:  5
# Number of estimators:  34
# Selected_features:  Index(['lst_day', 'lst_night', 'acc_rainfall_1week', 'acc_rainfall_2week',
#        'acc_rainfall_jan', 'lst_jan_day_mean', 'lst_feb_day_mean',
#        'lst_mar_day_mean', 'lst_apr_day_mean', 'lst_jan_night_mean',
#        'lst_feb_night_mean', 'lst_mar_night_mean', 'lst_apr_night_mean',
#        'null_island_distance', 'days_distance', 'year', 'lst',
#        'summer_days_month', 'mosq_sum_month', 'mosq_sum_month_previous_year',
#        'mosq_sum_year', 'mosq_sum_previous_2weeks', 'previous_mosq_measure'],
#       dtype='object')
# prediction
# 3.0    5
# 4.0    8
# 5.0    7
# 6.0    1
# Name: count, dtype: int64
#
# Low risk category stations: 0
# Medium risk category stations: 20
# High risk category stations: 1
# #===========================================
# Predictions with/without entomological features
# #===========================================
# prediction
# 1.0      9
# 2.0    301
# 3.0    371
# 4.0    685
# 5.0    760
# 6.0    590
# 7.0    224
# 8.0     12
# Name: count, dtype: int64
#
# Low risk category stations: 9
# Medium risk category stations: 2117
# High risk category stations: 826
