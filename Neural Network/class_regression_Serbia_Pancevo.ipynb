# %%
import pandas as pd
import numpy as np
from ipynb.fs.defs.Preprocessing_Module import read_data, add_topological, add_landcover, select_columns, reshape_dataset, fillna_dataset
from ipynb.fs.defs.Feature_Expansion_Module import feature_expansion
from ipynb.fs.defs.Initializer_Module import initializer
from ipynb.fs.defs.Neural_Network_Module import FeedforwardNeuralNetModel
from ipynb.fs.defs.Model_Validation_Module import test_model_random_split, train_model_KFold, operational_validation
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
import warnings
warnings.filterwarnings('ignore')
np.set_printoptions(suppress=True)

# %%
data = read_data('../Datasets/Serbia/Pancevo/SER_pancevo_2015_2022.csv')
columns = ['x', 'y', 'dt_placement',
           'Total', 'ndvi', 'ndwi', 'ndmi', 'ndbi',
           'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean',
           'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day', 'lst_night',
           'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan',
           'lst_jan_day_mean', 'lst_feb_day_mean', 'lst_mar_day_mean', 'lst_apr_day_mean',
           'lst_jan_night_mean', 'lst_feb_night_mean', 'lst_mar_night_mean', 'lst_apr_night_mean' ]
names = ['x', 'y', 'dt_placement',
         'mosq_now', 'ndvi', 'ndwi', 'ndmi', 'ndbi',
         'ndvi_mean', 'ndvi_std', 'ndwi_mean', 'ndwi_std', 'ndmi_mean',
         'ndmi_std', 'ndbi_mean', 'ndbi_std', 'lst_day', 'lst_night',
         'acc_rainfall_1week', 'acc_rainfall_2week', 'acc_rainfall_jan',
         'lst_jan_day_mean', 'lst_feb_day_mean', 'lst_mar_day_mean', 'lst_apr_day_mean',
         'lst_jan_night_mean', 'lst_feb_night_mean', 'lst_mar_night_mean', 'lst_apr_night_mean']
data = select_columns(data,columns,names)
data = add_topological(data,'../Datasets/Topological Datasets/2x2grid/serbia_vojvodina_2km_geo.csv')
data = add_landcover(data,'../Datasets/Landcover Datasets/2x2grid/serbia_vojvodina_2km_lulc.csv')
data = reshape_dataset(data,['x','y','dt_placement'])
data = fillna_dataset(data,{'acc_rainfall_1week':0, 'acc_rainfall_2week':0, 'acc_rainfall_jan':0})
# Out:
# Index(['dt_placement_original', 'Location', 'GPS', 'Culex sp.', 'Aedes',
#        'Anopheles', 'Total', 'y', 'x', 'dt_placement', 'region', 'year',
#        'month', 'ndvi', 'ndmi', 'ndwi', 'ndbi', 'ndvi_mean', 'ndmi_mean',
#        'ndwi_mean', 'ndbi_mean', 'ndvi_std', 'ndmi_std', 'ndwi_std',
#        'ndbi_std', 'lst_day', 'lst_night', 'lst_jan_day_mean',
#        'lst_jan_night_mean', 'lst_feb_day_mean', 'lst_feb_night_mean',
#        'lst_mar_day_mean', 'lst_mar_night_mean', 'lst_apr_day_mean',
#        'lst_apr_night_mean', '1990_landcover', '2000_landcover',
#        '2006_landcover', '2012_landcover', '2018_landcover',
#        'acc_rainfall_jan', 'dt_placement_minus_7', 'dt_placement_minus_14',
#        'dt_placement_minus_7_avail', 'dt_placement_minus_14_avail',
#        'acc_rainfall_1week', 'acc_rainfall_2week'],
#       dtype='object')

# %%
# set the only_env as True if you want to use only environmental features
only_env = False
# set the case title
case_title = 'NN class regression'
# set the exp as True if you want to save the results as csv
exp = False
# set the filepath to export the data
path = '../Resuts/Serbia/Pancevo/'
# set the name of the date column
date_col = 'dt_placement'
# set the model type. Could be 'class_regression' or 'mosquito_regression' or 'classification'
model_type = 'class_regression'
# set the transform argument as True if you want to limit the target variable to 0-9 scale
transform_target = False
#set the data for embeddings e.g. data[['col', 'col2']]
embedded_data = None
#set the transformation actions on the data. Options are 'augmentation', 'normalization', 'log', 'scaling'
transformation_list = ['scaling']

# %%
data = feature_expansion(data, env=only_env)

# %%
data = initializer(data, model_type, 10, dropna=True)
# Out:
# Bounds: [   0.    12.6   36.    63.    88.   115.   142.   203.   290.   474.4
#  1905. ]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data = initializer(data, model_type, 10, dropna=True)
#
# File ~\Desktop\noa\Neural Network\Initializer_Module.ipynb:124, in initializer(data, model_type, bound, flag, mosq_column, dropna)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "unnecessary-excerpt",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "from datetime import date, datetime\n",
#      11     "import numpy as np\n",
#      12     "import pandas as pd"
#      13    ]
#      14   },
#      15   {
#      16    "cell_type": "code",
#      17    "execution_count": 2,
#      18    "id": "a0242bec",
#      19    "metadata": {},
#      20    "outputs": [],
#      21    "source": [
#      22     "def pct_rank_qcut(series, n):\n",
#      23     "    edges = pd.Series([float(i) / n for i in range(n)])\n",
#      24     "    f = lambda x: (edges >= x).values.argmax() if not np.isnan(x) else np.nan\n",
#      25     "    return series.rank(pct=1).apply(f)"
#      26    ]
#      27   },
#      28   {
#      29    "cell_type": "code",
#      30    "execution_count": 1,
#      31    "id": "average-census",
#      32    "metadata": {},
#      33    "outputs": [],
#      34    "source": [
#      35     "def create_classes(data, q, mosq_column='mosq_now', imb=False):\n",
#      36     "    \"\"\"Creates the population classes, so as every class is cosnsisting of nearly equal number of observations.\n",
#      37     "       Either the number of classes or a list of bounds must be given.\n",
#      38     "    \n",
#      39     "    Parameters\n",
#      40     "    ----------\n",
#      41     "    data : Dataframe\n",
#      42     "        A Daframe containing the data\n",
#      43     "        \n",
#      44     "    q : int or list\n",
#      45     "        The number of classes to create, or the a list with the bounds of each class \n",
#      46     "        \n",
#      47     "    mosq_column : str, optional\n",
#      48     "        The name of the column with the mosquito classes (default = 'mosq_now')\n",
#      49     "        \n",
#      50     "    imb : bool, optional\n",
#      51     "        if True performs balance handling by setting zeros as a class itself (default = False)\n",
#      52     "        \n",
#      53     "    Returns\n",
#      54     "    ----------\n",
#      55     "    data: Dataframe\n",
#      56     "        A dataframe expanded by the column of class\n",
#      57     "        \n",
#      58     "    Raises\n",
#      59     "    ------\n",
#      60     "    Keyerror\n",
#      61     "        If the name column of mosquitoes given is not in index\n",
#      62     "        \n",
#      63     "    Exception\n",
#      64     "        If neither of number of classes or the list of the bounds is given\n",
#      65     "    \n",
#      66     "    \"\"\"\n",
#      67     "    if (mosq_column not in data.columns):\n",
#      68     "        raise KeyError('Column given not in index')\n",
#      69     "        \n",
#      70     "    if (not isinstance(q, int)) and (not isinstance(q, list)):\n",
#      71     "        raise Exception('Give an integer with the number of classes or a list with the bounds of the class')\n",
#      72     "\n",
#      73     "    if isinstance(q, int):\n",
#      74     "        if imb:\n",
#      75     "            classes = list(range(1,q))\n",
#      76     "            dat = data.loc[data[mosq_column]== 0]\n",
#      77     "            dat[mosq_column] = 0\n",
#      78     "            data2 = data.loc[data[mosq_column] != 0]\n",
#      79     "            bins, bounds = pd.qcut(data2.loc[:, mosq_column], retbins=True, q=q-1, labels=classes)\n",
#      80     "            data2[mosq_column] = bins\n",
#      81     "            data = pd.concat([dat, data2])\n",
#      82     "            data[mosq_column] = pd.Categorical(data[mosq_column])\n",
#      83     "            print('Bounds:', [0]+bounds.tolist())\n",
#      84     "        else:\n",
#      85     "            classes = list(range(q))\n",
#      86     "            bins, bounds = pd.qcut(data.loc[:, mosq_column], retbins=True, q=q, duplicates='raise', labels=classes)\n",
#      87     "            data.loc[:,mosq_column] = bins\n",
#      88     "            print('Bounds:', bounds)\n",
#      89     "    else:\n",
#      90     "        classes = list(range(len(q)-1))\n",
#      91     "        q = np.array(q)\n",
#      92     "        bins, bounds = pd.cut(data.loc[:, mosq_column], bins=q, retbins=True, labels=classes)\n",
#      93     "        data.loc[:,mosq_column] = bins\n",
#      94     "        print('Bounds:', bounds)\n",
#      95     "        \n",
#      96     "    data.loc[:, mosq_column] = data.loc[:, mosq_column].cat.codes\n",
#      97     "    data.loc[:, mosq_column] = data.loc[:, mosq_column].fillna(-1)\n",
#      98     "    data.loc[:, mosq_column] = data.loc[:, mosq_column].astype(int)\n",
#      99     "    idx = data[data[mosq_column]==-1][mosq_column].index\n",
#     100     "    data.loc[idx, mosq_column] = None\n",
#     101     "    \n",
#     102     "    return data"
#     103    ]
#     104   },
#     105   {
#     106    "cell_type": "code",
#     107    "execution_count": null,
#     108    "id": "c06dbfb6",
#     109    "metadata": {},
#     110    "outputs": [],
#     111    "source": [
#     112     "def initializer(data, model_type, bound=None, flag=False, mosq_column = 'mosq_now', dropna = False):\n",
#     113     "    \"\"\"Creates the class of abudance and the target variable for each observation,\n",
#     114     "    and removes all the rows that contain at least one NaN value. Optionally removes columns\n",
#     115     "\n",
#     116     "        Parameters\n",
#     117     "        ----------\n",
#     118     "        data : Dataframe\n",
#     119     "            The dataframe contaning the number of mosquitoes\n",
#     120     "            \n",
#     121     "        bound : int or list, optional\n",
#     122     "            The number of classes (if integer is given), or the bounds of the classes (if a list is given)\n",
#     123     "            (default = None)\n",
# --> 124     "            \n",
#     125     "        flag : bool, optional\n",
#     126     "            if True performs balance handling by setting zeros as a class itself (default = False)\n",
#     127     "        \n",
#     128     "            \n",
#     129     "        mosq_column : str, optional\n",
#     130     "            The name of the column with the mosquito data to create the data from (default = 'mosq_bins')\n",
#     131     "\n",
#     132     "        Returns\n",
#     133     "        ----------\n",
#     134     "        dataframe: Dataframe\n",
#     135     "            An imputed dataframe\n",
#     136     "\n",
#     137     "        Raises\n",
#     138     "        ------\n",
#     139     "        ValueError\n",
#     140     "        If classes muust be created but bounds are not given\n",
#     141     "        \n",
#     142     "        KeyError\n",
#     143     "        If  mosq column given not in index\n",
#     144     "    \"\"\"\n",
#     145     "    if (mosq_column not in data.columns):\n",
#     146     "        raise KeyError('Column given not in index')\n",
#     147     "        \n",
#     148     "    if model_type != 'mosquito_regression':\n",
#     149     "        if bound==None:\n",
#     150     "            raise ValueError('Bound argument must be given (int: number of classes or list: bounds of the classes)')\n",
#     151     "        else:\n",
#     152     "            data = create_classes(data, q=bound, imb=flag, mosq_column=mosq_column)\n",
#     153     "#             data[mosq_column] = pct_rank_qcut(data[mosq_column], bound)\n",
#     154     "    if dropna:\n",
#     155     "        data = data.dropna().reset_index(drop=True)\n",
#     156     "    column_to_move = data.pop(mosq_column)\n",
#     157     "    data[mosq_column] = column_to_move\n",
#     158     "    return data"
#     159    ]
#     160   }
#     161  ],
#     162  "metadata": {
#     163   "kernelspec": {
#     164    "display_name": "Python 3 (ipykernel)",
#     165    "language": "python",
#     166    "name": "python3"
#     167   },
#     168   "language_info": {
#     169    "codemirror_mode": {
#     170     "name": "ipython",
#     171     "version": 3
#     172    },
#     173    "file_extension": ".py",
#     174    "mimetype": "text/x-python",
#     175    "name": "python",
#     176    "nbconvert_exporter": "python",
#     177    "pygments_lexer": "ipython3",
#     178    "version": "3.11.4"
#     179   }
#     180  },
#     181  "nbformat": 4,
#     182  "nbformat_minor": 5
#     183 }
#
# File ~\Desktop\noa\Neural Network\Initializer_Module.ipynb:77, in create_classes(data, q, mosq_column, imb)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#       6    "id": "unnecessary-excerpt",
#       7    "metadata": {},
#       8    "outputs": [],
#       9    "source": [
#      10     "from datetime import date, datetime\n",
#      11     "import numpy as np\n",
#      12     "import pandas as pd"
#      13    ]
#      14   },
#      15   {
#      16    "cell_type": "code",
#      17    "execution_count": 2,
#      18    "id": "a0242bec",
#      19    "metadata": {},
#      20    "outputs": [],
#      21    "source": [
#      22     "def pct_rank_qcut(series, n):\n",
#      23     "    edges = pd.Series([float(i) / n for i in range(n)])\n",
#      24     "    f = lambda x: (edges >= x).values.argmax() if not np.isnan(x) else np.nan\n",
#      25     "    return series.rank(pct=1).apply(f)"
#      26    ]
#      27   },
#      28   {
#      29    "cell_type": "code",
#      30    "execution_count": 1,
#      31    "id": "average-census",
#      32    "metadata": {},
#      33    "outputs": [],
#      34    "source": [
#      35     "def create_classes(data, q, mosq_column='mosq_now', imb=False):\n",
#      36     "    \"\"\"Creates the population classes, so as every class is cosnsisting of nearly equal number of observations.\n",
#      37     "       Either the number of classes or a list of bounds must be given.\n",
#      38     "    \n",
#      39     "    Parameters\n",
#      40     "    ----------\n",
#      41     "    data : Dataframe\n",
#      42     "        A Daframe containing the data\n",
#      43     "        \n",
#      44     "    q : int or list\n",
#      45     "        The number of classes to create, or the a list with the bounds of each class \n",
#      46     "        \n",
#      47     "    mosq_column : str, optional\n",
#      48     "        The name of the column with the mosquito classes (default = 'mosq_now')\n",
#      49     "        \n",
#      50     "    imb : bool, optional\n",
#      51     "        if True performs balance handling by setting zeros as a class itself (default = False)\n",
#      52     "        \n",
#      53     "    Returns\n",
#      54     "    ----------\n",
#      55     "    data: Dataframe\n",
#      56     "        A dataframe expanded by the column of class\n",
#      57     "        \n",
#      58     "    Raises\n",
#      59     "    ------\n",
#      60     "    Keyerror\n",
#      61     "        If the name column of mosquitoes given is not in index\n",
#      62     "        \n",
#      63     "    Exception\n",
#      64     "        If neither of number of classes or the list of the bounds is given\n",
#      65     "    \n",
#      66     "    \"\"\"\n",
#      67     "    if (mosq_column not in data.columns):\n",
#      68     "        raise KeyError('Column given not in index')\n",
#      69     "        \n",
#      70     "    if (not isinstance(q, int)) and (not isinstance(q, list)):\n",
#      71     "        raise Exception('Give an integer with the number of classes or a list with the bounds of the class')\n",
#      72     "\n",
#      73     "    if isinstance(q, int):\n",
#      74     "        if imb:\n",
#      75     "            classes = list(range(1,q))\n",
#      76     "            dat = data.loc[data[mosq_column]== 0]\n",
# ---> 77     "            dat[mosq_column] = 0\n",
#      78     "            data2 = data.loc[data[mosq_column] != 0]\n",
#      79     "            bins, bounds = pd.qcut(data2.loc[:, mosq_column], retbins=True, q=q-1, labels=classes)\n",
#      80     "            data2[mosq_column] = bins\n",
#      81     "            data = pd.concat([dat, data2])\n",
#      82     "            data[mosq_column] = pd.Categorical(data[mosq_column])\n",
#      83     "            print('Bounds:', [0]+bounds.tolist())\n",
#      84     "        else:\n",
#      85     "            classes = list(range(q))\n",
#      86     "            bins, bounds = pd.qcut(data.loc[:, mosq_column], retbins=True, q=q, duplicates='raise', labels=classes)\n",
#      87     "            data.loc[:,mosq_column] = bins\n",
#      88     "            print('Bounds:', bounds)\n",
#      89     "    else:\n",
#      90     "        classes = list(range(len(q)-1))\n",
#      91     "        q = np.array(q)\n",
#      92     "        bins, bounds = pd.cut(data.loc[:, mosq_column], bins=q, retbins=True, labels=classes)\n",
#      93     "        data.loc[:,mosq_column] = bins\n",
#      94     "        print('Bounds:', bounds)\n",
#      95     "        \n",
#      96     "    data.loc[:, mosq_column] = data.loc[:, mosq_column].cat.codes\n",
#      97     "    data.loc[:, mosq_column] = data.loc[:, mosq_column].fillna(-1)\n",
#      98     "    data.loc[:, mosq_column] = data.loc[:, mosq_column].astype(int)\n",
#      99     "    idx = data[data[mosq_column]==-1][mosq_column].index\n",
#     100     "    data.loc[idx, mosq_column] = None\n",
#     101     "    \n",
#     102     "    return data"
#     103    ]
#     104   },
#     105   {
#     106    "cell_type": "code",
#     107    "execution_count": null,
#     108    "id": "c06dbfb6",
#     109    "metadata": {},
#     110    "outputs": [],
#     111    "source": [
#     112     "def initializer(data, model_type, bound=None, flag=False, mosq_column = 'mosq_now', dropna = False):\n",
#     113     "    \"\"\"Creates the class of abudance and the target variable for each observation,\n",
#     114     "    and removes all the rows that contain at least one NaN value. Optionally removes columns\n",
#     115     "\n",
#     116     "        Parameters\n",
#     117     "        ----------\n",
#     118     "        data : Dataframe\n",
#     119     "            The dataframe contaning the number of mosquitoes\n",
#     120     "            \n",
#     121     "        bound : int or list, optional\n",
#     122     "            The number of classes (if integer is given), or the bounds of the classes (if a list is given)\n",
#     123     "            (default = None)\n",
#     124     "            \n",
#     125     "        flag : bool, optional\n",
#     126     "            if True performs balance handling by setting zeros as a class itself (default = False)\n",
#     127     "        \n",
#     128     "            \n",
#     129     "        mosq_column : str, optional\n",
#     130     "            The name of the column with the mosquito data to create the data from (default = 'mosq_bins')\n",
#     131     "\n",
#     132     "        Returns\n",
#     133     "        ----------\n",
#     134     "        dataframe: Dataframe\n",
#     135     "            An imputed dataframe\n",
#     136     "\n",
#     137     "        Raises\n",
#     138     "        ------\n",
#     139     "        ValueError\n",
#     140     "        If classes muust be created but bounds are not given\n",
#     141     "        \n",
#     142     "        KeyError\n",
#     143     "        If  mosq column given not in index\n",
#     144     "    \"\"\"\n",
#     145     "    if (mosq_column not in data.columns):\n",
#     146     "        raise KeyError('Column given not in index')\n",
#     147     "        \n",
#     148     "    if model_type != 'mosquito_regression':\n",
#     149     "        if bound==None:\n",
#     150     "            raise ValueError('Bound argument must be given (int: number of classes or list: bounds of the classes)')\n",
#     151     "        else:\n",
#     152     "            data = create_classes(data, q=bound, imb=flag, mosq_column=mosq_column)\n",
#     153     "#             data[mosq_column] = pct_rank_qcut(data[mosq_column], bound)\n",
#     154     "    if dropna:\n",
#     155     "        data = data.dropna().reset_index(drop=True)\n",
#     156     "    column_to_move = data.pop(mosq_column)\n",
#     157     "    data[mosq_column] = column_to_move\n",
#     158     "    return data"
#     159    ]
#     160   }
#     161  ],
#     162  "metadata": {
#     163   "kernelspec": {
#     164    "display_name": "Python 3 (ipykernel)",
#     165    "language": "python",
#     166    "name": "python3"
#     167   },
#     168   "language_info": {
#     169    "codemirror_mode": {
#     170     "name": "ipython",
#     171     "version": 3
#     172    },
#     173    "file_extension": ".py",
#     174    "mimetype": "text/x-python",
#     175    "name": "python",
#     176    "nbconvert_exporter": "python",
#     177    "pygments_lexer": "ipython3",
#     178    "version": "3.11.4"
#     179   }
#     180  },
#     181  "nbformat": 4,
#     182  "nbformat_minor": 5
#     183 }
#
# File ~\anaconda3\envs\noa3\Lib\site-packages\pandas\core\series.py:5145, in Series.fillna(self, value, method, axis, inplace, limit, downcast)
#    5134 @doc(NDFrame.fillna, **_shared_doc_kwargs)
#    5135 def fillna(
#    5136     self,
#    (...)
#    5143     downcast: dict | None = None,
#    5144 ) -> Series | None:
# -> 5145     return super().fillna(
#    5146         value=value,
#    5147         method=method,
#    5148         axis=axis,
#    5149         inplace=inplace,
#    5150         limit=limit,
#    5151         downcast=downcast,
#    5152     )
#
# File ~\anaconda3\envs\noa3\Lib\site-packages\pandas\core\generic.py:6904, in NDFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#    6897     else:
#    6898         raise TypeError(
#    6899             '"value" parameter must be a scalar, dict '
#    6900             "or Series, but you passed a "
#    6901             f'"{type(value).__name__}"'
#    6902         )
# -> 6904     new_data = self._mgr.fillna(
#    6905         value=value, limit=limit, inplace=inplace, downcast=downcast
#    6906     )
#    6908 elif isinstance(value, (dict, ABCSeries)):
#    6909     if axis == 1:
#
# File ~\anaconda3\envs\noa3\Lib\site-packages\pandas\core\internals\managers.py:433, in BaseBlockManager.fillna(self, value, limit, inplace, downcast)
#     429 if limit is not None:
#     430     # Do this validation even if we go through one of the no-op paths
#     431     limit = libalgos.validate_limit(None, limit=limit)
# --> 433 return self.apply(
#     434     "fillna",
#     435     value=value,
#     436     limit=limit,
#     437     inplace=inplace,
#     438     downcast=downcast,
#     439     using_cow=using_copy_on_write(),
#     440 )
#
# File ~\anaconda3\envs\noa3\Lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353     result_blocks = extend_blocks(applied, result_blocks)
#     355 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\anaconda3\envs\noa3\Lib\site-packages\pandas\core\internals\blocks.py:1868, in ExtensionBlock.fillna(self, value, limit, inplace, downcast, using_cow)
#    1866 else:
#    1867     refs = None
# -> 1868     new_values = self.values.fillna(value=value, method=None, limit=limit)
#    1869 nb = self.make_block_same_class(new_values, refs=refs)
#    1870 return nb._maybe_downcast([nb], downcast, using_cow=using_cow)
#
# File ~\anaconda3\envs\noa3\Lib\site-packages\pandas\core\arrays\_mixins.py:328, in NDArrayBackedExtensionArray.fillna(self, value, method, limit)
#     325 else:
#     326     # We validate the fill_value even if there is nothing to fill
#     327     if value is not None:
# --> 328         self._validate_setitem_value(value)
#     330     new_values = self.copy()
#     331 return new_values
#
# File ~\anaconda3\envs\noa3\Lib\site-packages\pandas\core\arrays\categorical.py:1297, in Categorical._validate_setitem_value(self, value)
#    1295     return self._validate_listlike(value)
#    1296 else:
# -> 1297     return self._validate_scalar(value)
#
# File ~\anaconda3\envs\noa3\Lib\site-packages\pandas\core\arrays\categorical.py:1322, in Categorical._validate_scalar(self, fill_value)
#    1320     fill_value = self._unbox_scalar(fill_value)
#    1321 else:
# -> 1322     raise TypeError(
#    1323         "Cannot setitem on a Categorical with a new "
#    1324         f"category ({fill_value}), set the categories first"
#    1325     ) from None
#    1326 return fill_value
#
# TypeError: Cannot setitem on a Categorical with a new category (-1), set the categories first

# %%
model = FeedforwardNeuralNetModel(num_features=len(data.iloc[0,:])-2, num_class=1,
                                  hidden_layers = [264,128,128,64,32], model_type=model_type, learning_rate = 0.001,
                                  epochs = 50, batch_size = 128, embedding_data=embedded_data,
                                  dropout=0.2, transformation_list=transformation_list,
                                  early_stop = None, l1_weight=0, l2_weight=0, weights=False)

# %%
test_model_random_split(data, model, filepath = path, date_col = date_col, case=case_title, export=exp)

# %%
train_model_KFold(data, model, date_col=date_col)

# %%
operational_validation(data, model, date='2022-01-01', filepath=path, date_col=date_col, case=case_title, export=exp)
